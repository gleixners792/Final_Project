# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
hcpsc_key_file = "top_ten_list.csv"
top10_df = pd.read_csv(os.path.join("..", "Data", hcpsc_key_file),sep=',')
top10_df
# Out:
#   Occurance_top_10 Line_Service_top_10
# 0            99213               P9603
# 1            99214               A0425
# 2            99204               99213
# 3            99203               99214
# 4            99212               J1071
# 5            93000               J0585
# 6            36415               36415
# 7            99215               95004
# 8            96372               Q0138
# 9            G0008               G0471

# %%
input_data_file = "sort_data.txt"
df = pd.read_csv(os.path.join("..", "Data", input_data_file),sep='\t')
#df = pd.read_csv(os.path.join("..", "Data", input_data_file),sep='\t', nrows=5000000)

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
#df = df.dropna()
df.head()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           npi nppes_provider_gender nppes_entity_code nppes_provider_city  \
# 0  1205963402                     M                 I           ROCKVILLE
# 1  1467447557                     M                 I               FLINT
# 2  1952417610                     M                 I             HOUSTON
# 3  1467447557                     M                 I               FLINT
# 4  1467447557                     M                 I               FLINT
#
#   nppes_provider_zip nppes_provider_state nppes_provider_country  \
# 0        2.08521e+08                   MD                     US
# 1        4.85325e+08                   MI                     US
# 2        7.70813e+08                   TX                     US
# 3        4.85325e+08                   MI                     US
# 4        4.85325e+08                   MI                     US
#
#         provider_type medicare_participation_indicator place_of_service  ...  \
# 0  Allergy/Immunology                                Y                O  ...
# 1     Family Practice                                Y                O  ...
# 2           Neurology                                Y                O  ...
# 3     Family Practice                                Y                O  ...
# 4     Family Practice                                Y                O  ...
#
#   hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt  bene_day_srvc_cnt  \
# 0                    N         153.0            13.0              153.0
# 1                    N          93.0            65.0               93.0
# 2                    N          36.0            35.0               36.0
# 3                    N         724.0           210.0              724.0
# 4                    N          11.0            11.0               11.0
#
#    average_Medicare_allowed_amt  average_submitted_chrg_amt  \
# 0                     11.800000                   25.000000
# 1                    129.454731                  209.408602
# 2                     40.992778                   50.123611
# 3                     48.580000                  150.000000
# 4                     25.000000                   25.000000
#
#    average_Medicare_payment_amt  year  leie_code     leie
# 0                      7.897516  2012     1128b4  On_List
# 1                     97.705054  2017     1128a1  On_List
# 2                     25.856944  2014     1128a1  On_List
# 3                     47.610000  2017     1128a1  On_List
# 4                      6.985455  2017     1128a1  On_List
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56819227 entries, 0 to 56819226
# Data columns (total 22 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_gender             object
#  2   nppes_entity_code                 object
#  3   nppes_provider_city               object
#  4   nppes_provider_zip                object
#  5   nppes_provider_state              object
#  6   nppes_provider_country            object
#  7   provider_type                     object
#  8   medicare_participation_indicator  object
#  9   place_of_service                  object
#  10  hcpcs_code                        object
#  11  hcpcs_description                 object
#  12  hcpcs_drug_indicator              object
#  13  line_srvc_cnt                     float64
#  14  bene_unique_cnt                   float64
#  15  bene_day_srvc_cnt                 float64
#  16  average_Medicare_allowed_amt      float64
#  17  average_submitted_chrg_amt        float64
#  18  average_Medicare_payment_amt      float64
#  19  year                              int64
#  20  leie_code                         object
#  21  leie                              object
# dtypes: float64(6), int64(2), object(14)
# memory usage: 9.3+ GB

# %%
new_df = df.loc[(df["leie"] == "On_List"), :]

# %%
#df = df.sort_values("leie", ascending=False)

# %%
new_df
# Out:
#               npi nppes_provider_gender nppes_entity_code nppes_provider_city  \
# 0      1205963402                     M                 I           ROCKVILLE
# 1      1467447557                     M                 I               FLINT
# 2      1952417610                     M                 I             HOUSTON
# 3      1467447557                     M                 I               FLINT
# 4      1467447557                     M                 I               FLINT
# ...           ...                   ...               ...                 ...
# 60317  1447202205                     M                 I              HAZARD
# 60318  1447202205                     M                 I              HAZARD
# 60319  1659434108                     M                 I         ORLAND PARK
# 60320  1447202205                     M                 I              HAZARD
# 60321  1649373291                     M                 I              ENCINO
#
#       nppes_provider_zip nppes_provider_state nppes_provider_country  \
# 0            2.08521e+08                   MD                     US
# 1            4.85325e+08                   MI                     US
# 2            7.70813e+08                   TX                     US
# 3            4.85325e+08                   MI                     US
# 4            4.85325e+08                   MI                     US
# ...                  ...                  ...                    ...
# 60317              41701                   KY                     US
# 60318              41701                   KY                     US
# 60319        6.04627e+08                   IL                     US
# 60320              41701                   KY                     US
# 60321              91316                   CA                     US
#
#             provider_type medicare_participation_indicator place_of_service  \
# 0      Allergy/Immunology                                Y                O
# 1         Family Practice                                Y                O
# 2               Neurology                                Y                O
# 3         Family Practice                                Y                O
# 4         Family Practice                                Y                O
# ...                   ...                              ...              ...
# 60317    General Practice                                Y                O
# 60318    General Practice                                Y                O
# 60319     General Surgery                                Y                O
# 60320    General Practice                                Y                O
# 60321   Internal Medicine                                Y                O
#
#        ... hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt  \
# 0      ...                    N         153.0            13.0
# 1      ...                    N          93.0            65.0
# 2      ...                    N          36.0            35.0
# 3      ...                    N         724.0           210.0
# 4      ...                    N          11.0            11.0
# ...    ...                  ...           ...             ...
# 60317  ...                    N         175.0           111.0
# 60318  ...                    N         168.0           158.0
# 60319  ...                    N          31.0            31.0
# 60320  ...                    N         171.0           161.0
# 60321  ...                    N         712.0           128.0
#
#        bene_day_srvc_cnt  average_Medicare_allowed_amt  \
# 0                  153.0                     11.800000
# 1                   93.0                    129.454731
# 2                   36.0                     40.992778
# 3                  724.0                     48.580000
# 4                   11.0                     25.000000
# ...                  ...                           ...
# 60317              175.0                      4.320000
# 60318              168.0                     18.680000
# 60319               31.0                    197.070000
# 60320              171.0                     15.620000
# 60321              712.0                    113.820000
#
#        average_submitted_chrg_amt  average_Medicare_payment_amt  year  \
# 0                       25.000000                      7.897516  2012
# 1                      209.408602                     97.705054  2017
# 2                       50.123611                     25.856944  2014
# 3                      150.000000                     47.610000  2017
# 4                       25.000000                      6.985455  2017
# ...                           ...                           ...   ...
# 60317                   10.000000                      4.230000  2014
# 60318                   40.000000                     18.310000  2014
# 60319                  400.000000                    154.510000  2013
# 60320                   40.000000                     15.310000  2014
# 60321                  180.000000                     81.597360  2016
#
#        leie_code     leie
# 0         1128b4  On_List
# 1         1128a1  On_List
# 2         1128a1  On_List
# 3         1128a1  On_List
# 4         1128a1  On_List
# ...          ...      ...
# 60317  1128a1     On_List
# 60318     1128b4  On_List
# 60319     1128b4  On_List
# 60320  1128a1     On_List
# 60321     1128a2  On_List
#
# [60322 rows x 22 columns]

# %%
output_data_file = "mike_data.txt"
new_df.to_csv(os.path.join("..", "Data", output_data_file), index= False, sep='\t')
