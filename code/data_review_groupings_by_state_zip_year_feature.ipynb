# %%
import pandas as pd
import numpy as np
import os

# %%
data_file2012 = "Medicare_Provider_Util_Payment_PUF_CY2012.txt"
data_file2013 = "Medicare_Provider_Util_Payment_PUF_CY2013.txt"
data_file2014 = "Medicare_Provider_Util_Payment_PUF_CY2014.txt"
data_file2015 = "Medicare_Provider_Util_Payment_PUF_CY2015.txt"
data_file2016 = "Medicare_Provider_Util_Payment_PUF_CY2016.txt"
data_file2017 = "Medicare_Provider_Util_Payment_PUF_CY2017.txt"
data_updated = "UPDATED.csv"


provider_1 = 1104909043
provider_2 = 1568476968

# %%
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2012),sep='\t', nrows=500)
data_df = pd.read_csv(os.path.join("..", "Data", data_file2012),sep='\t')
# Drop the null rows
#data_df = data_df.dropna()
#data_df.head()
data_df.info()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9153273 entries, 0 to 9153272
# Data columns (total 28 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   NPI                               int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      object
#  2   NPPES_PROVIDER_FIRST_NAME         object
#  3   NPPES_PROVIDER_MI                 object
#  4   NPPES_CREDENTIALS                 object
#  5   NPPES_PROVIDER_GENDER             object
#  6   NPPES_ENTITY_CODE                 object
#  7   NPPES_PROVIDER_STREET1            object
#  8   NPPES_PROVIDER_STREET2            object
#  9   NPPES_PROVIDER_CITY               object
#  10  NPPES_PROVIDER_ZIP                object
#  11  NPPES_PROVIDER_STATE              object
#  12  NPPES_PROVIDER_COUNTRY            object
#  13  PROVIDER_TYPE                     object
#  14  MEDICARE_PARTICIPATION_INDICATOR  object
#  15  PLACE_OF_SERVICE                  object
#  16  HCPCS_CODE                        object
#  17  HCPCS_DESCRIPTION                 object
#  18  HCPCS_DRUG_INDICATOR              object
#  19  LINE_SRVC_CNT                     float64
#  20  BENE_UNIQUE_CNT                   float64
#  21  BENE_DAY_SRVC_CNT                 float64
#  22  AVERAGE_MEDICARE_ALLOWED_AMT      float64
#  23  STDEV_MEDICARE_ALLOWED_AMT        float64
#  24  AVERAGE_SUBMITTED_CHRG_AMT        float64
#  25  STDEV_SUBMITTED_CHRG_AMT          float64
#  26  AVERAGE_MEDICARE_PAYMENT_AMT      float64
#  27  STDEV_MEDICARE_PAYMENT_AMT        float64
# dtypes: float64(9), int64(1), object(18)
# memory usage: 1.9+ GB

# %%
data_df.drop(data_df[data_df['NPI'] == 1].index, inplace = True)
data_df.drop(data_df[data_df['NPPES_PROVIDER_COUNTRY'] != "US"].index, inplace = True)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9152973 entries, 1 to 9153272
# Data columns (total 28 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   NPI                               int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      object
#  2   NPPES_PROVIDER_FIRST_NAME         object
#  3   NPPES_PROVIDER_MI                 object
#  4   NPPES_CREDENTIALS                 object
#  5   NPPES_PROVIDER_GENDER             object
#  6   NPPES_ENTITY_CODE                 object
#  7   NPPES_PROVIDER_STREET1            object
#  8   NPPES_PROVIDER_STREET2            object
#  9   NPPES_PROVIDER_CITY               object
#  10  NPPES_PROVIDER_ZIP                object
#  11  NPPES_PROVIDER_STATE              object
#  12  NPPES_PROVIDER_COUNTRY            object
#  13  PROVIDER_TYPE                     object
#  14  MEDICARE_PARTICIPATION_INDICATOR  object
#  15  PLACE_OF_SERVICE                  object
#  16  HCPCS_CODE                        object
#  17  HCPCS_DESCRIPTION                 object
#  18  HCPCS_DRUG_INDICATOR              object
#  19  LINE_SRVC_CNT                     float64
#  20  BENE_UNIQUE_CNT                   float64
#  21  BENE_DAY_SRVC_CNT                 float64
#  22  AVERAGE_MEDICARE_ALLOWED_AMT      float64
#  23  STDEV_MEDICARE_ALLOWED_AMT        float64
#  24  AVERAGE_SUBMITTED_CHRG_AMT        float64
#  25  STDEV_SUBMITTED_CHRG_AMT          float64
#  26  AVERAGE_MEDICARE_PAYMENT_AMT      float64
#  27  STDEV_MEDICARE_PAYMENT_AMT        float64
# dtypes: float64(9), int64(1), object(18)
# memory usage: 2.0+ GB

# %%
data_df
# Out:
#                 NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 1        1003000126                    ENKESHAFI                   ARDALAN
# 2        1003000126                    ENKESHAFI                   ARDALAN
# 3        1003000126                    ENKESHAFI                   ARDALAN
# 4        1003000126                    ENKESHAFI                   ARDALAN
# 5        1003000126                    ENKESHAFI                   ARDALAN
# ...             ...                          ...                       ...
# 9153268  1992999874                        JOFFE                 GABRIELLA
# 9153269  1992999874                        JOFFE                 GABRIELLA
# 9153270  1992999874                        JOFFE                 GABRIELLA
# 9153271  1992999874                        JOFFE                 GABRIELLA
# 9153272  1992999874                        JOFFE                 GABRIELLA
#
#         NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER  \
# 1                     NaN              M.D.                     M
# 2                     NaN              M.D.                     M
# 3                     NaN              M.D.                     M
# 4                     NaN              M.D.                     M
# 5                     NaN              M.D.                     M
# ...                   ...               ...                   ...
# 9153268               NaN               NaN                     F
# 9153269               NaN               NaN                     F
# 9153270               NaN               NaN                     F
# 9153271               NaN               NaN                     F
# 9153272               NaN               NaN                     F
#
#         NPPES_ENTITY_CODE NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2  \
# 1                       I           900 SETON DR                    NaN
# 2                       I           900 SETON DR                    NaN
# 3                       I           900 SETON DR                    NaN
# 4                       I           900 SETON DR                    NaN
# 5                       I           900 SETON DR                    NaN
# ...                   ...                    ...                    ...
# 9153268                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9153269                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9153270                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9153271                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9153272                 I          8260 ATLEE RD       MOB 2, SUITE 319
#
#         NPPES_PROVIDER_CITY  ... HCPCS_DRUG_INDICATOR LINE_SRVC_CNT  \
# 1                CUMBERLAND  ...                    N         115.0
# 2                CUMBERLAND  ...                    N          93.0
# 3                CUMBERLAND  ...                    N         111.0
# 4                CUMBERLAND  ...                    N         544.0
# 5                CUMBERLAND  ...                    N          75.0
# ...                     ...  ...                  ...           ...
# 9153268      MECHANICSVILLE  ...                    N          69.0
# 9153269      MECHANICSVILLE  ...                    N          99.0
# 9153270      MECHANICSVILLE  ...                    N         462.0
# 9153271      MECHANICSVILLE  ...                    N         189.0
# 9153272      MECHANICSVILLE  ...                    N         164.0
#
#         BENE_UNIQUE_CNT BENE_DAY_SRVC_CNT AVERAGE_MEDICARE_ALLOWED_AMT  \
# 1                 112.0             115.0                       135.25
# 2                  88.0              93.0                       198.59
# 3                  83.0             111.0                        38.75
# 4                 295.0             544.0                        70.95
# 5                  55.0              75.0                       101.74
# ...                 ...               ...                          ...
# 9153268            69.0              69.0                       130.23
# 9153269            98.0              99.0                       191.48
# 9153270           202.0             462.0                        68.59
# 9153271           105.0             189.0                        98.33
# 9153272           157.0             164.0                       101.33
#
#         STDEV_MEDICARE_ALLOWED_AMT AVERAGE_SUBMITTED_CHRG_AMT  \
# 1                              0.0                 199.000000
# 2                              0.0                 291.000000
# 3                              0.0                  58.000000
# 4                              0.0                 105.000000
# 5                              0.0                 150.000000
# ...                            ...                        ...
# 9153268                        0.0                 319.884058
# 9153269                        0.0                 481.292929
# 9153270                        0.0                 174.073593
# 9153271                        0.0                 251.444444
# 9153272                        0.0                 257.487805
#
#         STDEV_SUBMITTED_CHRG_AMT AVERAGE_MEDICARE_PAYMENT_AMT  \
# 1                       0.000000                   108.115652
# 2                       9.591663                   158.870000
# 3                       0.000000                    30.720721
# 4                       0.000000                    56.655662
# 5                       0.000000                    81.390000
# ...                          ...                          ...
# 9153268                24.033513                   104.180000
# 9153269                37.827159                   153.180000
# 9153270                 5.429497                    54.779156
# 9153271                 7.228203                    78.341587
# 9153272                12.107490                    80.680488
#
#          STDEV_MEDICARE_PAYMENT_AMT
# 1                          0.900588
# 2                          0.000000
# 3                          2.929106
# 4                          2.431327
# 5                          0.000000
# ...                             ...
# 9153268                    0.000000
# 9153269                    0.000000
# 9153270                    1.950507
# 9153271                    4.365855
# 9153272                    4.845287
#
# [9152973 rows x 28 columns]

# %%
data_df['NPPES_PROVIDER_ZIP'] = data_df['NPPES_PROVIDER_ZIP'].apply(str)
#data_df.info()
data_df['new_zip'] = data_df['NPPES_PROVIDER_ZIP'].str[:5]
#data_df['facility'] = [1 if x == "F" else 0 for x in data_df['PLACE_OF_SERVICE']]
#data_df['outside'] = [1 if x == "O" else 0 for x in data_df['PLACE_OF_SERVICE']]
data_df['facility'] = data_df["BENE_DAY_SRVC_CNT"].where(data_df['PLACE_OF_SERVICE'] == "F", 0)
data_df['outside'] = data_df["BENE_DAY_SRVC_CNT"].where(data_df['PLACE_OF_SERVICE'] == "O", 0)
data_df['year'] = 2012

df_data_2012 = data_df.groupby(['NPPES_PROVIDER_STATE', 'new_zip', 'year']).agg({'LINE_SRVC_CNT': ['median'],
                                                                                                      'facility' : ['median'],
                                                                                                      'outside' : ['median']})
       
df_data_2012
# Out:
#                                   LINE_SRVC_CNT facility outside
#                                          median   median  median
# NPPES_PROVIDER_STATE new_zip year
# AA                   20307   2012          14.0     14.0     0.0
#                      28310   2012          14.0     14.0     0.0
#                      32925   2012          45.0     14.0     0.0
#                      73503   2012          30.0     27.0     0.0
# AE                   09550   2012          31.5     31.5     0.0
# ...                                         ...      ...     ...
# WY                   83116   2012          91.0      0.0    82.5
#                      83126   2012        1151.5      0.0  1151.5
#                      83127   2012          70.0      0.0    54.5
#                      83128   2012          17.0      0.0    17.0
# XX                   33483   2012          43.0      0.0    43.0
#
# [26934 rows x 3 columns]

# %%
df_data_2012 = df_data_2012.reset_index()
df_data_2012.columns = ['state', 'zip_code', 'year', 'line_srcv_median', 'facility_median', 'outside_median']
df_data_2012
# Out:
#       state zip_code  year  line_srcv_median  facility_median  outside_median
# 0        AA    20307  2012              14.0             14.0             0.0
# 1        AA    28310  2012              14.0             14.0             0.0
# 2        AA    32925  2012              45.0             14.0             0.0
# 3        AA    73503  2012              30.0             27.0             0.0
# 4        AE    09550  2012              31.5             31.5             0.0
# ...     ...      ...   ...               ...              ...             ...
# 26929    WY    83116  2012              91.0              0.0            82.5
# 26930    WY    83126  2012            1151.5              0.0          1151.5
# 26931    WY    83127  2012              70.0              0.0            54.5
# 26932    WY    83128  2012              17.0              0.0            17.0
# 26933    XX    33483  2012              43.0              0.0            43.0
#
# [26934 rows x 6 columns]

# %%
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2013),sep='\t', nrows=5000)
data_df = pd.read_csv(os.path.join("..", "Data", data_file2013),sep='\t')
# Drop the null rows
#data_df = data_df.dropna()
data_df.info()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9287877 entries, 0 to 9287876
# Data columns (total 28 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   NPI                               int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      object
#  2   NPPES_PROVIDER_FIRST_NAME         object
#  3   NPPES_PROVIDER_MI                 object
#  4   NPPES_CREDENTIALS                 object
#  5   NPPES_PROVIDER_GENDER             object
#  6   NPPES_ENTITY_CODE                 object
#  7   NPPES_PROVIDER_STREET1            object
#  8   NPPES_PROVIDER_STREET2            object
#  9   NPPES_PROVIDER_CITY               object
#  10  NPPES_PROVIDER_ZIP                object
#  11  NPPES_PROVIDER_STATE              object
#  12  NPPES_PROVIDER_COUNTRY            object
#  13  PROVIDER_TYPE                     object
#  14  MEDICARE_PARTICIPATION_INDICATOR  object
#  15  PLACE_OF_SERVICE                  object
#  16  HCPCS_CODE                        object
#  17  HCPCS_DESCRIPTION                 object
#  18  HCPCS_DRUG_INDICATOR              object
#  19  LINE_SRVC_CNT                     float64
#  20  BENE_UNIQUE_CNT                   float64
#  21  BENE_DAY_SRVC_CNT                 float64
#  22  AVERAGE_MEDICARE_ALLOWED_AMT      float64
#  23  STDEV_MEDICARE_ALLOWED_AMT        float64
#  24  AVERAGE_SUBMITTED_CHRG_AMT        float64
#  25  STDEV_SUBMITTED_CHRG_AMT          float64
#  26  AVERAGE_MEDICARE_PAYMENT_AMT      float64
#  27  STDEV_MEDICARE_PAYMENT_AMT        float64
# dtypes: float64(9), int64(1), object(18)
# memory usage: 1.9+ GB

# %%
data_df.drop(data_df[data_df['NPI'] == 1].index, inplace = True)
data_df.drop(data_df[data_df['NPPES_PROVIDER_COUNTRY'] != "US"].index, inplace = True)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9287471 entries, 1 to 9287876
# Data columns (total 28 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   NPI                               int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      object
#  2   NPPES_PROVIDER_FIRST_NAME         object
#  3   NPPES_PROVIDER_MI                 object
#  4   NPPES_CREDENTIALS                 object
#  5   NPPES_PROVIDER_GENDER             object
#  6   NPPES_ENTITY_CODE                 object
#  7   NPPES_PROVIDER_STREET1            object
#  8   NPPES_PROVIDER_STREET2            object
#  9   NPPES_PROVIDER_CITY               object
#  10  NPPES_PROVIDER_ZIP                object
#  11  NPPES_PROVIDER_STATE              object
#  12  NPPES_PROVIDER_COUNTRY            object
#  13  PROVIDER_TYPE                     object
#  14  MEDICARE_PARTICIPATION_INDICATOR  object
#  15  PLACE_OF_SERVICE                  object
#  16  HCPCS_CODE                        object
#  17  HCPCS_DESCRIPTION                 object
#  18  HCPCS_DRUG_INDICATOR              object
#  19  LINE_SRVC_CNT                     float64
#  20  BENE_UNIQUE_CNT                   float64
#  21  BENE_DAY_SRVC_CNT                 float64
#  22  AVERAGE_MEDICARE_ALLOWED_AMT      float64
#  23  STDEV_MEDICARE_ALLOWED_AMT        float64
#  24  AVERAGE_SUBMITTED_CHRG_AMT        float64
#  25  STDEV_SUBMITTED_CHRG_AMT          float64
#  26  AVERAGE_MEDICARE_PAYMENT_AMT      float64
#  27  STDEV_MEDICARE_PAYMENT_AMT        float64
# dtypes: float64(9), int64(1), object(18)
# memory usage: 2.0+ GB

# %%
data_df['NPPES_PROVIDER_ZIP'] = data_df['NPPES_PROVIDER_ZIP'].apply(str)
#data_df.info()
data_df['new_zip'] = data_df['NPPES_PROVIDER_ZIP'].str[:5]
#data_df['facility'] = [1 if x == "F" else 0 for x in data_df['PLACE_OF_SERVICE']]
#data_df['outside'] = [1 if x == "O" else 0 for x in data_df['PLACE_OF_SERVICE']]
data_df['facility'] = data_df["BENE_DAY_SRVC_CNT"].where(data_df['PLACE_OF_SERVICE'] == "F", 0)
data_df['outside'] = data_df["BENE_DAY_SRVC_CNT"].where(data_df['PLACE_OF_SERVICE'] == "O", 0)
data_df['year'] = 2013


df_data_2013 = data_df.groupby(['NPPES_PROVIDER_STATE', 'new_zip', 'year']).agg({'LINE_SRVC_CNT': ['median'],
                                                                                                      'facility' : ['median'],
                                                                                                      'outside' : ['median']})
       
df_data_2013
# Out:
#                                   LINE_SRVC_CNT facility outside
#                                          median   median  median
# NPPES_PROVIDER_STATE new_zip year
# AA                   20307   2013          16.0     16.0     0.0
#                      28310   2013          34.0     34.0     0.0
#                      28547   2013          15.0     15.0     0.0
#                      73503   2013          26.0     26.0     0.0
#                      94535   2013          22.0     22.0     0.0
# ...                                         ...      ...     ...
# WY                   83127   2013          58.0      0.0    45.0
#                      83128   2013          45.0      0.0    45.0
# XX                   0       2013          24.0     24.0     0.0
#                      33483   2013          41.0      0.0    41.0
#                      969     2013          35.0     35.0     0.0
#
# [27060 rows x 3 columns]

# %%
df_data_2013 = df_data_2013.reset_index()
df_data_2013.columns = ['state', 'zip_code', 'year', 'line_srcv_median', 'facility_median', 'outside_median']
df_data_2013
# Out:
#       state zip_code  year  line_srcv_median  facility_median  outside_median
# 0        AA    20307  2013              16.0             16.0             0.0
# 1        AA    28310  2013              34.0             34.0             0.0
# 2        AA    28547  2013              15.0             15.0             0.0
# 3        AA    73503  2013              26.0             26.0             0.0
# 4        AA    94535  2013              22.0             22.0             0.0
# ...     ...      ...   ...               ...              ...             ...
# 27055    WY    83127  2013              58.0              0.0            45.0
# 27056    WY    83128  2013              45.0              0.0            45.0
# 27057    XX        0  2013              24.0             24.0             0.0
# 27058    XX    33483  2013              41.0              0.0            41.0
# 27059    XX      969  2013              35.0             35.0             0.0
#
# [27060 rows x 6 columns]

# %%
data_df_total = pd.concat([df_data_2012, df_data_2013])
data_df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53994 entries, 0 to 27059
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             53994 non-null  object
#  1   zip_code          53994 non-null  object
#  2   year              53994 non-null  int64
#  3   line_srcv_median  53994 non-null  float64
#  4   facility_median   53994 non-null  float64
#  5   outside_median    53994 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.9+ MB

# %%
#data_df_total[240900:240920]

# %%
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2014),sep='\t', nrows=50000)
data_df = pd.read_csv(os.path.join("..", "Data", data_file2014),sep='\t')
# Drop the null rows
#data_df = data_df.dropna()
data_df.info()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9316308 entries, 0 to 9316307
# Data columns (total 26 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_last_org_name      object
#  2   nppes_provider_first_name         object
#  3   nppes_provider_mi                 object
#  4   nppes_credentials                 object
#  5   nppes_provider_gender             object
#  6   nppes_entity_code                 object
#  7   nppes_provider_street1            object
#  8   nppes_provider_street2            object
#  9   nppes_provider_city               object
#  10  nppes_provider_zip                object
#  11  nppes_provider_state              object
#  12  nppes_provider_country            object
#  13  provider_type                     object
#  14  medicare_participation_indicator  object
#  15  place_of_service                  object
#  16  hcpcs_code                        object
#  17  hcpcs_description                 object
#  18  hcpcs_drug_indicator              object
#  19  line_srvc_cnt                     float64
#  20  bene_unique_cnt                   float64
#  21  bene_day_srvc_cnt                 float64
#  22  average_Medicare_allowed_amt      float64
#  23  average_submitted_chrg_amt        float64
#  24  average_Medicare_payment_amt      float64
#  25  average_Medicare_standard_amt     float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 1.8+ GB

# %%
data_df.drop(data_df[data_df['npi'] == 1].index, inplace = True)
data_df.drop(data_df[data_df['nppes_provider_country'] != "US"].index, inplace = True)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9315906 entries, 1 to 9316307
# Data columns (total 26 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_last_org_name      object
#  2   nppes_provider_first_name         object
#  3   nppes_provider_mi                 object
#  4   nppes_credentials                 object
#  5   nppes_provider_gender             object
#  6   nppes_entity_code                 object
#  7   nppes_provider_street1            object
#  8   nppes_provider_street2            object
#  9   nppes_provider_city               object
#  10  nppes_provider_zip                object
#  11  nppes_provider_state              object
#  12  nppes_provider_country            object
#  13  provider_type                     object
#  14  medicare_participation_indicator  object
#  15  place_of_service                  object
#  16  hcpcs_code                        object
#  17  hcpcs_description                 object
#  18  hcpcs_drug_indicator              object
#  19  line_srvc_cnt                     float64
#  20  bene_unique_cnt                   float64
#  21  bene_day_srvc_cnt                 float64
#  22  average_Medicare_allowed_amt      float64
#  23  average_submitted_chrg_amt        float64
#  24  average_Medicare_payment_amt      float64
#  25  average_Medicare_standard_amt     float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 1.9+ GB

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9315906 entries, 1 to 9316307
# Data columns (total 26 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_last_org_name      object
#  2   nppes_provider_first_name         object
#  3   nppes_provider_mi                 object
#  4   nppes_credentials                 object
#  5   nppes_provider_gender             object
#  6   nppes_entity_code                 object
#  7   nppes_provider_street1            object
#  8   nppes_provider_street2            object
#  9   nppes_provider_city               object
#  10  nppes_provider_zip                object
#  11  nppes_provider_state              object
#  12  nppes_provider_country            object
#  13  provider_type                     object
#  14  medicare_participation_indicator  object
#  15  place_of_service                  object
#  16  hcpcs_code                        object
#  17  hcpcs_description                 object
#  18  hcpcs_drug_indicator              object
#  19  line_srvc_cnt                     float64
#  20  bene_unique_cnt                   float64
#  21  bene_day_srvc_cnt                 float64
#  22  average_Medicare_allowed_amt      float64
#  23  average_submitted_chrg_amt        float64
#  24  average_Medicare_payment_amt      float64
#  25  average_Medicare_standard_amt     float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 1.9+ GB

# %%
data_df['nppes_provider_zip'] = data_df['nppes_provider_zip'].apply(str)
#data_df.info()
data_df['new_zip'] = data_df['nppes_provider_zip'].str[:5]
#data_df['facility'] = [1 if x == "F" else 0 for x in data_df['place_of_service']]
#data_df['outside'] = [1 if x == "O" else 0 for x in data_df['place_of_service']]
data_df['facility'] = data_df["bene_day_srvc_cnt"].where(data_df['place_of_service'] == "F", 0)
data_df['outside'] = data_df["bene_day_srvc_cnt"].where(data_df['place_of_service'] == "O", 0)

data_df['year'] = 2014


df_data_2014 = data_df.groupby(['nppes_provider_state', 'new_zip', 'year']).agg({'line_srvc_cnt': ['median'],
                                                                                                      'facility' : ['median'],
                                                                                                      'outside' : ['median']})
       
df_data_2014
# Out:
#                                   line_srvc_cnt facility outside
#                                          median   median  median
# nppes_provider_state new_zip year
# AA                   20307   2014          19.0     19.0     0.0
#                      28310   2014          22.5     22.0     0.0
#                      28547   2014          26.5     26.5     0.0
#                      31699   2014          53.5      0.0    35.5
#                      32925   2014          12.0     12.0     0.0
# ...                                         ...      ...     ...
# XX                   0       2014          13.0     13.0     0.0
#                      30506   2014          43.0      0.0    43.0
#                      33483   2014          32.0      0.0    32.0
#                      820     2014          24.5     24.5     0.0
#                      969     2014          43.0     43.0     0.0
#
# [27194 rows x 3 columns]

# %%
df_data_2014 = df_data_2014.reset_index()
df_data_2014.columns = ['state', 'zip_code', 'year', 'line_srcv_median', 'facility_median', 'outside_median']
df_data_2014
# Out:
#       state zip_code  year  line_srcv_median  facility_median  outside_median
# 0        AA    20307  2014              19.0             19.0             0.0
# 1        AA    28310  2014              22.5             22.0             0.0
# 2        AA    28547  2014              26.5             26.5             0.0
# 3        AA    31699  2014              53.5              0.0            35.5
# 4        AA    32925  2014              12.0             12.0             0.0
# ...     ...      ...   ...               ...              ...             ...
# 27189    XX        0  2014              13.0             13.0             0.0
# 27190    XX    30506  2014              43.0              0.0            43.0
# 27191    XX    33483  2014              32.0              0.0            32.0
# 27192    XX      820  2014              24.5             24.5             0.0
# 27193    XX      969  2014              43.0             43.0             0.0
#
# [27194 rows x 6 columns]

# %%
data_df_total = pd.concat([data_df_total, df_data_2014])
data_df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81188 entries, 0 to 27193
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             81188 non-null  object
#  1   zip_code          81188 non-null  object
#  2   year              81188 non-null  int64
#  3   line_srcv_median  81188 non-null  float64
#  4   facility_median   81188 non-null  float64
#  5   outside_median    81188 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 4.3+ MB

# %%
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2015),sep='\t', nrows=50000)
data_df = pd.read_csv(os.path.join("..", "Data", data_file2015),sep='\t')
# Drop the null rows
#data_df = data_df.dropna()
data_df.info()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9497892 entries, 0 to 9497891
# Data columns (total 26 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_last_org_name      object
#  2   nppes_provider_first_name         object
#  3   nppes_provider_mi                 object
#  4   nppes_credentials                 object
#  5   nppes_provider_gender             object
#  6   nppes_entity_code                 object
#  7   nppes_provider_street1            object
#  8   nppes_provider_street2            object
#  9   nppes_provider_city               object
#  10  nppes_provider_zip                object
#  11  nppes_provider_state              object
#  12  nppes_provider_country            object
#  13  provider_type                     object
#  14  medicare_participation_indicator  object
#  15  place_of_service                  object
#  16  hcpcs_code                        object
#  17  hcpcs_description                 object
#  18  hcpcs_drug_indicator              object
#  19  line_srvc_cnt                     float64
#  20  bene_unique_cnt                   float64
#  21  bene_day_srvc_cnt                 float64
#  22  average_Medicare_allowed_amt      float64
#  23  average_submitted_chrg_amt        float64
#  24  average_Medicare_payment_amt      float64
#  25  average_Medicare_standard_amt     float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 1.8+ GB

# %%
data_df.drop(data_df[data_df['npi'] == 1].index, inplace = True)
data_df.drop(data_df[data_df['nppes_provider_country'] != "US"].index, inplace = True)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9497376 entries, 1 to 9497891
# Data columns (total 26 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_last_org_name      object
#  2   nppes_provider_first_name         object
#  3   nppes_provider_mi                 object
#  4   nppes_credentials                 object
#  5   nppes_provider_gender             object
#  6   nppes_entity_code                 object
#  7   nppes_provider_street1            object
#  8   nppes_provider_street2            object
#  9   nppes_provider_city               object
#  10  nppes_provider_zip                object
#  11  nppes_provider_state              object
#  12  nppes_provider_country            object
#  13  provider_type                     object
#  14  medicare_participation_indicator  object
#  15  place_of_service                  object
#  16  hcpcs_code                        object
#  17  hcpcs_description                 object
#  18  hcpcs_drug_indicator              object
#  19  line_srvc_cnt                     float64
#  20  bene_unique_cnt                   float64
#  21  bene_day_srvc_cnt                 float64
#  22  average_Medicare_allowed_amt      float64
#  23  average_submitted_chrg_amt        float64
#  24  average_Medicare_payment_amt      float64
#  25  average_Medicare_standard_amt     float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 1.9+ GB

# %%
data_df['nppes_provider_zip'] = data_df['nppes_provider_zip'].apply(str)
#data_df.info()
data_df['new_zip'] = data_df['nppes_provider_zip'].str[:5]
#data_df['facility'] = [1 if x == "F" else 0 for x in data_df['place_of_service']]
#data_df['outside'] = [1 if x == "O" else 0 for x in data_df['place_of_service']]
data_df['facility'] = data_df["bene_day_srvc_cnt"].where(data_df['place_of_service'] == "F", 0)
data_df['outside'] = data_df["bene_day_srvc_cnt"].where(data_df['place_of_service'] == "O", 0)
data_df['year'] = 2015


df_data_2015 = data_df.groupby(['nppes_provider_state', 'new_zip', 'year']).agg({'line_srvc_cnt': ['median'],
                                                                                                      'facility' : ['median'],
                                                                                                      'outside' : ['median']})
       
df_data_2015
# Out:
#                                   line_srvc_cnt facility outside
#                                          median   median  median
# nppes_provider_state new_zip year
# AA                   20307   2015          12.0     12.0     0.0
#                      28310   2015          38.5     38.5     0.0
#                      28547   2015          30.0     30.0     0.0
#                      31699   2015          57.5      0.0    31.5
#                      37389   2015          22.0      0.0    22.0
# ...                                         ...      ...     ...
# XX                   77478   2015          63.0      0.0    17.0
#                      820     2015          55.0     55.0     0.0
#                      92024   2015          80.5      0.0    56.0
#                      969     2015          24.0     24.0     0.0
#                      99701   2015          38.0      0.0    38.0
#
# [27197 rows x 3 columns]

# %%
df_data_2015 = df_data_2015.reset_index()
df_data_2015.columns = ['state', 'zip_code', 'year', 'line_srcv_median', 'facility_median', 'outside_median']
df_data_2015
# Out:
#       state zip_code  year  line_srcv_median  facility_median  outside_median
# 0        AA    20307  2015              12.0             12.0             0.0
# 1        AA    28310  2015              38.5             38.5             0.0
# 2        AA    28547  2015              30.0             30.0             0.0
# 3        AA    31699  2015              57.5              0.0            31.5
# 4        AA    37389  2015              22.0              0.0            22.0
# ...     ...      ...   ...               ...              ...             ...
# 27192    XX    77478  2015              63.0              0.0            17.0
# 27193    XX      820  2015              55.0             55.0             0.0
# 27194    XX    92024  2015              80.5              0.0            56.0
# 27195    XX      969  2015              24.0             24.0             0.0
# 27196    XX    99701  2015              38.0              0.0            38.0
#
# [27197 rows x 6 columns]

# %%
data_df_total = pd.concat([data_df_total, df_data_2015])
data_df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108385 entries, 0 to 27196
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   state             108385 non-null  object
#  1   zip_code          108385 non-null  object
#  2   year              108385 non-null  int64
#  3   line_srcv_median  108385 non-null  float64
#  4   facility_median   108385 non-null  float64
#  5   outside_median    108385 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 5.8+ MB

# %%
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2016),sep='\t', nrows=50000)
data_df = pd.read_csv(os.path.join("..", "Data", data_file2016),sep='\t')
# Drop the null rows
#data_df = data_df.dropna()
data_df.info()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9714897 entries, 0 to 9714896
# Data columns (total 26 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   NPI                               int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      object
#  2   NPPES_PROVIDER_FIRST_NAME         object
#  3   NPPES_PROVIDER_MI                 object
#  4   NPPES_CREDENTIALS                 object
#  5   NPPES_PROVIDER_GENDER             object
#  6   NPPES_ENTITY_CODE                 object
#  7   NPPES_PROVIDER_STREET1            object
#  8   NPPES_PROVIDER_STREET2            object
#  9   NPPES_PROVIDER_CITY               object
#  10  NPPES_PROVIDER_ZIP                object
#  11  NPPES_PROVIDER_STATE              object
#  12  NPPES_PROVIDER_COUNTRY            object
#  13  PROVIDER_TYPE                     object
#  14  MEDICARE_PARTICIPATION_INDICATOR  object
#  15  PLACE_OF_SERVICE                  object
#  16  HCPCS_CODE                        object
#  17  HCPCS_DESCRIPTION                 object
#  18  HCPCS_DRUG_INDICATOR              object
#  19  LINE_SRVC_CNT                     float64
#  20  BENE_UNIQUE_CNT                   float64
#  21  BENE_DAY_SRVC_CNT                 float64
#  22  AVERAGE_MEDICARE_ALLOWED_AMT      float64
#  23  AVERAGE_SUBMITTED_CHRG_AMT        float64
#  24  AVERAGE_MEDICARE_PAYMENT_AMT      float64
#  25  AVERAGE_MEDICARE_STANDARD_AMT     float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 1.9+ GB

# %%
data_df.drop(data_df[data_df['NPI'] == 1].index, inplace = True)
data_df.drop(data_df[data_df['NPPES_PROVIDER_COUNTRY'] != "US"].index, inplace = True)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9714369 entries, 1 to 9714896
# Data columns (total 26 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   NPI                               int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      object
#  2   NPPES_PROVIDER_FIRST_NAME         object
#  3   NPPES_PROVIDER_MI                 object
#  4   NPPES_CREDENTIALS                 object
#  5   NPPES_PROVIDER_GENDER             object
#  6   NPPES_ENTITY_CODE                 object
#  7   NPPES_PROVIDER_STREET1            object
#  8   NPPES_PROVIDER_STREET2            object
#  9   NPPES_PROVIDER_CITY               object
#  10  NPPES_PROVIDER_ZIP                object
#  11  NPPES_PROVIDER_STATE              object
#  12  NPPES_PROVIDER_COUNTRY            object
#  13  PROVIDER_TYPE                     object
#  14  MEDICARE_PARTICIPATION_INDICATOR  object
#  15  PLACE_OF_SERVICE                  object
#  16  HCPCS_CODE                        object
#  17  HCPCS_DESCRIPTION                 object
#  18  HCPCS_DRUG_INDICATOR              object
#  19  LINE_SRVC_CNT                     float64
#  20  BENE_UNIQUE_CNT                   float64
#  21  BENE_DAY_SRVC_CNT                 float64
#  22  AVERAGE_MEDICARE_ALLOWED_AMT      float64
#  23  AVERAGE_SUBMITTED_CHRG_AMT        float64
#  24  AVERAGE_MEDICARE_PAYMENT_AMT      float64
#  25  AVERAGE_MEDICARE_STANDARD_AMT     float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 2.0+ GB

# %%
data_df['NPPES_PROVIDER_ZIP'] = data_df['NPPES_PROVIDER_ZIP'].apply(str)
#data_df.info()
data_df['new_zip'] = data_df['NPPES_PROVIDER_ZIP'].str[:5]
#data_df['facility'] = [1 if x == "F" else 0 for x in data_df['PLACE_OF_SERVICE']]
#data_df['outside'] = [1 if x == "O" else 0 for x in data_df['PLACE_OF_SERVICE']]
data_df['facility'] = data_df["BENE_DAY_SRVC_CNT"].where(data_df['PLACE_OF_SERVICE'] == "F", 0)
data_df['outside'] = data_df["BENE_DAY_SRVC_CNT"].where(data_df['PLACE_OF_SERVICE'] == "O", 0)
data_df['year'] = 2016


df_data_2016 = data_df.groupby(['NPPES_PROVIDER_STATE', 'new_zip', 'year']).agg({'LINE_SRVC_CNT': ['median'],
                                                                                                      'facility' : ['median'],
                                                                                                      'outside' : ['median']})
       
df_data_2016
# Out:
#                                   LINE_SRVC_CNT facility outside
#                                          median   median  median
# NPPES_PROVIDER_STATE new_zip year
# AA                   20307   2016          11.0     11.0     0.0
#                      28547   2016          50.5     50.5     0.0
#                      31699   2016          28.0      0.0    15.0
#                      37389   2016          22.0      0.0    22.0
#                      73503   2016          27.0     26.0     0.0
# ...                                         ...      ...     ...
# XX                   820     2016         187.0    187.0     0.0
#                      85013   2016         116.0      0.0   116.0
#                      92024   2016          67.0      0.0    60.0
#                      969     2016          27.0     27.0     0.0
#                      99701   2016          17.5      0.0    17.5
#
# [27472 rows x 3 columns]

# %%
df_data_2016 = df_data_2016.reset_index()
df_data_2016.columns = ['state', 'zip_code', 'year', 'line_srcv_median', 'facility_median', 'outside_median']
df_data_2016
# Out:
#       state zip_code  year  line_srcv_median  facility_median  outside_median
# 0        AA    20307  2016              11.0             11.0             0.0
# 1        AA    28547  2016              50.5             50.5             0.0
# 2        AA    31699  2016              28.0              0.0            15.0
# 3        AA    37389  2016              22.0              0.0            22.0
# 4        AA    73503  2016              27.0             26.0             0.0
# ...     ...      ...   ...               ...              ...             ...
# 27467    XX      820  2016             187.0            187.0             0.0
# 27468    XX    85013  2016             116.0              0.0           116.0
# 27469    XX    92024  2016              67.0              0.0            60.0
# 27470    XX      969  2016              27.0             27.0             0.0
# 27471    XX    99701  2016              17.5              0.0            17.5
#
# [27472 rows x 6 columns]

# %%
data_df_total = pd.concat([data_df_total, df_data_2016])
data_df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135857 entries, 0 to 27471
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   state             135857 non-null  object
#  1   zip_code          135857 non-null  object
#  2   year              135857 non-null  int64
#  3   line_srcv_median  135857 non-null  float64
#  4   facility_median   135857 non-null  float64
#  5   outside_median    135857 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 7.3+ MB

# %%
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2017),sep='\t', nrows=50000)
data_df = pd.read_csv(os.path.join("..", "Data", data_file2017),sep='\t')
# Drop the null rows
#data_df = data_df.dropna()
data_df.info()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9847444 entries, 0 to 9847443
# Data columns (total 26 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_last_org_name      object
#  2   nppes_provider_first_name         object
#  3   nppes_provider_mi                 object
#  4   nppes_credentials                 object
#  5   nppes_provider_gender             object
#  6   nppes_entity_code                 object
#  7   nppes_provider_street1            object
#  8   nppes_provider_street2            object
#  9   nppes_provider_city               object
#  10  nppes_provider_zip                object
#  11  nppes_provider_state              object
#  12  nppes_provider_country            object
#  13  provider_type                     object
#  14  medicare_participation_indicator  object
#  15  place_of_service                  object
#  16  hcpcs_code                        object
#  17  hcpcs_description                 object
#  18  hcpcs_drug_indicator              object
#  19  line_srvc_cnt                     float64
#  20  bene_unique_cnt                   float64
#  21  bene_day_srvc_cnt                 float64
#  22  average_Medicare_allowed_amt      float64
#  23  average_submitted_chrg_amt        float64
#  24  average_Medicare_payment_amt      float64
#  25  average_Medicare_standard_amt     float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 1.9+ GB

# %%
data_df.drop(data_df[data_df['npi'] == 1].index, inplace = True)
data_df.drop(data_df[data_df['nppes_provider_country'] != "US"].index, inplace = True)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9846847 entries, 1 to 9847443
# Data columns (total 26 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_last_org_name      object
#  2   nppes_provider_first_name         object
#  3   nppes_provider_mi                 object
#  4   nppes_credentials                 object
#  5   nppes_provider_gender             object
#  6   nppes_entity_code                 object
#  7   nppes_provider_street1            object
#  8   nppes_provider_street2            object
#  9   nppes_provider_city               object
#  10  nppes_provider_zip                object
#  11  nppes_provider_state              object
#  12  nppes_provider_country            object
#  13  provider_type                     object
#  14  medicare_participation_indicator  object
#  15  place_of_service                  object
#  16  hcpcs_code                        object
#  17  hcpcs_description                 object
#  18  hcpcs_drug_indicator              object
#  19  line_srvc_cnt                     float64
#  20  bene_unique_cnt                   float64
#  21  bene_day_srvc_cnt                 float64
#  22  average_Medicare_allowed_amt      float64
#  23  average_submitted_chrg_amt        float64
#  24  average_Medicare_payment_amt      float64
#  25  average_Medicare_standard_amt     float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 2.0+ GB

# %%
data_df['nppes_provider_zip'] = data_df['nppes_provider_zip'].apply(str)
#data_df.info()
data_df['new_zip'] = data_df['nppes_provider_zip'].str[:5]
#data_df['facility'] = [1 if x == "F" else 0 for x in data_df['place_of_service']]
#data_df['outside'] = [1 if x == "O" else 0 for x in data_df['place_of_service']]
data_df['facility'] = data_df["bene_day_srvc_cnt"].where(data_df['place_of_service'] == "F", 0)
data_df['outside'] = data_df["bene_day_srvc_cnt"].where(data_df['place_of_service'] == "O", 0)
data_df['year'] = 2017


df_data_2017 = data_df.groupby(['nppes_provider_state', 'new_zip', 'year']).agg({'line_srvc_cnt': ['median'],
                                                                                                      'facility' : ['median'],
                                                                                                      'outside' : ['median']})
       
df_data_2017
# Out:
#                                   line_srvc_cnt facility outside
#                                          median   median  median
# nppes_provider_state new_zip year
# AA                   28547   2017          91.0     91.0     0.0
#                      31699   2017          11.0      0.0    11.0
#                      37389   2017          21.0      0.0    17.0
#                      39530   2017          50.5     50.0     0.0
#                      73503   2017          34.0     34.0     0.0
# ...                                         ...      ...     ...
# XX                   77478   2017          82.5      0.0    39.0
#                      820     2017         118.0    118.0     0.0
#                      85013   2017          57.5      0.0    57.5
#                      92024   2017          66.0      0.0    66.0
#                      99701   2017          15.0      0.0    14.0
#
# [27423 rows x 3 columns]

# %%
df_data_2017 = df_data_2017.reset_index()
df_data_2017.columns = ['state', 'zip_code', 'year', 'line_srcv_median', 'facility_median', 'outside_median']
df_data_2017
# Out:
#       state zip_code  year  line_srcv_median  facility_median  outside_median
# 0        AA    28547  2017              91.0             91.0             0.0
# 1        AA    31699  2017              11.0              0.0            11.0
# 2        AA    37389  2017              21.0              0.0            17.0
# 3        AA    39530  2017              50.5             50.0             0.0
# 4        AA    73503  2017              34.0             34.0             0.0
# ...     ...      ...   ...               ...              ...             ...
# 27418    XX    77478  2017              82.5              0.0            39.0
# 27419    XX      820  2017             118.0            118.0             0.0
# 27420    XX    85013  2017              57.5              0.0            57.5
# 27421    XX    92024  2017              66.0              0.0            66.0
# 27422    XX    99701  2017              15.0              0.0            14.0
#
# [27423 rows x 6 columns]

# %%
data_df_total = pd.concat([data_df_total, df_data_2017])
data_df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163280 entries, 0 to 27422
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   state             163280 non-null  object
#  1   zip_code          163280 non-null  object
#  2   year              163280 non-null  int64
#  3   line_srcv_median  163280 non-null  float64
#  4   facility_median   163280 non-null  float64
#  5   outside_median    163280 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 8.7+ MB

# %%
data_df_total = data_df_total.fillna(0)
data_df_total
# Out:
#       state zip_code  year  line_srcv_median  facility_median  outside_median
# 0        AA    20307  2012              14.0             14.0             0.0
# 1        AA    28310  2012              14.0             14.0             0.0
# 2        AA    32925  2012              45.0             14.0             0.0
# 3        AA    73503  2012              30.0             27.0             0.0
# 4        AE    09550  2012              31.5             31.5             0.0
# ...     ...      ...   ...               ...              ...             ...
# 27418    XX    77478  2017              82.5              0.0            39.0
# 27419    XX      820  2017             118.0            118.0             0.0
# 27420    XX    85013  2017              57.5              0.0            57.5
# 27421    XX    92024  2017              66.0              0.0            66.0
# 27422    XX    99701  2017              15.0              0.0            14.0
#
# [163280 rows x 6 columns]

# %%
data_df_total = data_df_total.reset_index(drop = True)
data_df_total
# Out:
#        state zip_code  year  line_srcv_median  facility_median  outside_median
# 0         AA    20307  2012              14.0             14.0             0.0
# 1         AA    28310  2012              14.0             14.0             0.0
# 2         AA    32925  2012              45.0             14.0             0.0
# 3         AA    73503  2012              30.0             27.0             0.0
# 4         AE    09550  2012              31.5             31.5             0.0
# ...      ...      ...   ...               ...              ...             ...
# 163275    XX    77478  2017              82.5              0.0            39.0
# 163276    XX      820  2017             118.0            118.0             0.0
# 163277    XX    85013  2017              57.5              0.0            57.5
# 163278    XX    92024  2017              66.0              0.0            66.0
# 163279    XX    99701  2017              15.0              0.0            14.0
#
# [163280 rows x 6 columns]

# %%
#Sort output_data by year largest to smallest to match other file.
data_df_total = data_df_total.sort_values(["year", "state", "zip_code"],  ascending=[False, True, True])

# %%
updated_data_df = pd.read_csv(os.path.join("..", "Data", data_updated))
# Drop the null rows that are completely null.
updated_data_df = updated_data_df.dropna(axis='rows', how='all')

updated_data_df.info()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73850 entries, 0 to 73849
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LASTNAME    70693 non-null  object
#  1   FIRSTNAME   70694 non-null  object
#  2   MIDNAME     73850 non-null  object
#  3   BUSNAME     3154 non-null   object
#  4   GENERAL     73850 non-null  object
#  5   SPECIALTY   69677 non-null  object
#  6   UPIN        6259 non-null   object
#  7   NPI         73850 non-null  int64
#  8   DOB         69832 non-null  float64
#  9   ADDRESS     73841 non-null  object
#  10  CITY        73849 non-null  object
#  11  STATE       73845 non-null  object
#  12  ZIP         73850 non-null  int64
#  13  EXCLTYPE    73850 non-null  object
#  14  EXCLDATE    73850 non-null  int64
#  15  REINDATE    73850 non-null  int64
#  16  WAIVERDATE  73850 non-null  int64
#  17  WVRSTATE    14 non-null     object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 10.7+ MB

# %%
updated_df = updated_data_df.groupby(['STATE', 'ZIP']).agg({'EXCLTYPE': ['count']})
updated_df
# Out:
#             EXCLTYPE
#                count
# STATE ZIP
# AE    9110         1
# AK    35442        2
#       99501       18
#       99502       15
#       99503       20
# ...              ...
# XX    6050         1
#       7010         1
#       9096         1
#       9812         1
#       96950        1
#
# [17466 rows x 1 columns]

# %%
updated_df = updated_df.reset_index()
updated_df.columns = ['state', 'zip_code', 'leie_count']
updated_df['zip_code'] = updated_df['zip_code'].apply(str)
updated_df
# Out:
#       state zip_code  leie_count
# 0        AE     9110           1
# 1        AK    35442           2
# 2        AK    99501          18
# 3        AK    99502          15
# 4        AK    99503          20
# ...     ...      ...         ...
# 17461    XX     6050           1
# 17462    XX     7010           1
# 17463    XX     9096           1
# 17464    XX     9812           1
# 17465    XX    96950           1
#
# [17466 rows x 3 columns]

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17466 entries, 0 to 17465
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   state       17466 non-null  object
#  1   zip_code    17466 non-null  object
#  2   leie_count  17466 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 409.5+ KB

# %%
data_df_total_new = pd.merge(data_df_total, updated_df, how='left', on=['state','zip_code'])
data_df_total_new
# Out:
#        state zip_code  year  line_srcv_median  facility_median  \
# 0         AA    28547  2017              91.0             91.0
# 1         AA    31699  2017              11.0              0.0
# 2         AA    37389  2017              21.0              0.0
# 3         AA    39530  2017              50.5             50.0
# 4         AA    73503  2017              34.0             34.0
# ...      ...      ...   ...               ...              ...
# 163275    WY    83116  2012              91.0              0.0
# 163276    WY    83126  2012            1151.5              0.0
# 163277    WY    83127  2012              70.0              0.0
# 163278    WY    83128  2012              17.0              0.0
# 163279    XX    33483  2012              43.0              0.0
#
#         outside_median  leie_count
# 0                  0.0         NaN
# 1                 11.0         NaN
# 2                 17.0         NaN
# 3                  0.0         NaN
# 4                  0.0         NaN
# ...                ...         ...
# 163275            82.5         NaN
# 163276          1151.5         NaN
# 163277            54.5         NaN
# 163278            17.0         NaN
# 163279            43.0         NaN
#
# [163280 rows x 7 columns]

# %%
data_df_total_new = data_df_total_new.fillna(0)
data_df_total_new
# Out:
#        state zip_code  year  line_srcv_median  facility_median  \
# 0         AA    28547  2017              91.0             91.0
# 1         AA    31699  2017              11.0              0.0
# 2         AA    37389  2017              21.0              0.0
# 3         AA    39530  2017              50.5             50.0
# 4         AA    73503  2017              34.0             34.0
# ...      ...      ...   ...               ...              ...
# 163275    WY    83116  2012              91.0              0.0
# 163276    WY    83126  2012            1151.5              0.0
# 163277    WY    83127  2012              70.0              0.0
# 163278    WY    83128  2012              17.0              0.0
# 163279    XX    33483  2012              43.0              0.0
#
#         outside_median  leie_count
# 0                  0.0         0.0
# 1                 11.0         0.0
# 2                 17.0         0.0
# 3                  0.0         0.0
# 4                  0.0         0.0
# ...                ...         ...
# 163275            82.5         0.0
# 163276          1151.5         0.0
# 163277            54.5         0.0
# 163278            17.0         0.0
# 163279            43.0         0.0
#
# [163280 rows x 7 columns]

# %%
output_data_file = "output_data_state_zip_year.csv"
data_df_total_new.to_csv(os.path.join("..", "Data", output_data_file), index= False, sep=',')
