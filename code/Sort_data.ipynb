# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
input_data_file = "output_data_npi.txt"
df = pd.read_csv(os.path.join("..", "Data", input_data_file),sep='\t')
#df = pd.read_csv(os.path.join("..", "Data", input_data_file),sep='\t', nrows=5000000)

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
#df = df.dropna()
df.head()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           npi nppes_provider_gender nppes_entity_code nppes_provider_city  \
# 0           1                   NaN               NaN                 NaN
# 1  1003000126                     M                 I          CUMBERLAND
# 2  1003000126                     M                 I          CUMBERLAND
# 3  1003000126                     M                 I          CUMBERLAND
# 4  1003000126                     M                 I          CUMBERLAND
#
#   nppes_provider_zip nppes_provider_state nppes_provider_country  \
# 0                NaN                  NaN                    NaN
# 1        2.15022e+08                   MD                     US
# 2        2.15022e+08                   MD                     US
# 3        2.15022e+08                   MD                     US
# 4        2.15022e+08                   MD                     US
#
#        provider_type medicare_participation_indicator place_of_service  ...  \
# 0                NaN                              NaN              NaN  ...
# 1  Internal Medicine                                Y                F  ...
# 2  Internal Medicine                                Y                F  ...
# 3  Internal Medicine                                Y                F  ...
# 4  Internal Medicine                                Y                F  ...
#
#   hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt  bene_day_srvc_cnt  \
# 0                  NaN           NaN             NaN                NaN
# 1                    N         115.0           112.0              115.0
# 2                    N          93.0            88.0               93.0
# 3                    N         111.0            83.0              111.0
# 4                    N         544.0           295.0              544.0
#
#    average_Medicare_allowed_amt  average_submitted_chrg_amt  \
# 0                           NaN                         NaN
# 1                        135.25                       199.0
# 2                        198.59                       291.0
# 3                         38.75                        58.0
# 4                         70.95                       105.0
#
#    average_Medicare_payment_amt  year  leie_code  leie
# 0                           NaN  2012       None   Not
# 1                    108.115652  2012       None   Not
# 2                    158.870000  2012       None   Not
# 3                     30.720721  2012       None   Not
# 4                     56.655662  2012       None   Not
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56819227 entries, 0 to 56819226
# Data columns (total 22 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_gender             object
#  2   nppes_entity_code                 object
#  3   nppes_provider_city               object
#  4   nppes_provider_zip                object
#  5   nppes_provider_state              object
#  6   nppes_provider_country            object
#  7   provider_type                     object
#  8   medicare_participation_indicator  object
#  9   place_of_service                  object
#  10  hcpcs_code                        object
#  11  hcpcs_description                 object
#  12  hcpcs_drug_indicator              object
#  13  line_srvc_cnt                     float64
#  14  bene_unique_cnt                   float64
#  15  bene_day_srvc_cnt                 float64
#  16  average_Medicare_allowed_amt      float64
#  17  average_submitted_chrg_amt        float64
#  18  average_Medicare_payment_amt      float64
#  19  year                              int64
#  20  leie_code                         object
#  21  leie                              object
# dtypes: float64(6), int64(2), object(14)
# memory usage: 9.3+ GB

# %%
#df

# %%
df = df.sort_values("leie", ascending=False)

# %%
#df

# %%
output_data_file = "sort_data.txt"
df.to_csv(os.path.join("..", "Data", output_data_file), index= False, sep='\t')

# %%
df
# Out:
#                  npi nppes_provider_gender nppes_entity_code  \
# 1917454   1205963402                     M                 I
# 51530849  1467447557                     M                 I
# 27355039  1952417610                     M                 I
# 51530837  1467447557                     M                 I
# 51530838  1467447557                     M                 I
# ...              ...                   ...               ...
# 18957545  1053396929                     M                 I
# 18957546  1053396929                     M                 I
# 18957547  1053396929                     M                 I
# 18957548  1053396929                     M                 I
# 56819226  1992999874                     F                 I
#
#          nppes_provider_city nppes_provider_zip nppes_provider_state  \
# 1917454            ROCKVILLE          208521246                   MD
# 51530849               FLINT          485325497                   MI
# 27355039             HOUSTON          770812706                   TX
# 51530837               FLINT          485325497                   MI
# 51530838               FLINT          485325497                   MI
# ...                      ...                ...                  ...
# 18957545          HACKENSACK           76011914                   NJ
# 18957546          HACKENSACK           76011914                   NJ
# 18957547          HACKENSACK           76011914                   NJ
# 18957548          HACKENSACK           76011914                   NJ
# 56819226      MECHANICSVILLE          231161844                   VA
#
#          nppes_provider_country         provider_type  \
# 1917454                      US    Allergy/Immunology
# 51530849                     US       Family Practice
# 27355039                     US             Neurology
# 51530837                     US       Family Practice
# 51530838                     US       Family Practice
# ...                         ...                   ...
# 18957545                     US  Diagnostic Radiology
# 18957546                     US  Diagnostic Radiology
# 18957547                     US  Diagnostic Radiology
# 18957548                     US  Diagnostic Radiology
# 56819226                     US     Internal Medicine
#
#          medicare_participation_indicator place_of_service  ...  \
# 1917454                                 Y                O  ...
# 51530849                                Y                O  ...
# 27355039                                Y                O  ...
# 51530837                                Y                O  ...
# 51530838                                Y                O  ...
# ...                                   ...              ...  ...
# 18957545                                Y                F  ...
# 18957546                                Y                F  ...
# 18957547                                Y                F  ...
# 18957548                                Y                O  ...
# 56819226                                Y                F  ...
#
#          hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt  \
# 1917454                     N         153.0            13.0
# 51530849                    N          93.0            65.0
# 27355039                    N          36.0            35.0
# 51530837                    N         724.0           210.0
# 51530838                    N          11.0            11.0
# ...                       ...           ...             ...
# 18957545                    N          11.0            11.0
# 18957546                    N          15.0            13.0
# 18957547                    N          33.0            32.0
# 18957548                    N          46.0            44.0
# 56819226                    N          49.0            49.0
#
#           bene_day_srvc_cnt  average_Medicare_allowed_amt  \
# 1917454               153.0                     11.800000
# 51530849               93.0                    129.454731
# 27355039               36.0                     40.992778
# 51530837              724.0                     48.580000
# 51530838               11.0                     25.000000
# ...                     ...                           ...
# 18957545               11.0                     40.180000
# 18957546               15.0                     53.290000
# 18957547               33.0                     46.360000
# 18957548               46.0                    299.020000
# 56819226               49.0                    107.980000
#
#           average_submitted_chrg_amt  average_Medicare_payment_amt  year  \
# 1917454                    25.000000                      7.897516  2012
# 51530849                  209.408602                     97.705054  2017
# 27355039                   50.123611                     25.856944  2014
# 51530837                  150.000000                     47.610000  2017
# 51530838                   25.000000                      6.985455  2017
# ...                              ...                           ...   ...
# 18957545                   75.000000                     31.500000  2014
# 18957546                  160.000000                     41.780000  2014
# 18957547                  151.000000                     36.350000  2014
# 18957548                  525.000000                    230.607391  2014
# 56819226                  262.000000                    123.950000  2017
#
#           leie_code     leie
# 1917454      1128b4  On_List
# 51530849     1128a1  On_List
# 27355039     1128a1  On_List
# 51530837     1128a1  On_List
# 51530838     1128a1  On_List
# ...             ...      ...
# 18957545       None      Not
# 18957546       None      Not
# 18957547       None      Not
# 18957548       None      Not
# 56819226       None      Not
#
# [56819227 rows x 22 columns]
