# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
hcpsc_key_file = "top_ten_list.csv"
top10_df = pd.read_csv(os.path.join("..", "Data", hcpsc_key_file),sep=',')
top10_df
# Out:
#   Occurance_top_10 Line_Service_top_10
# 0            99213               P9603
# 1            99214               A0425
# 2            99204               99213
# 3            99203               99214
# 4            99212               J1071
# 5            93000               J0585
# 6            36415               36415
# 7            99215               95004
# 8            96372               Q0138
# 9            G0008               G0471

# %%
input_data_file = "sort_data.txt"
df = pd.read_csv(os.path.join("..", "Data", input_data_file),sep='\t')
#df = pd.read_csv(os.path.join("..", "Data", input_data_file),sep='\t', nrows=50000)

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
#df = df.dropna()
df
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  npi nppes_provider_gender nppes_entity_code  \
# 0         1205963402                     M                 I
# 1         1467447557                     M                 I
# 2         1952417610                     M                 I
# 3         1467447557                     M                 I
# 4         1467447557                     M                 I
# ...              ...                   ...               ...
# 56819222  1053396929                     M                 I
# 56819223  1053396929                     M                 I
# 56819224  1053396929                     M                 I
# 56819225  1053396929                     M                 I
# 56819226  1992999874                     F                 I
#
#          nppes_provider_city nppes_provider_zip nppes_provider_state  \
# 0                  ROCKVILLE        2.08521e+08                   MD
# 1                      FLINT        4.85325e+08                   MI
# 2                    HOUSTON        7.70813e+08                   TX
# 3                      FLINT        4.85325e+08                   MI
# 4                      FLINT        4.85325e+08                   MI
# ...                      ...                ...                  ...
# 56819222          HACKENSACK           76011914                   NJ
# 56819223          HACKENSACK           76011914                   NJ
# 56819224          HACKENSACK           76011914                   NJ
# 56819225          HACKENSACK           76011914                   NJ
# 56819226      MECHANICSVILLE          231161844                   VA
#
#          nppes_provider_country         provider_type  \
# 0                            US    Allergy/Immunology
# 1                            US       Family Practice
# 2                            US             Neurology
# 3                            US       Family Practice
# 4                            US       Family Practice
# ...                         ...                   ...
# 56819222                     US  Diagnostic Radiology
# 56819223                     US  Diagnostic Radiology
# 56819224                     US  Diagnostic Radiology
# 56819225                     US  Diagnostic Radiology
# 56819226                     US     Internal Medicine
#
#          medicare_participation_indicator place_of_service  ...  \
# 0                                       Y                O  ...
# 1                                       Y                O  ...
# 2                                       Y                O  ...
# 3                                       Y                O  ...
# 4                                       Y                O  ...
# ...                                   ...              ...  ...
# 56819222                                Y                F  ...
# 56819223                                Y                F  ...
# 56819224                                Y                F  ...
# 56819225                                Y                O  ...
# 56819226                                Y                F  ...
#
#          hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt  \
# 0                           N         153.0            13.0
# 1                           N          93.0            65.0
# 2                           N          36.0            35.0
# 3                           N         724.0           210.0
# 4                           N          11.0            11.0
# ...                       ...           ...             ...
# 56819222                    N          11.0            11.0
# 56819223                    N          15.0            13.0
# 56819224                    N          33.0            32.0
# 56819225                    N          46.0            44.0
# 56819226                    N          49.0            49.0
#
#           bene_day_srvc_cnt  average_Medicare_allowed_amt  \
# 0                     153.0                     11.800000
# 1                      93.0                    129.454731
# 2                      36.0                     40.992778
# 3                     724.0                     48.580000
# 4                      11.0                     25.000000
# ...                     ...                           ...
# 56819222               11.0                     40.180000
# 56819223               15.0                     53.290000
# 56819224               33.0                     46.360000
# 56819225               46.0                    299.020000
# 56819226               49.0                    107.980000
#
#           average_submitted_chrg_amt  average_Medicare_payment_amt  year  \
# 0                          25.000000                      7.897516  2012
# 1                         209.408602                     97.705054  2017
# 2                          50.123611                     25.856944  2014
# 3                         150.000000                     47.610000  2017
# 4                          25.000000                      6.985455  2017
# ...                              ...                           ...   ...
# 56819222                   75.000000                     31.500000  2014
# 56819223                  160.000000                     41.780000  2014
# 56819224                  151.000000                     36.350000  2014
# 56819225                  525.000000                    230.607391  2014
# 56819226                  262.000000                    123.950000  2017
#
#           leie_code     leie
# 0            1128b4  On_List
# 1            1128a1  On_List
# 2            1128a1  On_List
# 3            1128a1  On_List
# 4            1128a1  On_List
# ...             ...      ...
# 56819222       None      Not
# 56819223       None      Not
# 56819224       None      Not
# 56819225       None      Not
# 56819226       None      Not
#
# [56819227 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56819227 entries, 0 to 56819226
# Data columns (total 22 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_gender             object
#  2   nppes_entity_code                 object
#  3   nppes_provider_city               object
#  4   nppes_provider_zip                object
#  5   nppes_provider_state              object
#  6   nppes_provider_country            object
#  7   provider_type                     object
#  8   medicare_participation_indicator  object
#  9   place_of_service                  object
#  10  hcpcs_code                        object
#  11  hcpcs_description                 object
#  12  hcpcs_drug_indicator              object
#  13  line_srvc_cnt                     float64
#  14  bene_unique_cnt                   float64
#  15  bene_day_srvc_cnt                 float64
#  16  average_Medicare_allowed_amt      float64
#  17  average_submitted_chrg_amt        float64
#  18  average_Medicare_payment_amt      float64
#  19  year                              int64
#  20  leie_code                         object
#  21  leie                              object
# dtypes: float64(6), int64(2), object(14)
# memory usage: 9.3+ GB

# %%
#new_df = df.loc[(df["leie"] == "On_List"), :]
#df = df.sort_values("leie", ascending=False)

# %%
top10_df.rename(columns={"Line_Service_top_10": "hcpcs_code"}, inplace = True)
del top10_df['Occurance_top_10']
top10_df
# Out:
#   hcpcs_code
# 0      P9603
# 1      A0425
# 2      99213
# 3      99214
# 4      J1071
# 5      J0585
# 6      36415
# 7      95004
# 8      Q0138
# 9      G0471

# %%
new_df = pd.merge(df, top10_df, how='inner', on='hcpcs_code')

# %%
new_df
# Out:
#                 npi nppes_provider_gender nppes_entity_code  \
# 0        1437152196                     F                 I
# 1        1790785277                     M                 I
# 2        1952417610                     M                 I
# 3        1376537977                     M                 I
# 4        1043319866                     M                 I
# ...             ...                   ...               ...
# 5625893  1063564714                   NaN                 O
# 5625894  1053314146                   NaN                 O
# 5625895  1053314401                     M                 I
# 5625896  1053343442                   NaN                 O
# 5625897  1043565021                   NaN                 O
#
#         nppes_provider_city nppes_provider_zip nppes_provider_state  \
# 0                     MIAMI        3.31665e+08                   FL
# 1             OCEAN SPRINGS        3.95646e+08                   MS
# 2                   HOUSTON        7.70813e+08                   TX
# 3                 DYERSBURG        3.80242e+08                   TN
# 4                   SALINAS        9.39014e+08                   CA
# ...                     ...                ...                  ...
# 5625893            SANDWICH               2563                   MA
# 5625894                NOVI          483751849                   MI
# 5625895            BEAUMONT          777014683                   TX
# 5625896           MILWAUKEE          532154526                   WI
# 5625897        MOUNT LAUREL           80544638                   NJ
#
#         nppes_provider_country        provider_type  \
# 0                           US             Podiatry
# 1                           US     Gastroenterology
# 2                           US            Neurology
# 3                           US      Family Practice
# 4                           US           Cardiology
# ...                        ...                  ...
# 5625893                     US  Clinical Laboratory
# 5625894                     US  Clinical Laboratory
# 5625895                     US    Internal Medicine
# 5625896                     US  Clinical Laboratory
# 5625897                     US  Clinical Laboratory
#
#         medicare_participation_indicator place_of_service  ...  \
# 0                                      Y                O  ...
# 1                                      Y                O  ...
# 2                                      Y                O  ...
# 3                                      Y                O  ...
# 4                                      Y                O  ...
# ...                                  ...              ...  ...
# 5625893                                Y                O  ...
# 5625894                                Y                F  ...
# 5625895                                Y                O  ...
# 5625896                                Y                O  ...
# 5625897                                Y                O  ...
#
#         hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt  bene_day_srvc_cnt  \
# 0                          N          91.0            54.0               91.0
# 1                          N         511.0           326.0              511.0
# 2                          N         309.0           282.0              309.0
# 3                          N          63.0            41.0               63.0
# 4                          N         286.0           232.0              286.0
# ...                      ...           ...             ...                ...
# 5625893                    N       19661.4           302.0              713.0
# 5625894                    N        1179.0           188.0             1179.0
# 5625895                    N       72053.0           191.0             1727.0
# 5625896                    N       23144.0           678.0             3014.0
# 5625897                    N        4268.6           133.0              224.0
#
#          average_Medicare_allowed_amt  average_submitted_chrg_amt  \
# 0                           75.910000                   76.680000
# 1                           64.546360                   80.000000
# 2                           72.852136                  114.499191
# 3                           65.750000                   87.000000
# 4                           75.870455                   77.492832
# ...                               ...                         ...
# 5625893                      1.010007                    1.062944
# 5625894                      1.015844                    6.371391
# 5625895                      0.073811                    0.075894
# 5625896                      0.949945                    0.950060
# 5625897                      1.007101                    1.027508
#
#          average_Medicare_payment_amt  year  leie_code     leie
# 0                           60.730000  2012     1128a1  On_List
# 1                           46.697789  2012     1128a4  On_List
# 2                           55.423883  2014     1128a1  On_List
# 3                           29.795238  2012     1128b4  On_List
# 4                           52.149476  2014     1128a2  On_List
# ...                               ...   ...        ...      ...
# 5625893                      0.989832  2014       None      Not
# 5625894                      0.995827  2014       None      Not
# 5625895                      0.072338  2014       None      Not
# 5625896                      0.930979  2014       None      Not
# 5625897                      0.986954  2014       None      Not
#
# [5625898 rows x 22 columns]

# %%
output_data_file = "top_ten_line_cnt.txt"
new_df.to_csv(os.path.join("..", "Data", output_data_file), index= False, sep='\t')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5625898 entries, 0 to 5625897
# Data columns (total 22 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   npi                               int64
#  1   nppes_provider_gender             object
#  2   nppes_entity_code                 object
#  3   nppes_provider_city               object
#  4   nppes_provider_zip                object
#  5   nppes_provider_state              object
#  6   nppes_provider_country            object
#  7   provider_type                     object
#  8   medicare_participation_indicator  object
#  9   place_of_service                  object
#  10  hcpcs_code                        object
#  11  hcpcs_description                 object
#  12  hcpcs_drug_indicator              object
#  13  line_srvc_cnt                     float64
#  14  bene_unique_cnt                   float64
#  15  bene_day_srvc_cnt                 float64
#  16  average_Medicare_allowed_amt      float64
#  17  average_submitted_chrg_amt        float64
#  18  average_Medicare_payment_amt      float64
#  19  year                              int64
#  20  leie_code                         object
#  21  leie                              object
# dtypes: float64(6), int64(2), object(14)
# memory usage: 987.2+ MB
