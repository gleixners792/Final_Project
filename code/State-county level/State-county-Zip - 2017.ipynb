# %%
# Dependencies

import pandas as pd
import numpy as np

# %%
# Read data file and store into pandas data frame.

df = pd.read_csv("2017/Medicare_Provider_Util_Payment_PUF_CY2017/Medicare_Provider_Util_Payment_PUF_CY2017.txt", sep="\t", header=0)
# Out:
# /Users/diegogonzalez/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Check data

df.dtypes
# Out:
# npi                                   int64
# nppes_provider_last_org_name         object
# nppes_provider_first_name            object
# nppes_provider_mi                    object
# nppes_credentials                    object
# nppes_provider_gender                object
# nppes_entity_code                    object
# nppes_provider_street1               object
# nppes_provider_street2               object
# nppes_provider_city                  object
# nppes_provider_zip                   object
# nppes_provider_state                 object
# nppes_provider_country               object
# provider_type                        object
# medicare_participation_indicator     object
# place_of_service                     object
# hcpcs_code                           object
# hcpcs_description                    object
# hcpcs_drug_indicator                 object
# line_srvc_cnt                       float64
# bene_unique_cnt                     float64
# ...

# %%
# Check Data

len(df)
# Out:
# 9847444

# %%
# Select only US

df1= df[df.nppes_provider_country == 'US']
df1
# Out:
#                 npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1        1003000126                    ENKESHAFI                   ARDALAN
# 2        1003000126                    ENKESHAFI                   ARDALAN
# 3        1003000126                    ENKESHAFI                   ARDALAN
# 4        1003000126                    ENKESHAFI                   ARDALAN
# 5        1003000126                    ENKESHAFI                   ARDALAN
# ...             ...                          ...                       ...
# 9847439  1992999825                    DESCHENES                  GEOFFREY
# 9847440  1992999874                        JOFFE                 GABRIELLA
# 9847441  1992999874                        JOFFE                 GABRIELLA
# 9847442  1992999874                        JOFFE                 GABRIELLA
# 9847443  1992999874                        JOFFE                 GABRIELLA
#
#         nppes_provider_mi nppes_credentials nppes_provider_gender  \
# ...

# %%
# Create ZIP Column

df1['ZIP'] = df1['nppes_provider_zip']
df1.head(5)
# Out:
# <ipython-input-6-83d5433f6691>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ZIP'] = df1['nppes_provider_zip']
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 1               NaN              M.D.                     M                 I
# ...

# %%
# Check Data

df1.dtypes
# Out:
# npi                                   int64
# nppes_provider_last_org_name         object
# nppes_provider_first_name            object
# nppes_provider_mi                    object
# nppes_credentials                    object
# nppes_provider_gender                object
# nppes_entity_code                    object
# nppes_provider_street1               object
# nppes_provider_street2               object
# nppes_provider_city                  object
# nppes_provider_zip                   object
# nppes_provider_state                 object
# nppes_provider_country               object
# provider_type                        object
# medicare_participation_indicator     object
# place_of_service                     object
# hcpcs_code                           object
# hcpcs_description                    object
# hcpcs_drug_indicator                 object
# line_srvc_cnt                       float64
# bene_unique_cnt                     float64
# ...

# %%
# Check unique ZIPs

df1['ZIP'].unique
# Out:
# <bound method Series.unique of 1          2.15022e+08
# 2          2.15022e+08
# 3          2.15022e+08
# 4          2.15022e+08
# 5          2.15022e+08
#               ...
# 9847439      981012756
# 9847440      231161844
# 9847441      231161844
# 9847442      231161844
# 9847443      231161844
# Name: ZIP, Length: 9846847, dtype: object>

# %%
# Create new dataframe with selected columns

df2 = df1[['ZIP','nppes_provider_state', 'npi', 'place_of_service','provider_type', 'hcpcs_code', 'hcpcs_drug_indicator', 'average_submitted_chrg_amt', 'average_Medicare_payment_amt']]
df2.tail(50)
# Out:
#                ZIP nppes_provider_state         npi place_of_service  \
# 9847394  334872768                   FL  1992999122                F
# 9847395  334872768                   FL  1992999122                O
# 9847396  334872768                   FL  1992999122                O
# 9847397  334872768                   FL  1992999122                O
# 9847398  334872768                   FL  1992999122                O
# 9847399  334872768                   FL  1992999122                O
# 9847400  334872768                   FL  1992999122                O
# 9847401  333162510                   FL  1992999437                F
# 9847402  333162510                   FL  1992999437                F
# 9847403  333162510                   FL  1992999437                F
# 9847404      44839                   OH  1992999452                O
# 9847405  920254402                   CA  1992999551                O
# 9847406  920254402                   CA  1992999551                O
# ...

# %%
# Check New dataframe

df2.dtypes
# Out:
# ZIP                              object
# nppes_provider_state             object
# npi                               int64
# place_of_service                 object
# provider_type                    object
# hcpcs_code                       object
# hcpcs_drug_indicator             object
# average_submitted_chrg_amt      float64
# average_Medicare_payment_amt    float64
# dtype: object

# %%
# Create states list to then exclude US territories

states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
df2 = df2[df2['nppes_provider_state'].isin(states)]
df2
# Out:
#                  ZIP nppes_provider_state         npi place_of_service  \
# 1        2.15022e+08                   MD  1003000126                F
# 2        2.15022e+08                   MD  1003000126                F
# 3        2.15022e+08                   MD  1003000126                F
# 4        2.15022e+08                   MD  1003000126                F
# 5        2.15022e+08                   MD  1003000126                F
# ...              ...                  ...         ...              ...
# 9847439    981012756                   WA  1992999825                O
# 9847440    231161844                   VA  1992999874                F
# 9847441    231161844                   VA  1992999874                F
# 9847442    231161844                   VA  1992999874                F
# 9847443    231161844                   VA  1992999874                F
#
#              provider_type hcpcs_code hcpcs_drug_indicator  \
# ...

# %%
# Clean and sort ZIP codes for merging

df2['ZIP'] = df2['ZIP'].astype(str).str[0:5].map(lambda x: str(x.replace('.','')))
df2['ZIP'] = df2['ZIP'].astype(int)
df2 = df2.dropna()
df2.sort_values(by=['ZIP'], inplace=True)
df2
# Out:
#            ZIP nppes_provider_state         npi place_of_service  \
# 1090562      0                   MA  1114060506                F
# 1090567      0                   MA  1114060506                F
# 1090566      0                   MA  1114060506                F
# 1090565      0                   MA  1114060506                F
# 1090564      0                   MA  1114060506                F
# ...        ...                  ...         ...              ...
# 4294412  99929                   AK  1437252566                O
# 4294411  99929                   AK  1437252566                O
# 4294409  99929                   AK  1437252566                O
# 4294407  99929                   AK  1437252566                O
# 8951100  99929                   AK  1902921653                F
#
#                       provider_type hcpcs_code hcpcs_drug_indicator  \
# 1090562          Emergency Medicine      93010                    N
# ...

# %%
# Check data

len(df2)
# Out:
# 9817212

# %%
# Check data

df2.dtypes
# Out:
# ZIP                               int64
# nppes_provider_state             object
# npi                               int64
# place_of_service                 object
# provider_type                    object
# hcpcs_code                       object
# hcpcs_drug_indicator             object
# average_submitted_chrg_amt      float64
# average_Medicare_payment_amt    float64
# dtype: object

# %%
# Read ZIP data file and store into pandas data frame

df3 = pd.read_csv('../Final_project_BigData/ZIP-COUNTY-FIPS.csv') 
df3.dtypes
# Out:
# ZIP            int64
# COUNTYNAME    object
# STATE         object
# STCOUNTYFP     int64
# CLASSFP       object
# dtype: object

# %%
# Check data

len(df3)
# Out:
# 52889

# %%
# Create states list to then exclude US territories

df3 = df3[df3['STATE'].isin(states)]
df3
# Out:
#          ZIP      COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0      36003  Autauga County    AL        1001      H1
# 1      36006  Autauga County    AL        1001      H1
# 2      36067  Autauga County    AL        1001      H1
# 3      36066  Autauga County    AL        1001      H1
# 4      36703  Autauga County    AL        1001      H1
# ...      ...             ...   ...         ...     ...
# 52566  82729   Weston County    WY       56045      H1
# 52567  82730   Weston County    WY       56045      H1
# 52568  82701   Weston County    WY       56045      H1
# 52569  82723   Weston County    WY       56045      H1
# 52570  82715   Weston County    WY       56045      H1
#
# [52571 rows x 5 columns]

# %%
# Select column for the merge

df3 = df3[['ZIP','COUNTYNAME']]
df3.sort_values(by=['ZIP'], inplace=True)
df3
# Out:
# <ipython-input-18-9fb1020b0784>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.sort_values(by=['ZIP'], inplace=True)
#          ZIP                         COUNTYNAME
# 32368    501                     Suffolk County
# 20964   1001                     Hampden County
# 20940   1002                    Franklin County
# 21018   1002                   Hampshire County
# 21028   1003                   Hampshire County
# ...      ...                                ...
# 1300   99925  Prince of Wales-Hyder Census Area
# 1296   99926  Prince of Wales-Hyder Census Area
# 1295   99927  Prince of Wales-Hyder Census Area
# 1227   99928          Ketchikan Gateway Borough
# 1333   99929          Wrangell City and Borough
#
# [52571 rows x 2 columns]

# %%
# Check data

df3.dtypes
# Out:
# ZIP            int64
# COUNTYNAME    object
# dtype: object

# %%
# Merge dataframes by Zipcode

dfinal= pd.merge_asof(df2, df3, on='ZIP')

# %%
# Sort Data by NPI number

dfinal.sort_values(by=['npi'], inplace=True)
dfinal.head(100)
# Out:
#            ZIP nppes_provider_state         npi place_of_service  \
# 1657723  21502                   MD  1003000126                F
# 1658028  21502                   MD  1003000126                F
# 1657938  21502                   MD  1003000126                F
# 1657939  21502                   MD  1003000126                F
# 1658710  21502                   MD  1003000126                F
# ...        ...                  ...         ...              ...
# 1170274  18951                   PA  1003000530                O
# 1170267  18951                   PA  1003000530                O
# 1170396  18951                   PA  1003000530                O
# 1170418  18951                   PA  1003000530                O
# 1170404  18951                   PA  1003000530                O
#
#              provider_type hcpcs_code hcpcs_drug_indicator  \
# 1657723  Internal Medicine      99218                    N
# 1658028  Internal Medicine      99291                    N
# ...

# %%
# Check data

len(dfinal)
# Out:
# 9817212

# %%
# Create Dataframe 

df_2017 = dfinal.groupby(['nppes_provider_state', 'COUNTYNAME', 'ZIP', 'provider_type', 'place_of_service']).agg({'average_submitted_chrg_amt': ['mean'], 'average_Medicare_payment_amt': ['mean']})
df_2017.columns = ['Avg Submit 2017', 'Avg Payment 2017']
df_2017 = df_2017.reset_index()

df_2017.head()
# Out:
#   nppes_provider_state                  COUNTYNAME    ZIP  \
# 0                   AK      Aleutians East Borough  99571
# 1                   AK      Aleutians East Borough  99612
# 2                   AK      Aleutians East Borough  99612
# 3                   AK  Aleutians West Census Area  99660
# 4                   AK  Aleutians West Census Area  99685
#
#          provider_type place_of_service  Avg Submit 2017  Avg Payment 2017
# 0  Physician Assistant                O       152.672727         38.538189
# 1   Nurse Practitioner                O       126.895299         46.545576
# 2  Physician Assistant                F       772.062500         58.700309
# 3  Physician Assistant                O        96.193971         41.308062
# 4   Nurse Practitioner                O       312.035088         59.408287

# %%
# Check data

len(df_2017)
# Out:
# 352258

# %%
# Save dataframe as CSV

df_2017.to_csv('2017.csv')
