# %%
# Dependencies

import pandas as pd
import numpy as np

# %%
# Read data file and store into pandas data frame.

df = pd.read_csv("2014/Medicare_Provider_Util_Payment_PUF_CY2014/Medicare_Provider_Util_Payment_PUF_CY2014.txt", sep="\t", header=0)
# Out:
# /Users/diegogonzalez/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Check data

df.dtypes
# Out:
# npi                                   int64
# nppes_provider_last_org_name         object
# nppes_provider_first_name            object
# nppes_provider_mi                    object
# nppes_credentials                    object
# nppes_provider_gender                object
# nppes_entity_code                    object
# nppes_provider_street1               object
# nppes_provider_street2               object
# nppes_provider_city                  object
# nppes_provider_zip                   object
# nppes_provider_state                 object
# nppes_provider_country               object
# provider_type                        object
# medicare_participation_indicator     object
# place_of_service                     object
# hcpcs_code                           object
# hcpcs_description                    object
# hcpcs_drug_indicator                 object
# line_srvc_cnt                       float64
# bene_unique_cnt                     float64
# bene_day_srvc_cnt                   float64
# average_Medicare_allowed_amt        float64
# average_submitted_chrg_amt          float64
# average_Medicare_payment_amt        float64
# average_Medicare_standard_amt       float64
# dtype: object

# %%
# Check Data

len(df)
# Out:
# 9316308

# %%
# Select only US

df1= df[df.nppes_provider_country == 'US']
df1
# Out:
#                 npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1        1003000126                    ENKESHAFI                   ARDALAN
# 2        1003000126                    ENKESHAFI                   ARDALAN
# 3        1003000126                    ENKESHAFI                   ARDALAN
# 4        1003000126                    ENKESHAFI                   ARDALAN
# 5        1003000126                    ENKESHAFI                   ARDALAN
# ...             ...                          ...                       ...
# 9316303  1992999874                        JOFFE                 GABRIELLA
# 9316304  1992999874                        JOFFE                 GABRIELLA
# 9316305  1992999874                        JOFFE                 GABRIELLA
# 9316306  1992999874                        JOFFE                 GABRIELLA
# 9316307  1992999874                        JOFFE                 GABRIELLA
#
#         nppes_provider_mi nppes_credentials nppes_provider_gender  \
# 1                     NaN              M.D.                     M
# 2                     NaN              M.D.                     M
# 3                     NaN              M.D.                     M
# 4                     NaN              M.D.                     M
# 5                     NaN              M.D.                     M
# ...                   ...               ...                   ...
# 9316303               NaN               NaN                     F
# 9316304               NaN               NaN                     F
# 9316305               NaN               NaN                     F
# 9316306               NaN               NaN                     F
# 9316307               NaN               NaN                     F
#
#         nppes_entity_code nppes_provider_street1 nppes_provider_street2  \
# 1                       I           900 SETON DR                    NaN
# 2                       I           900 SETON DR                    NaN
# 3                       I           900 SETON DR                    NaN
# 4                       I           900 SETON DR                    NaN
# 5                       I           900 SETON DR                    NaN
# ...                   ...                    ...                    ...
# 9316303                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9316304                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9316305                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9316306                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9316307                 I          8260 ATLEE RD       MOB 2, SUITE 319
#
#         nppes_provider_city  ... hcpcs_code  \
# 1                CUMBERLAND  ...      99222
# 2                CUMBERLAND  ...      99223
# 3                CUMBERLAND  ...      99231
# 4                CUMBERLAND  ...      99232
# 5                CUMBERLAND  ...      99233
# ...                     ...  ...        ...
# 9316303      MECHANICSVILLE  ...      99223
# 9316304      MECHANICSVILLE  ...      99232
# 9316305      MECHANICSVILLE  ...      99233
# 9316306      MECHANICSVILLE  ...      99239
# 9316307      MECHANICSVILLE  ...      99291
#
#                                          hcpcs_description  \
# 1        Initial hospital inpatient care, typically 50 ...
# 2        Initial hospital inpatient care, typically 70 ...
# 3        Subsequent hospital inpatient care, typically ...
# 4        Subsequent hospital inpatient care, typically ...
# 5        Subsequent hospital inpatient care, typically ...
# ...                                                    ...
# 9316303  Initial hospital inpatient care, typically 70 ...
# 9316304  Subsequent hospital inpatient care, typically ...
# 9316305  Subsequent hospital inpatient care, typically ...
# 9316306  Hospital discharge day management, more than 3...
# 9316307  Critical care delivery critically ill or injur...
#
#         hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 1                          N         357.0           341.0             357.0
# 2                          N          98.0            98.0              98.0
# 3                          N         104.0            65.0             104.0
# 4                          N        1418.0           596.0            1418.0
# 5                          N         175.0           104.0             175.0
# ...                      ...           ...             ...               ...
# 9316303                    N         109.0           108.0             109.0
# 9316304                    N         425.0           211.0             425.0
# 9316305                    N         387.0           204.0             387.0
# 9316306                    N         194.0           184.0             194.0
# 9316307                    N          22.0            20.0              22.0
#
#         average_Medicare_allowed_amt average_submitted_chrg_amt  \
# 1                             141.05                 416.546218
# 2                             207.79                 611.000000
# 3                              40.10                 119.000000
# 4                              73.66                 217.000000
# 5                             106.12                 312.000000
# ...                              ...                        ...
# 9316303                       200.85                 496.000000
# 9316304                        71.33                 176.000000
# 9316305                       102.80                 254.000000
# 9316306                       105.88                 262.000000
# 9316307                       220.95                 546.000000
#
#         average_Medicare_payment_amt  average_Medicare_standard_amt
# 1                         107.517871                     106.731232
# 2                         152.551224                     153.306837
# 3                          30.835385                      30.708269
# 4                          56.297757                      56.098209
# 5                          82.398171                      81.612743
# ...                              ...                            ...
# 9316303                   155.434220                     158.044404
# 9316304                    55.920000                      56.720000
# 9316305                    80.600000                      81.705530
# 9316306                    83.010000                      84.243608
# 9316307                   173.220000                     175.969091
#
# [9315906 rows x 26 columns]

# %%
# Create ZIP Column

df1['ZIP'] = df1['nppes_provider_zip']
df1.head(5)
# Out:
# <ipython-input-6-83d5433f6691>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ZIP'] = df1['nppes_provider_zip']
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  ...  \
# 1           900 SETON DR                    NaN          CUMBERLAND  ...
# 2           900 SETON DR                    NaN          CUMBERLAND  ...
# 3           900 SETON DR                    NaN          CUMBERLAND  ...
# 4           900 SETON DR                    NaN          CUMBERLAND  ...
# 5           900 SETON DR                    NaN          CUMBERLAND  ...
#
#                                    hcpcs_description hcpcs_drug_indicator  \
# 1  Initial hospital inpatient care, typically 50 ...                    N
# 2  Initial hospital inpatient care, typically 70 ...                    N
# 3  Subsequent hospital inpatient care, typically ...                    N
# 4  Subsequent hospital inpatient care, typically ...                    N
# 5  Subsequent hospital inpatient care, typically ...                    N
#
#   line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 1         357.0           341.0             357.0
# 2          98.0            98.0              98.0
# 3         104.0            65.0             104.0
# 4        1418.0           596.0            1418.0
# 5         175.0           104.0             175.0
#
#   average_Medicare_allowed_amt average_submitted_chrg_amt  \
# 1                       141.05                 416.546218
# 2                       207.79                 611.000000
# 3                        40.10                 119.000000
# 4                        73.66                 217.000000
# 5                       106.12                 312.000000
#
#   average_Medicare_payment_amt average_Medicare_standard_amt          ZIP
# 1                   107.517871                    106.731232  2.15022e+08
# 2                   152.551224                    153.306837  2.15022e+08
# 3                    30.835385                     30.708269  2.15022e+08
# 4                    56.297757                     56.098209  2.15022e+08
# 5                    82.398171                     81.612743  2.15022e+08
#
# [5 rows x 27 columns]

# %%
# Check Data

df1.dtypes
# Out:
# npi                                   int64
# nppes_provider_last_org_name         object
# nppes_provider_first_name            object
# nppes_provider_mi                    object
# nppes_credentials                    object
# nppes_provider_gender                object
# nppes_entity_code                    object
# nppes_provider_street1               object
# nppes_provider_street2               object
# nppes_provider_city                  object
# nppes_provider_zip                   object
# nppes_provider_state                 object
# nppes_provider_country               object
# provider_type                        object
# medicare_participation_indicator     object
# place_of_service                     object
# hcpcs_code                           object
# hcpcs_description                    object
# hcpcs_drug_indicator                 object
# line_srvc_cnt                       float64
# bene_unique_cnt                     float64
# bene_day_srvc_cnt                   float64
# average_Medicare_allowed_amt        float64
# average_submitted_chrg_amt          float64
# average_Medicare_payment_amt        float64
# average_Medicare_standard_amt       float64
# ZIP                                  object
# dtype: object

# %%
# Check unique ZIPs

df1['ZIP'].unique
# Out:
# <bound method Series.unique of 1          2.15022e+08
# 2          2.15022e+08
# 3          2.15022e+08
# 4          2.15022e+08
# 5          2.15022e+08
#               ...
# 9316303      231161844
# 9316304      231161844
# 9316305      231161844
# 9316306      231161844
# 9316307      231161844
# Name: ZIP, Length: 9315906, dtype: object>

# %%
# Create new dataframe with selected columns

df2 = df1[['ZIP','nppes_provider_state', 'npi', 'place_of_service','provider_type', 'hcpcs_code', 'hcpcs_drug_indicator', 'average_submitted_chrg_amt', 'average_Medicare_payment_amt']]
df2.tail(50)
# Out:
#                ZIP nppes_provider_state         npi place_of_service  \
# 9316258  208741214                   MD  1992999551                O
# 9316259  208741214                   MD  1992999551                O
# 9316260  208741214                   MD  1992999551                O
# 9316261  208741214                   MD  1992999551                O
# 9316262  208741214                   MD  1992999551                O
# 9316263  208741214                   MD  1992999551                O
# 9316264  208741214                   MD  1992999551                O
# 9316265  208741214                   MD  1992999551                O
# 9316266  208741214                   MD  1992999551                O
# 9316267  208741214                   MD  1992999551                O
# 9316268  208741214                   MD  1992999551                O
# 9316269  208741214                   MD  1992999551                O
# 9316270  208741214                   MD  1992999551                O
# 9316271  208741214                   MD  1992999551                O
# 9316272  208741214                   MD  1992999551                O
# 9316273  208741214                   MD  1992999551                O
# 9316274  208741214                   MD  1992999551                O
# 9316275  208741214                   MD  1992999551                O
# 9316276  208741214                   MD  1992999551                O
# 9316277  208741214                   MD  1992999551                O
# 9316278  208741214                   MD  1992999551                O
# 9316279  208741214                   MD  1992999551                O
# 9316280  208741214                   MD  1992999551                O
# 9316281  208741214                   MD  1992999551                O
# 9316282  941342809                   CA  1992999569                O
# 9316283  941342809                   CA  1992999569                O
# 9316284  941342809                   CA  1992999569                O
# 9316285  941342809                   CA  1992999569                O
# 9316286  177011932                   PA  1992999585                O
# 9316287  177011932                   PA  1992999585                O
# 9316288  974014604                   OR  1992999775                F
# 9316289  974014604                   OR  1992999775                F
# 9316290  981012756                   WA  1992999825                F
# 9316291  981012756                   WA  1992999825                F
# 9316292  981012756                   WA  1992999825                F
# 9316293  981012756                   WA  1992999825                O
# 9316294  981012756                   WA  1992999825                O
# 9316295  981012756                   WA  1992999825                F
# 9316296  981012756                   WA  1992999825                O
# 9316297  981012756                   WA  1992999825                F
# 9316298  981012756                   WA  1992999825                O
# 9316299  981012756                   WA  1992999825                O
# 9316300  981012756                   WA  1992999825                F
# 9316301  981012756                   WA  1992999825                O
# 9316302  231161844                   VA  1992999874                F
# 9316303  231161844                   VA  1992999874                F
# 9316304  231161844                   VA  1992999874                F
# 9316305  231161844                   VA  1992999874                F
# 9316306  231161844                   VA  1992999874                F
# 9316307  231161844                   VA  1992999874                F
#
#                       provider_type hcpcs_code hcpcs_drug_indicator  \
# 9316258           Internal Medicine      80076                    N
# 9316259           Internal Medicine      81001                    N
# 9316260           Internal Medicine      81003                    N
# 9316261           Internal Medicine      82043                    N
# 9316262           Internal Medicine      82570                    N
# 9316263           Internal Medicine      83036                    N
# 9316264           Internal Medicine      84443                    N
# 9316265           Internal Medicine      84450                    N
# 9316266           Internal Medicine      84460                    N
# 9316267           Internal Medicine      85025                    N
# 9316268           Internal Medicine      90662                    Y
# 9316269           Internal Medicine      90670                    Y
# 9316270           Internal Medicine      90688                    Y
# 9316271           Internal Medicine      90715                    Y
# 9316272           Internal Medicine      93000                    N
# 9316273           Internal Medicine      99202                    N
# 9316274           Internal Medicine      99213                    N
# 9316275           Internal Medicine      99214                    N
# 9316276           Internal Medicine      G0008                    N
# 9316277           Internal Medicine      G0009                    N
# 9316278           Internal Medicine      G0402                    N
# 9316279           Internal Medicine      G0403                    N
# 9316280           Internal Medicine      G0438                    N
# 9316281           Internal Medicine      G0439                    N
# 9316282                   Optometry      92004                    N
# 9316283                   Optometry      92012                    N
# 9316284                   Optometry      92014                    N
# 9316285                   Optometry      99213                    N
# 9316286                Chiropractic      98940                    N
# 9316287                Chiropractic      98941                    N
# 9316288  Ambulatory Surgical Center      62311                    N
# 9316289  Ambulatory Surgical Center      64483                    N
# 9316290              Otolaryngology      30130                    N
# 9316291              Otolaryngology      30520                    N
# 9316292              Otolaryngology      31575                    N
# 9316293              Otolaryngology      31575                    N
# 9316294              Otolaryngology      69210                    N
# 9316295              Otolaryngology      69433                    N
# 9316296              Otolaryngology      99203                    N
# 9316297              Otolaryngology      99204                    N
# 9316298              Otolaryngology      99204                    N
# 9316299              Otolaryngology      99213                    N
# 9316300              Otolaryngology      99214                    N
# 9316301              Otolaryngology      99214                    N
# 9316302           Internal Medicine      99220                    N
# 9316303           Internal Medicine      99223                    N
# 9316304           Internal Medicine      99232                    N
# 9316305           Internal Medicine      99233                    N
# 9316306           Internal Medicine      99239                    N
# 9316307           Internal Medicine      99291                    N
#
#          average_submitted_chrg_amt  average_Medicare_payment_amt
# 9316258                   52.000000                      7.836757
# 9316259                   22.000000                      4.230000
# 9316260                   16.000000                      3.000000
# 9316261                   35.000000                      7.730000
# 9316262                   41.000000                      6.920000
# 9316263                   50.000000                     12.980000
# 9316264                   50.000000                     22.470000
# 9316265                   24.000000                      3.558529
# 9316266                   25.000000                      3.698235
# 9316267                   32.000000                     10.267010
# 9316268                   39.000000                     32.700000
# 9316269                  175.000000                    150.880000
# 9316270                   30.000000                     16.500000
# 9316271                   55.000000                     22.039167
# 9316272                   80.000000                     12.936667
# 9316273                  121.000000                     49.064545
# 9316274                  116.000000                     54.217759
# 9316275                  173.000000                     85.190571
# 9316276                   31.000000                     28.640000
# 9316277                   31.000000                     28.640000
# 9316278                  175.000000                    171.500000
# 9316279                   76.000000                     12.810769
# 9316280                  225.000000                    187.480000
# 9316281                  145.000000                    125.760000
# 9316282                  205.000000                    132.437692
# 9316283                  120.000000                     81.976471
# 9316284                  170.000000                    116.467000
# 9316285                   95.000000                     68.850000
# 9316286                   30.000000                     18.415128
# 9316287                   40.000000                     29.327534
# 9316288                 1500.000000                    312.717333
# 9316289                 1520.833333                    297.569444
# 9316290                 1348.500000                    318.449231
# 9316291                 1831.000000                    539.770000
# 9316292                  339.000000                     60.534706
# 9316293                  339.000000                     92.889464
# 9316294                  151.000000                     37.896375
# 9316295                  619.000000                    115.460000
# 9316296                  278.000000                     81.541250
# 9316297                  257.000000                     99.192449
# 9316298                  410.000000                    125.587039
# 9316299                  223.000000                     54.076923
# 9316300                  175.000000                     59.519608
# 9316301                  328.000000                     84.217076
# 9316302                  452.000000                    143.810000
# 9316303                  496.000000                    155.434220
# 9316304                  176.000000                     55.920000
# 9316305                  254.000000                     80.600000
# 9316306                  262.000000                     83.010000
# 9316307                  546.000000                    173.220000

# %%
# Check New dataframe
df2.dtypes
# Out:
# ZIP                              object
# nppes_provider_state             object
# npi                               int64
# place_of_service                 object
# provider_type                    object
# hcpcs_code                       object
# hcpcs_drug_indicator             object
# average_submitted_chrg_amt      float64
# average_Medicare_payment_amt    float64
# dtype: object

# %%
# Create states list to then exclude US territories

states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
df2 = df2[df2['nppes_provider_state'].isin(states)]
df2
# Out:
#                  ZIP nppes_provider_state         npi place_of_service  \
# 1        2.15022e+08                   MD  1003000126                F
# 2        2.15022e+08                   MD  1003000126                F
# 3        2.15022e+08                   MD  1003000126                F
# 4        2.15022e+08                   MD  1003000126                F
# 5        2.15022e+08                   MD  1003000126                F
# ...              ...                  ...         ...              ...
# 9316303    231161844                   VA  1992999874                F
# 9316304    231161844                   VA  1992999874                F
# 9316305    231161844                   VA  1992999874                F
# 9316306    231161844                   VA  1992999874                F
# 9316307    231161844                   VA  1992999874                F
#
#              provider_type hcpcs_code hcpcs_drug_indicator  \
# 1        Internal Medicine      99222                    N
# 2        Internal Medicine      99223                    N
# 3        Internal Medicine      99231                    N
# 4        Internal Medicine      99232                    N
# 5        Internal Medicine      99233                    N
# ...                    ...        ...                  ...
# 9316303  Internal Medicine      99223                    N
# 9316304  Internal Medicine      99232                    N
# 9316305  Internal Medicine      99233                    N
# 9316306  Internal Medicine      99239                    N
# 9316307  Internal Medicine      99291                    N
#
#          average_submitted_chrg_amt  average_Medicare_payment_amt
# 1                        416.546218                    107.517871
# 2                        611.000000                    152.551224
# 3                        119.000000                     30.835385
# 4                        217.000000                     56.297757
# 5                        312.000000                     82.398171
# ...                             ...                           ...
# 9316303                  496.000000                    155.434220
# 9316304                  176.000000                     55.920000
# 9316305                  254.000000                     80.600000
# 9316306                  262.000000                     83.010000
# 9316307                  546.000000                    173.220000
#
# [9280545 rows x 9 columns]

# %%
# Clean and sort ZIP codes for merging

df2['ZIP'] = df2['ZIP'].astype(str).str[0:5].map(lambda x: str(x.replace('.','')))
df2['ZIP'] = df2['ZIP'].astype(int)
df2 = df2.dropna()
df2.sort_values(by=['ZIP'], inplace=True)
df2
# Out:
#            ZIP nppes_provider_state         npi place_of_service  \
# 1035602      0                   MA  1114060506                F
# 1035606      0                   MA  1114060506                F
# 1035605      0                   MA  1114060506                F
# 1035604      0                   MA  1114060506                F
# 1035603      0                   MA  1114060506                F
# ...        ...                  ...         ...              ...
# 1021080  99929                   AK  1104982909                F
# 6772418  99929                   AK  1720144520                F
# 1021079  99929                   AK  1104982909                F
# 1021083  99929                   AK  1104982909                O
# 2787775  99929                   AK  1295886950                O
#
#                              provider_type hcpcs_code hcpcs_drug_indicator  \
# 1035602  Osteopathic Manipulative Medicine      99283                    N
# 1035606  Osteopathic Manipulative Medicine      99292                    N
# 1035605  Osteopathic Manipulative Medicine      99291                    N
# 1035604  Osteopathic Manipulative Medicine      99285                    N
# 1035603  Osteopathic Manipulative Medicine      99284                    N
# ...                                    ...        ...                  ...
# 1021080                    Family Practice      99213                    N
# 6772418                    Family Practice      99222                    N
# 1021079                    Family Practice      99212                    N
# 1021083                    Family Practice      99214                    N
# 2787775                       Chiropractic      98941                    N
#
#          average_submitted_chrg_amt  average_Medicare_payment_amt
# 1035602                  304.758621                     44.960345
# 1035606                  411.296296                     89.012963
# 1035605                  813.804403                    176.781045
# 1035604                  572.891014                    135.657101
# 1035603                  411.837003                     89.848258
# ...                             ...                           ...
# 1021080                  157.052632                     49.868684
# 6772418                  431.000000                    146.060000
# 1021079                  121.684211                     21.603158
# 1021083                  215.000000                    101.541250
# 2787775                   50.000000                     35.289317
#
# [9280545 rows x 9 columns]

# %%
# Check data

len(df2)
# Out:
# 9280545

# %%
# Check data

df2.dtypes
# Out:
# ZIP                               int64
# nppes_provider_state             object
# npi                               int64
# place_of_service                 object
# provider_type                    object
# hcpcs_code                       object
# hcpcs_drug_indicator             object
# average_submitted_chrg_amt      float64
# average_Medicare_payment_amt    float64
# dtype: object

# %%
# Read ZIP data file and store into pandas data frame

df3 = pd.read_csv('../Final_project_BigData/ZIP-COUNTY-FIPS.csv') 
df3.dtypes
# Out:
# ZIP            int64
# COUNTYNAME    object
# STATE         object
# STCOUNTYFP     int64
# CLASSFP       object
# dtype: object

# %%
# Check data

len(df3)
# Out:
# 52889

# %%
# Create states list to then exclude US territories

df3 = df3[df3['STATE'].isin(states)]
df3
# Out:
#          ZIP      COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0      36003  Autauga County    AL        1001      H1
# 1      36006  Autauga County    AL        1001      H1
# 2      36067  Autauga County    AL        1001      H1
# 3      36066  Autauga County    AL        1001      H1
# 4      36703  Autauga County    AL        1001      H1
# ...      ...             ...   ...         ...     ...
# 52566  82729   Weston County    WY       56045      H1
# 52567  82730   Weston County    WY       56045      H1
# 52568  82701   Weston County    WY       56045      H1
# 52569  82723   Weston County    WY       56045      H1
# 52570  82715   Weston County    WY       56045      H1
#
# [52571 rows x 5 columns]

# %%
# Select column for the merge

df3 = df3[['ZIP','COUNTYNAME']]
df3.sort_values(by=['ZIP'], inplace=True)
df3
# Out:
# <ipython-input-18-9fb1020b0784>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.sort_values(by=['ZIP'], inplace=True)
#          ZIP                         COUNTYNAME
# 32368    501                     Suffolk County
# 20964   1001                     Hampden County
# 20940   1002                    Franklin County
# 21018   1002                   Hampshire County
# 21028   1003                   Hampshire County
# ...      ...                                ...
# 1300   99925  Prince of Wales-Hyder Census Area
# 1296   99926  Prince of Wales-Hyder Census Area
# 1295   99927  Prince of Wales-Hyder Census Area
# 1227   99928          Ketchikan Gateway Borough
# 1333   99929          Wrangell City and Borough
#
# [52571 rows x 2 columns]

# %%
# Check data

df3.dtypes
# Out:
# ZIP            int64
# COUNTYNAME    object
# dtype: object

# %%
# Merge dataframes by Zipcode

dfinal= pd.merge_asof(df2, df3, on='ZIP')

# %%
# Sort Data by NPI number

dfinal.sort_values(by=['npi'], inplace=True)
dfinal.head(100)
# Out:
#            ZIP nppes_provider_state         npi place_of_service  \
# 1550862  21502                   MD  1003000126                F
# 1548049  21502                   MD  1003000126                F
# 1551004  21502                   MD  1003000126                F
# 1550997  21502                   MD  1003000126                F
# 1550927  21502                   MD  1003000126                F
# ...        ...                  ...         ...              ...
# 8790450  94578                   CA  1003000852                O
# 8790454  94578                   CA  1003000852                O
# 4043850  40212                   KY  1003000902                O
# 4043847  40212                   KY  1003000902                O
# 4043829  40212                   KY  1003000902                F
#
#                  provider_type hcpcs_code hcpcs_drug_indicator  \
# 1550862      Internal Medicine      99223                    N
# 1548049      Internal Medicine      99222                    N
# 1551004      Internal Medicine      99233                    N
# 1550997      Internal Medicine      99238                    N
# 1550927      Internal Medicine      99239                    N
# ...                        ...        ...                  ...
# 8790450  Clinical Psychologist      90791                    N
# 8790454  Clinical Psychologist      90834                    N
# 4043850        Family Practice      99213                    N
# 4043847        Family Practice      99214                    N
# 4043829        Family Practice      99222                    N
#
#          average_submitted_chrg_amt  average_Medicare_payment_amt  \
# 1550862                  611.000000                    152.551224
# 1548049                  416.546218                    107.517871
# 1551004                  312.000000                     82.398171
# 1550997                  217.000000                     55.681242
# 1550927                  322.000000                     83.706368
# ...                             ...                           ...
# 8790450                  247.222222                    113.050000
# 8790454                  156.862745                     71.930000
# 4043850                  120.000000                     52.207679
# 4043847                  175.000000                     66.934505
# 4043829                  199.200000                    100.209223
#
#                COUNTYNAME
# 1550862   Allegany County
# 1548049   Allegany County
# 1551004   Allegany County
# 1550997   Allegany County
# 1550927   Allegany County
# ...                   ...
# 8790450    Alameda County
# 8790454    Alameda County
# 4043850  Jefferson County
# 4043847  Jefferson County
# 4043829  Jefferson County
#
# [100 rows x 10 columns]

# %%
# Check data

len(dfinal)
# Out:
# 9280545

# %%
# Create Dataframe 

df_2014 = dfinal.groupby(['nppes_provider_state', 'COUNTYNAME', 'ZIP', 'provider_type', 'place_of_service']).agg({'average_submitted_chrg_amt': ['mean'], 'average_Medicare_payment_amt': ['mean']})
df_2014.columns = ['Avg Submit 2014', 'Avg Payment 2014']
df_2014 = df_2014.reset_index()

df_2014.head(50)
# Out:
#    nppes_provider_state                  COUNTYNAME    ZIP  \
# 0                    AK      Aleutians East Borough  99612
# 1                    AK      Aleutians East Borough  99661
# 2                    AK  Aleutians West Census Area  99660
# 3                    AK  Aleutians West Census Area  99685
# 4                    AK  Aleutians West Census Area  99685
# 5                    AK  Aleutians West Census Area  99685
# 6                    AK  Aleutians West Census Area  99685
# 7                    AK      Anchorage Municipality  99501
# 8                    AK      Anchorage Municipality  99501
# 9                    AK      Anchorage Municipality  99501
# 10                   AK      Anchorage Municipality  99501
# 11                   AK      Anchorage Municipality  99501
# 12                   AK      Anchorage Municipality  99501
# 13                   AK      Anchorage Municipality  99501
# 14                   AK      Anchorage Municipality  99501
# 15                   AK      Anchorage Municipality  99501
# 16                   AK      Anchorage Municipality  99501
# 17                   AK      Anchorage Municipality  99501
# 18                   AK      Anchorage Municipality  99501
# 19                   AK      Anchorage Municipality  99501
# 20                   AK      Anchorage Municipality  99501
# 21                   AK      Anchorage Municipality  99502
# 22                   AK      Anchorage Municipality  99502
# 23                   AK      Anchorage Municipality  99502
# 24                   AK      Anchorage Municipality  99502
# 25                   AK      Anchorage Municipality  99502
# 26                   AK      Anchorage Municipality  99502
# 27                   AK      Anchorage Municipality  99502
# 28                   AK      Anchorage Municipality  99502
# 29                   AK      Anchorage Municipality  99502
# 30                   AK      Anchorage Municipality  99503
# 31                   AK      Anchorage Municipality  99503
# 32                   AK      Anchorage Municipality  99503
# 33                   AK      Anchorage Municipality  99503
# 34                   AK      Anchorage Municipality  99503
# 35                   AK      Anchorage Municipality  99503
# 36                   AK      Anchorage Municipality  99503
# 37                   AK      Anchorage Municipality  99503
# 38                   AK      Anchorage Municipality  99503
# 39                   AK      Anchorage Municipality  99503
# 40                   AK      Anchorage Municipality  99503
# 41                   AK      Anchorage Municipality  99503
# 42                   AK      Anchorage Municipality  99503
# 43                   AK      Anchorage Municipality  99503
# 44                   AK      Anchorage Municipality  99503
# 45                   AK      Anchorage Municipality  99503
# 46                   AK      Anchorage Municipality  99503
# 47                   AK      Anchorage Municipality  99503
# 48                   AK      Anchorage Municipality  99503
# 49                   AK      Anchorage Municipality  99503
#
#                               provider_type place_of_service  Avg Submit 2014  \
# 0                        Nurse Practitioner                O       110.371906
# 1                        Nurse Practitioner                O        86.957418
# 2                        Nurse Practitioner                F       178.000000
# 3                           Family Practice                O        90.857143
# 4                         Internal Medicine                F       224.454545
# 5                        Nurse Practitioner                O       280.333333
# 6                       Physician Assistant                O       126.383186
# 7                Ambulance Service Supplier                F       606.516458
# 8                Ambulatory Surgical Center                F      1909.396451
# 9                                      CRNA                F      1150.321789
# 10                          Centralized Flu                O        27.763947
# 11                          Family Practice                F       143.450000
# 12                          Family Practice                O        96.400810
# 13                        Internal Medicine                O       124.110350
# 14          Licensed Clinical Social Worker                O       127.360000
# 15                       Nurse Practitioner                O       167.286677
# 16                            Ophthalmology                F      4396.038560
# 17                            Ophthalmology                O       344.941403
# 18                                Optometry                O       233.928569
# 19                       Physical Therapist                O       104.059633
# 20                               Psychiatry                F       153.000000
# 21               Ambulance Service Supplier                F      3647.481353
# 22                           Anesthesiology                F      1448.721228
# 23                          Centralized Flu                O        25.563679
# 24                             Chiropractic                O        54.907227
# 25                          Family Practice                F       215.750000
# 26                          Family Practice                O       102.447250
# 27                         General Practice                O       115.046411
# 28                        Internal Medicine                O       184.873333
# 29                                Neurology                F       567.233213
# 30                          Centralized Flu                O        31.226438
# 31                             Chiropractic                O        52.706327
# 32                      Clinical Laboratory                O        62.241671
# 33                    Clinical Psychologist                O       336.236702
# 34             Critical Care (Intensivists)                F       745.671124
# 35                              Dermatology                O       440.424032
# 36                          Family Practice                F       508.192304
# 37                          Family Practice                O       109.012243
# 38              Hospice and Palliative Care                F       555.000000
# 39  Independent Diagnostic Testing Facility                O      3997.186701
# 40                        Internal Medicine                F       521.262735
# 41                       Nurse Practitioner                F       229.750000
# 42                       Nurse Practitioner                O       161.932678
# 43                    Obstetrics/Gynecology                O       172.207135
# 44                                Optometry                O       187.410499
# 45     Physical Medicine and Rehabilitation                F       560.750000
# 46                       Physical Therapist                O        95.987089
# 47                      Physician Assistant                O       127.007000
# 48                               Psychiatry                O       192.237015
# 49                        Pulmonary Disease                F       768.228106
#
#     Avg Payment 2014
# 0          31.733094
# 1          36.655052
# 2          42.414167
# 3          11.797447
# 4          77.345224
# 5          61.639533
# 6          41.700269
# 7         287.632562
# 8         671.970937
# 9         228.594330
# 10         27.208226
# 11         93.845000
# 12         18.072367
# 13         37.549679
# 14         54.303157
# 15         32.853463
# 16        630.389414
# 17         84.575329
# 18         73.866403
# 19         42.544093
# 20         56.200000
# 21        949.583110
# 22        100.917645
# 23         24.079535
# 24         33.725131
# 25         57.807286
# 26         37.210561
# 27         39.729356
# 28         94.723645
# 29         79.224228
# 30         29.890697
# 31         30.415536
# 32         14.310950
# 33         90.322907
# 34        123.398860
# 35         90.185130
# 36        113.396314
# 37         17.083157
# 38        108.221717
# 39        562.021816
# 40        115.392879
# 41         58.805003
# 42         63.755539
# 43        124.727124
# 44         70.067842
# 45        128.344302
# 46         37.848143
# 47         36.235131
# 48         76.834824
# 49        123.266967

# %%
# Check data

len(df_2014)
# Out:
# 340444

# %%
# Save dataframe as CSV

df_2014.to_csv('2014.csv')
