# %%
# Dependencies

import pandas as pd
import numpy as np

# %%
# Read data file and store into pandas data frame.

df = pd.read_csv("2016/Medicare_Provider_Util_Payment_PUF_CY2016/Medicare_Provider_Util_Payment_PUF_CY2016.txt", sep="\t", header=0)
# Out:
# /Users/diegogonzalez/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Check data

df.dtypes
# Out:
# NPI                                   int64
# NPPES_PROVIDER_LAST_ORG_NAME         object
# NPPES_PROVIDER_FIRST_NAME            object
# NPPES_PROVIDER_MI                    object
# NPPES_CREDENTIALS                    object
# NPPES_PROVIDER_GENDER                object
# NPPES_ENTITY_CODE                    object
# NPPES_PROVIDER_STREET1               object
# NPPES_PROVIDER_STREET2               object
# NPPES_PROVIDER_CITY                  object
# NPPES_PROVIDER_ZIP                   object
# NPPES_PROVIDER_STATE                 object
# NPPES_PROVIDER_COUNTRY               object
# PROVIDER_TYPE                        object
# MEDICARE_PARTICIPATION_INDICATOR     object
# PLACE_OF_SERVICE                     object
# HCPCS_CODE                           object
# HCPCS_DESCRIPTION                    object
# HCPCS_DRUG_INDICATOR                 object
# LINE_SRVC_CNT                       float64
# BENE_UNIQUE_CNT                     float64
# BENE_DAY_SRVC_CNT                   float64
# AVERAGE_MEDICARE_ALLOWED_AMT        float64
# AVERAGE_SUBMITTED_CHRG_AMT          float64
# AVERAGE_MEDICARE_PAYMENT_AMT        float64
# AVERAGE_MEDICARE_STANDARD_AMT       float64
# dtype: object

# %%
# Check Data

len(df)
# Out:
# 9714897

# %%
# Select only US

df1= df[df.NPPES_PROVIDER_COUNTRY == 'US']
df1
# Out:
#                 NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 1        1003000126                    ENKESHAFI                   ARDALAN
# 2        1003000126                    ENKESHAFI                   ARDALAN
# 3        1003000126                    ENKESHAFI                   ARDALAN
# 4        1003000126                    ENKESHAFI                   ARDALAN
# 5        1003000126                    ENKESHAFI                   ARDALAN
# ...             ...                          ...                       ...
# 9714892  1992999874                        JOFFE                 GABRIELLA
# 9714893  1992999874                        JOFFE                 GABRIELLA
# 9714894  1992999874                        JOFFE                 GABRIELLA
# 9714895  1992999874                        JOFFE                 GABRIELLA
# 9714896  1992999874                        JOFFE                 GABRIELLA
#
#         NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER  \
# 1                     NaN              M.D.                     M
# 2                     NaN              M.D.                     M
# 3                     NaN              M.D.                     M
# 4                     NaN              M.D.                     M
# 5                     NaN              M.D.                     M
# ...                   ...               ...                   ...
# 9714892               NaN               NaN                     F
# 9714893               NaN               NaN                     F
# 9714894               NaN               NaN                     F
# 9714895               NaN               NaN                     F
# 9714896               NaN               NaN                     F
#
#         NPPES_ENTITY_CODE NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2  \
# 1                       I           900 SETON DR                    NaN
# 2                       I           900 SETON DR                    NaN
# 3                       I           900 SETON DR                    NaN
# 4                       I           900 SETON DR                    NaN
# 5                       I           900 SETON DR                    NaN
# ...                   ...                    ...                    ...
# 9714892                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9714893                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9714894                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9714895                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9714896                 I          8260 ATLEE RD       MOB 2, SUITE 319
#
#         NPPES_PROVIDER_CITY  ... HCPCS_CODE  \
# 1                CUMBERLAND  ...      99217
# 2                CUMBERLAND  ...      99219
# 3                CUMBERLAND  ...      99220
# 4                CUMBERLAND  ...      99221
# 5                CUMBERLAND  ...      99222
# ...                     ...  ...        ...
# 9714892      MECHANICSVILLE  ...      99223
# 9714893      MECHANICSVILLE  ...      99232
# 9714894      MECHANICSVILLE  ...      99233
# 9714895      MECHANICSVILLE  ...      99239
# 9714896      MECHANICSVILLE  ...      99291
#
#                                          HCPCS_DESCRIPTION  \
# 1                      Hospital observation care discharge
# 2           Hospital observation care typically 50 minutes
# 3        Hospital observation care typically 70 minutes...
# 4        Initial hospital inpatient care, typically 30 ...
# 5        Initial hospital inpatient care, typically 50 ...
# ...                                                    ...
# 9714892  Initial hospital inpatient care, typically 70 ...
# 9714893  Subsequent hospital inpatient care, typically ...
# 9714894  Subsequent hospital inpatient care, typically ...
# 9714895  Hospital discharge day management, more than 3...
# 9714896  Critical care delivery critically ill or injur...
#
#         HCPCS_DRUG_INDICATOR LINE_SRVC_CNT BENE_UNIQUE_CNT BENE_DAY_SRVC_CNT  \
# 1                          N          57.0            55.0              57.0
# 2                          N          38.0            38.0              38.0
# 3                          N          23.0            23.0              23.0
# 4                          N          20.0            20.0              20.0
# 5                          N          96.0            87.0              96.0
# ...                      ...           ...             ...               ...
# 9714892                    N         138.0           136.0             138.0
# 9714893                    N         315.0           167.0             315.0
# 9714894                    N         323.0           175.0             323.0
# 9714895                    N         160.0           155.0             160.0
# 9714896                    N          17.0            17.0              17.0
#
#         AVERAGE_MEDICARE_ALLOWED_AMT AVERAGE_SUBMITTED_CHRG_AMT  \
# 1                          72.743158                 325.157895
# 2                         135.010000                 614.000000
# 3                         189.239565                 769.347826
# 4                         100.750000                 460.000000
# 5                         136.250000                 625.000000
# ...                              ...                        ...
# 9714892                   201.670000                 496.000000
# 9714893                    71.780000                 176.000000
# 9714894                   103.540000                 254.000000
# 9714895                   106.760000                 262.000000
# 9714896                   222.600000                 543.058824
#
#         AVERAGE_MEDICARE_PAYMENT_AMT  AVERAGE_MEDICARE_STANDARD_AMT
# 1                          54.474386                      55.807193
# 2                         105.850000                     107.230000
# 3                         146.116522                     144.278696
# 4                          78.990000                      80.280000
# 5                         105.477604                     107.007708
# ...                              ...                            ...
# 9714892                   155.637826                     157.817754
# 9714893                    56.270000                      56.980000
# 9714894                    80.918700                      81.999505
# 9714895                    83.393938                      84.473938
# 9714896                   174.520000                     177.120000
#
# [9714369 rows x 26 columns]

# %%
# Create ZIP Column

df1['ZIP'] = df1['NPPES_PROVIDER_ZIP']
df1.head(5)
# Out:
# <ipython-input-6-189a4acb3a75>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ZIP'] = df1['NPPES_PROVIDER_ZIP']
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  ...  \
# 1           900 SETON DR                    NaN          CUMBERLAND  ...
# 2           900 SETON DR                    NaN          CUMBERLAND  ...
# 3           900 SETON DR                    NaN          CUMBERLAND  ...
# 4           900 SETON DR                    NaN          CUMBERLAND  ...
# 5           900 SETON DR                    NaN          CUMBERLAND  ...
#
#                                    HCPCS_DESCRIPTION HCPCS_DRUG_INDICATOR  \
# 1                Hospital observation care discharge                    N
# 2     Hospital observation care typically 50 minutes                    N
# 3  Hospital observation care typically 70 minutes...                    N
# 4  Initial hospital inpatient care, typically 30 ...                    N
# 5  Initial hospital inpatient care, typically 50 ...                    N
#
#   LINE_SRVC_CNT BENE_UNIQUE_CNT BENE_DAY_SRVC_CNT  \
# 1          57.0            55.0              57.0
# 2          38.0            38.0              38.0
# 3          23.0            23.0              23.0
# 4          20.0            20.0              20.0
# 5          96.0            87.0              96.0
#
#   AVERAGE_MEDICARE_ALLOWED_AMT AVERAGE_SUBMITTED_CHRG_AMT  \
# 1                    72.743158                 325.157895
# 2                   135.010000                 614.000000
# 3                   189.239565                 769.347826
# 4                   100.750000                 460.000000
# 5                   136.250000                 625.000000
#
#   AVERAGE_MEDICARE_PAYMENT_AMT AVERAGE_MEDICARE_STANDARD_AMT          ZIP
# 1                    54.474386                     55.807193  2.15022e+08
# 2                   105.850000                    107.230000  2.15022e+08
# 3                   146.116522                    144.278696  2.15022e+08
# 4                    78.990000                     80.280000  2.15022e+08
# 5                   105.477604                    107.007708  2.15022e+08
#
# [5 rows x 27 columns]

# %%
# Check Data

df1.dtypes
# Out:
# NPI                                   int64
# NPPES_PROVIDER_LAST_ORG_NAME         object
# NPPES_PROVIDER_FIRST_NAME            object
# NPPES_PROVIDER_MI                    object
# NPPES_CREDENTIALS                    object
# NPPES_PROVIDER_GENDER                object
# NPPES_ENTITY_CODE                    object
# NPPES_PROVIDER_STREET1               object
# NPPES_PROVIDER_STREET2               object
# NPPES_PROVIDER_CITY                  object
# NPPES_PROVIDER_ZIP                   object
# NPPES_PROVIDER_STATE                 object
# NPPES_PROVIDER_COUNTRY               object
# PROVIDER_TYPE                        object
# MEDICARE_PARTICIPATION_INDICATOR     object
# PLACE_OF_SERVICE                     object
# HCPCS_CODE                           object
# HCPCS_DESCRIPTION                    object
# HCPCS_DRUG_INDICATOR                 object
# LINE_SRVC_CNT                       float64
# BENE_UNIQUE_CNT                     float64
# BENE_DAY_SRVC_CNT                   float64
# AVERAGE_MEDICARE_ALLOWED_AMT        float64
# AVERAGE_SUBMITTED_CHRG_AMT          float64
# AVERAGE_MEDICARE_PAYMENT_AMT        float64
# AVERAGE_MEDICARE_STANDARD_AMT       float64
# ZIP                                  object
# dtype: object

# %%
# Check unique ZIPs

df1['ZIP'].unique
# Out:
# <bound method Series.unique of 1          2.15022e+08
# 2          2.15022e+08
# 3          2.15022e+08
# 4          2.15022e+08
# 5          2.15022e+08
#               ...
# 9714892      231161844
# 9714893      231161844
# 9714894      231161844
# 9714895      231161844
# 9714896      231161844
# Name: ZIP, Length: 9714369, dtype: object>

# %%
# Create new dataframe with selected columns

df2 = df1[['ZIP','NPPES_PROVIDER_STATE', 'NPI', 'PLACE_OF_SERVICE', 'PROVIDER_TYPE', 'HCPCS_CODE', 'HCPCS_DRUG_INDICATOR', 'AVERAGE_SUBMITTED_CHRG_AMT', 'AVERAGE_MEDICARE_PAYMENT_AMT']]
df2.tail(50)
# Out:
#                ZIP NPPES_PROVIDER_STATE         NPI PLACE_OF_SERVICE  \
# 9714847  334872768                   FL  1992999122                O
# 9714848  338841107                   FL  1992999270                O
# 9714849  338841107                   FL  1992999270                O
# 9714850  338841107                   FL  1992999270                F
# 9714851  338841107                   FL  1992999270                F
# 9714852  338841107                   FL  1992999270                F
# 9714853  338841107                   FL  1992999270                F
# 9714854  333162510                   FL  1992999437                F
# 9714855  333162510                   FL  1992999437                F
# 9714856  333162510                   FL  1992999437                F
# 9714857  333162510                   FL  1992999437                F
# 9714858  333162510                   FL  1992999437                F
# 9714859  448706062                   OH  1992999452                O
# 9714860  920254402                   CA  1992999551                O
# 9714861  920254402                   CA  1992999551                O
# 9714862  920254402                   CA  1992999551                O
# 9714863  920254402                   CA  1992999551                O
# 9714864  920254402                   CA  1992999551                O
# 9714865  920254402                   CA  1992999551                O
# 9714866  920254402                   CA  1992999551                O
# 9714867  920254402                   CA  1992999551                O
# 9714868  920254402                   CA  1992999551                O
# 9714869  941342809                   CA  1992999569                O
# 9714870  941342809                   CA  1992999569                O
# 9714871  313127134                   GA  1992999759                O
# 9714872  313127134                   GA  1992999759                O
# 9714873  974014604                   OR  1992999775                F
# 9714874  974014604                   OR  1992999775                F
# 9714875  974014604                   OR  1992999775                F
# 9714876  981012756                   WA  1992999825                F
# 9714877  981012756                   WA  1992999825                O
# 9714878  981012756                   WA  1992999825                O
# 9714879  981012756                   WA  1992999825                F
# 9714880  981012756                   WA  1992999825                O
# 9714881  981012756                   WA  1992999825                F
# 9714882  981012756                   WA  1992999825                O
# 9714883  981012756                   WA  1992999825                O
# 9714884  981012756                   WA  1992999825                F
# 9714885  981012756                   WA  1992999825                O
# 9714886  981012756                   WA  1992999825                F
# 9714887  981012756                   WA  1992999825                O
# 9714888  981012756                   WA  1992999825                F
# 9714889  981012756                   WA  1992999825                O
# 9714890  231161844                   VA  1992999874                F
# 9714891  231161844                   VA  1992999874                F
# 9714892  231161844                   VA  1992999874                F
# 9714893  231161844                   VA  1992999874                F
# 9714894  231161844                   VA  1992999874                F
# 9714895  231161844                   VA  1992999874                F
# 9714896  231161844                   VA  1992999874                F
#
#                       PROVIDER_TYPE HCPCS_CODE HCPCS_DRUG_INDICATOR  \
# 9714847           Internal Medicine      G0439                    N
# 9714848         Physician Assistant      99212                    N
# 9714849         Physician Assistant      99213                    N
# 9714850         Physician Assistant      99221                    N
# 9714851         Physician Assistant      99222                    N
# 9714852         Physician Assistant      99231                    N
# 9714853         Physician Assistant      99232                    N
# 9714854          Emergency Medicine      31500                    N
# 9714855          Emergency Medicine      93010                    N
# 9714856          Emergency Medicine      99284                    N
# 9714857          Emergency Medicine      99285                    N
# 9714858          Emergency Medicine      99291                    N
# 9714859                Chiropractic      98941                    N
# 9714860           Internal Medicine      90662                    Y
# 9714861           Internal Medicine      90670                    Y
# 9714862           Internal Medicine      93000                    N
# 9714863           Internal Medicine      99202                    N
# 9714864           Internal Medicine      99203                    N
# 9714865           Internal Medicine      99213                    N
# 9714866           Internal Medicine      99214                    N
# 9714867           Internal Medicine      G0008                    N
# 9714868           Internal Medicine      G0009                    N
# 9714869                   Optometry      92004                    N
# 9714870                   Optometry      92250                    N
# 9714871          Nurse Practitioner      99204                    N
# 9714872          Nurse Practitioner      99214                    N
# 9714873  Ambulatory Surgical Center      62310                    N
# 9714874  Ambulatory Surgical Center      62311                    N
# 9714875  Ambulatory Surgical Center      64483                    N
# 9714876              Otolaryngology      30901                    N
# 9714877              Otolaryngology      30901                    N
# 9714878              Otolaryngology      31231                    N
# 9714879              Otolaryngology      31575                    N
# 9714880              Otolaryngology      31575                    N
# 9714881              Otolaryngology      37609                    N
# 9714882              Otolaryngology      69210                    N
# 9714883              Otolaryngology      82565                    N
# 9714884              Otolaryngology      99203                    N
# 9714885              Otolaryngology      99203                    N
# 9714886              Otolaryngology      99204                    N
# 9714887              Otolaryngology      99204                    N
# 9714888              Otolaryngology      99214                    N
# 9714889              Otolaryngology      99214                    N
# 9714890           Internal Medicine      99217                    N
# 9714891           Internal Medicine      99220                    N
# 9714892           Internal Medicine      99223                    N
# 9714893           Internal Medicine      99232                    N
# 9714894           Internal Medicine      99233                    N
# 9714895           Internal Medicine      99239                    N
# 9714896           Internal Medicine      99291                    N
#
#          AVERAGE_SUBMITTED_CHRG_AMT  AVERAGE_MEDICARE_PAYMENT_AMT
# 9714847                  120.000000                    116.257826
# 9714848                  110.000000                     14.781538
# 9714849                  178.705333                     45.238667
# 9714850                  271.000000                     66.572414
# 9714851                  371.000000                     92.690000
# 9714852                  112.000000                     26.660000
# 9714853                  201.000000                     47.459615
# 9714854                  815.846154                    100.448462
# 9714855                   34.500000                      6.407500
# 9714856                 1079.916667                     98.710833
# 9714857                 1662.960630                    147.601299
# 9714858                 1942.936709                    194.650886
# 9714859                   55.000000                     28.839600
# 9714860                   71.882353                     41.254314
# 9714861                  323.130435                    177.440000
# 9714862                   36.000000                     13.348421
# 9714863                  147.370909                     51.635455
# 9714864                  205.542105                     59.122105
# 9714865                  139.711864                     51.433874
# 9714866                  195.802574                     70.159926
# 9714867                   52.962264                     26.500000
# 9714868                   55.000000                     26.500000
# 9714869                  189.800000                    131.908400
# 9714870                  103.750000                     79.710000
# 9714871                  257.941176                     83.785882
# 9714872                  171.578947                     61.200000
# 9714873                 1500.000000                    275.793913
# 9714874                 1500.000000                    275.521071
# 9714875                 1573.943662                    265.785775
# 9714876                  284.000000                     42.047500
# 9714877                  284.000000                     79.002778
# 9714878                  652.000000                    187.740000
# 9714879                  346.000000                     62.265600
# 9714880                  346.000000                     91.691091
# 9714881                 1006.416667                    187.091667
# 9714882                  147.000000                     39.280667
# 9714883                   23.000000                      6.840000
# 9714884                  129.000000                     59.610455
# 9714885                  293.000000                     85.118615
# 9714886                  268.000000                     96.071905
# 9714887                  432.000000                    122.707538
# 9714888                  182.000000                     57.084808
# 9714889                  346.000000                     84.107015
# 9714890                  178.000000                     56.780000
# 9714891                  452.000000                    137.439444
# 9714892                  496.000000                    155.637826
# 9714893                  176.000000                     56.270000
# 9714894                  254.000000                     80.918700
# 9714895                  262.000000                     83.393938
# 9714896                  543.058824                    174.520000

# %%
# Check New dataframe

df2.dtypes
# Out:
# ZIP                              object
# NPPES_PROVIDER_STATE             object
# NPI                               int64
# PLACE_OF_SERVICE                 object
# PROVIDER_TYPE                    object
# HCPCS_CODE                       object
# HCPCS_DRUG_INDICATOR             object
# AVERAGE_SUBMITTED_CHRG_AMT      float64
# AVERAGE_MEDICARE_PAYMENT_AMT    float64
# dtype: object

# %%
# Create states list to then exclude US territories

states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
df2 = df2[df2['NPPES_PROVIDER_STATE'].isin(states)]
df2
# Out:
#                  ZIP NPPES_PROVIDER_STATE         NPI PLACE_OF_SERVICE  \
# 1        2.15022e+08                   MD  1003000126                F
# 2        2.15022e+08                   MD  1003000126                F
# 3        2.15022e+08                   MD  1003000126                F
# 4        2.15022e+08                   MD  1003000126                F
# 5        2.15022e+08                   MD  1003000126                F
# ...              ...                  ...         ...              ...
# 9714892    231161844                   VA  1992999874                F
# 9714893    231161844                   VA  1992999874                F
# 9714894    231161844                   VA  1992999874                F
# 9714895    231161844                   VA  1992999874                F
# 9714896    231161844                   VA  1992999874                F
#
#              PROVIDER_TYPE HCPCS_CODE HCPCS_DRUG_INDICATOR  \
# 1        Internal Medicine      99217                    N
# 2        Internal Medicine      99219                    N
# 3        Internal Medicine      99220                    N
# 4        Internal Medicine      99221                    N
# 5        Internal Medicine      99222                    N
# ...                    ...        ...                  ...
# 9714892  Internal Medicine      99223                    N
# 9714893  Internal Medicine      99232                    N
# 9714894  Internal Medicine      99233                    N
# 9714895  Internal Medicine      99239                    N
# 9714896  Internal Medicine      99291                    N
#
#          AVERAGE_SUBMITTED_CHRG_AMT  AVERAGE_MEDICARE_PAYMENT_AMT
# 1                        325.157895                     54.474386
# 2                        614.000000                    105.850000
# 3                        769.347826                    146.116522
# 4                        460.000000                     78.990000
# 5                        625.000000                    105.477604
# ...                             ...                           ...
# 9714892                  496.000000                    155.637826
# 9714893                  176.000000                     56.270000
# 9714894                  254.000000                     80.918700
# 9714895                  262.000000                     83.393938
# 9714896                  543.058824                    174.520000
#
# [9681120 rows x 9 columns]

# %%
# Clean and sort ZIP codes for merging

df2['ZIP'] = df2['ZIP'].astype(str).str[0:5].map(lambda x: str(x.replace('.','')))
df2['ZIP'] = df2['ZIP'].astype(int)
df2 = df2.dropna()
df2.sort_values(by=['ZIP'], inplace=True)
df2
# Out:
#            ZIP NPPES_PROVIDER_STATE         NPI PLACE_OF_SERVICE  \
# 1076716      0                   MA  1114060506                F
# 1076715      0                   MA  1114060506                F
# 1076714      0                   MA  1114060506                F
# 1076713      0                   MA  1114060506                F
# 1076712      0                   MA  1114060506                F
# ...        ...                  ...         ...              ...
# 4239051  99929                   AK  1437252566                O
# 4239050  99929                   AK  1437252566                O
# 2901625  99929                   AK  1295886950                O
# 1062716  99929                   AK  1104982909                F
# 4239068  99929                   AK  1437252566                O
#
#               PROVIDER_TYPE HCPCS_CODE HCPCS_DRUG_INDICATOR  \
# 1076716  Emergency Medicine      99291                    N
# 1076715  Emergency Medicine      99285                    N
# 1076714  Emergency Medicine      99284                    N
# 1076713  Emergency Medicine      99283                    N
# 1076712  Emergency Medicine      99282                    N
# ...                     ...        ...                  ...
# 4239051     Family Practice      80048                    N
# 4239050     Family Practice      36415                    N
# 2901625        Chiropractic      98941                    N
# 1062716     Family Practice      99213                    N
# 4239068     Family Practice      G0439                    N
#
#          AVERAGE_SUBMITTED_CHRG_AMT  AVERAGE_MEDICARE_PAYMENT_AMT
# 1076716                  870.020000                    177.482800
# 1076715                  612.807692                    135.446255
# 1076714                  441.413223                     89.050083
# 1076713                  312.340426                     44.710213
# 1076712                  165.178571                     28.105714
# ...                             ...                           ...
# 4239051                   74.000000                     11.086800
# 4239050                   26.000000                      2.940000
# 2901625                   50.000000                     34.345187
# 1062716                  550.023529                     45.151529
# 4239068                  322.714286                    146.310000
#
# [9681120 rows x 9 columns]

# %%
# Check data

len(df2)
# Out:
# 9681120

# %%
# Check data

df2.dtypes
# Out:
# ZIP                               int64
# NPPES_PROVIDER_STATE             object
# NPI                               int64
# PLACE_OF_SERVICE                 object
# PROVIDER_TYPE                    object
# HCPCS_CODE                       object
# HCPCS_DRUG_INDICATOR             object
# AVERAGE_SUBMITTED_CHRG_AMT      float64
# AVERAGE_MEDICARE_PAYMENT_AMT    float64
# dtype: object

# %%
# Read ZIP data file and store into pandas data frame

df3 = pd.read_csv('../Final_project_BigData/ZIP-COUNTY-FIPS.csv') 
df3.dtypes
# Out:
# ZIP            int64
# COUNTYNAME    object
# STATE         object
# STCOUNTYFP     int64
# CLASSFP       object
# dtype: object

# %%
# Check data

len(df3)
# Out:
# 52889

# %%
# Create states list to then exclude US territories

df3 = df3[df3['STATE'].isin(states)]
df3
# Out:
#          ZIP      COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0      36003  Autauga County    AL        1001      H1
# 1      36006  Autauga County    AL        1001      H1
# 2      36067  Autauga County    AL        1001      H1
# 3      36066  Autauga County    AL        1001      H1
# 4      36703  Autauga County    AL        1001      H1
# ...      ...             ...   ...         ...     ...
# 52566  82729   Weston County    WY       56045      H1
# 52567  82730   Weston County    WY       56045      H1
# 52568  82701   Weston County    WY       56045      H1
# 52569  82723   Weston County    WY       56045      H1
# 52570  82715   Weston County    WY       56045      H1
#
# [52571 rows x 5 columns]

# %%
# Select column for the merge

df3 = df3[['ZIP','COUNTYNAME']]
df3.sort_values(by=['ZIP'], inplace=True)
df3
# Out:
# <ipython-input-18-9fb1020b0784>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.sort_values(by=['ZIP'], inplace=True)
#          ZIP                         COUNTYNAME
# 32368    501                     Suffolk County
# 20964   1001                     Hampden County
# 20940   1002                    Franklin County
# 21018   1002                   Hampshire County
# 21028   1003                   Hampshire County
# ...      ...                                ...
# 1300   99925  Prince of Wales-Hyder Census Area
# 1296   99926  Prince of Wales-Hyder Census Area
# 1295   99927  Prince of Wales-Hyder Census Area
# 1227   99928          Ketchikan Gateway Borough
# 1333   99929          Wrangell City and Borough
#
# [52571 rows x 2 columns]

# %%
# Check data

df3.dtypes
# Out:
# ZIP            int64
# COUNTYNAME    object
# dtype: object

# %%
# Merge dataframes by Zipcode

dfinal= pd.merge_asof(df2, df3, on='ZIP')

# %%
# Sort Data by NPI number

dfinal.sort_values(by=['NPI'], inplace=True)
dfinal.head(100)
# Out:
#            ZIP NPPES_PROVIDER_STATE         NPI PLACE_OF_SERVICE  \
# 1623717  21502                   MD  1003000126                F
# 1623716  21502                   MD  1003000126                F
# 1623703  21502                   MD  1003000126                F
# 1626636  21502                   MD  1003000126                F
# 1623702  21502                   MD  1003000126                F
# ...        ...                  ...         ...              ...
# 7118375  74104                   OK  1003000597                O
# 7118362  74104                   OK  1003000597                O
# 7118373  74104                   OK  1003000597                F
# 7118371  74104                   OK  1003000597                F
# 7118370  74104                   OK  1003000597                F
#
#              PROVIDER_TYPE HCPCS_CODE HCPCS_DRUG_INDICATOR  \
# 1623717  Internal Medicine      99222                    N
# 1623716  Internal Medicine      99221                    N
# 1623703  Internal Medicine      99220                    N
# 1626636  Internal Medicine      99217                    N
# 1623702  Internal Medicine      99219                    N
# ...                    ...        ...                  ...
# 7118375            Urology      52000                    N
# 7118362            Urology      81003                    N
# 7118373            Urology      52332                    N
# 7118371            Urology      52356                    N
# 7118370            Urology      74420                    N
#
#          AVERAGE_SUBMITTED_CHRG_AMT  AVERAGE_MEDICARE_PAYMENT_AMT  \
# 1623717                  625.000000                    105.477604
# 1623716                  460.000000                     78.990000
# 1623703                  769.347826                    146.116522
# 1626636                  325.157895                     54.474386
# 1623702                  614.000000                    105.850000
# ...                             ...                           ...
# 7118375                  422.000000                    139.788652
# 7118362                    7.000000                      3.000000
# 7118373                 1002.450000                     98.267250
# 7118371                  904.000000                    321.560000
# 7118370                   39.000000                     12.749667
#
#               COUNTYNAME
# 1623717  Allegany County
# 1623716  Allegany County
# 1623703  Allegany County
# 1626636  Allegany County
# 1623702  Allegany County
# ...                  ...
# 7118375     Tulsa County
# 7118362     Tulsa County
# 7118373     Tulsa County
# 7118371     Tulsa County
# 7118370     Tulsa County
#
# [100 rows x 10 columns]

# %%
# Check data

len(dfinal)
# Out:
# 9681120

# %%
# Create Dataframe 

df_2016 = dfinal.groupby(['NPPES_PROVIDER_STATE', 'COUNTYNAME', 'ZIP', 'PROVIDER_TYPE', 'PLACE_OF_SERVICE']).agg({'AVERAGE_SUBMITTED_CHRG_AMT': ['mean'], 'AVERAGE_MEDICARE_PAYMENT_AMT': ['mean']})
df_2016.columns = ['Avg Submit 2016', 'Avg Payment 2016']
df_2016 = df_2016.reset_index()

df_2016.head(50)
# Out:
#    NPPES_PROVIDER_STATE                  COUNTYNAME    ZIP  \
# 0                    AK      Aleutians East Borough  99571
# 1                    AK      Aleutians East Borough  99612
# 2                    AK      Aleutians East Borough  99612
# 3                    AK      Aleutians East Borough  99661
# 4                    AK      Aleutians East Borough  99661
# 5                    AK  Aleutians West Census Area  99660
# 6                    AK  Aleutians West Census Area  99685
# 7                    AK  Aleutians West Census Area  99685
# 8                    AK      Anchorage Municipality  99501
# 9                    AK      Anchorage Municipality  99501
# 10                   AK      Anchorage Municipality  99501
# 11                   AK      Anchorage Municipality  99501
# 12                   AK      Anchorage Municipality  99501
# 13                   AK      Anchorage Municipality  99501
# 14                   AK      Anchorage Municipality  99501
# 15                   AK      Anchorage Municipality  99501
# 16                   AK      Anchorage Municipality  99501
# 17                   AK      Anchorage Municipality  99501
# 18                   AK      Anchorage Municipality  99501
# 19                   AK      Anchorage Municipality  99501
# 20                   AK      Anchorage Municipality  99501
# 21                   AK      Anchorage Municipality  99501
# 22                   AK      Anchorage Municipality  99501
# 23                   AK      Anchorage Municipality  99501
# 24                   AK      Anchorage Municipality  99502
# 25                   AK      Anchorage Municipality  99502
# 26                   AK      Anchorage Municipality  99502
# 27                   AK      Anchorage Municipality  99502
# 28                   AK      Anchorage Municipality  99502
# 29                   AK      Anchorage Municipality  99502
# 30                   AK      Anchorage Municipality  99502
# 31                   AK      Anchorage Municipality  99503
# 32                   AK      Anchorage Municipality  99503
# 33                   AK      Anchorage Municipality  99503
# 34                   AK      Anchorage Municipality  99503
# 35                   AK      Anchorage Municipality  99503
# 36                   AK      Anchorage Municipality  99503
# 37                   AK      Anchorage Municipality  99503
# 38                   AK      Anchorage Municipality  99503
# 39                   AK      Anchorage Municipality  99503
# 40                   AK      Anchorage Municipality  99503
# 41                   AK      Anchorage Municipality  99503
# 42                   AK      Anchorage Municipality  99503
# 43                   AK      Anchorage Municipality  99503
# 44                   AK      Anchorage Municipality  99503
# 45                   AK      Anchorage Municipality  99503
# 46                   AK      Anchorage Municipality  99503
# 47                   AK      Anchorage Municipality  99503
# 48                   AK      Anchorage Municipality  99503
# 49                   AK      Anchorage Municipality  99503
#
#                                      PROVIDER_TYPE PLACE_OF_SERVICE  \
# 0                              Physician Assistant                O
# 1                               Nurse Practitioner                O
# 2                              Physician Assistant                O
# 3                              Physician Assistant                F
# 4                              Physician Assistant                O
# 5                              Physician Assistant                O
# 6                               Nurse Practitioner                O
# 7                              Physician Assistant                F
# 8                       Ambulance Service Provider                F
# 9                       Ambulatory Surgical Center                F
# 10                                  Anesthesiology                F
# 11   Certified Registered Nurse Anesthetist (CRNA)                F
# 12                                    Chiropractic                O
# 13                                 Family Practice                F
# 14                                 Family Practice                O
# 15                               Internal Medicine                O
# 16                 Licensed Clinical Social Worker                F
# 17                 Licensed Clinical Social Worker                O
# 18                              Nurse Practitioner                O
# 19                                   Ophthalmology                F
# 20                                   Ophthalmology                O
# 21                                       Optometry                O
# 22               Osteopathic Manipulative Medicine                O
# 23          Physical Therapist in Private Practice                O
# 24                      Ambulance Service Provider                F
# 25                                  Anesthesiology                F
# 26                                    Chiropractic                O
# 27                                 Family Practice                F
# 28                                 Family Practice                O
# 29                                General Practice                O
# 30                              Nurse Practitioner                O
# 31                                  Anesthesiology                F
# 32                                     Audiologist                O
# 33                                 Centralized Flu                O
# 34                                    Chiropractic                O
# 35                             Clinical Laboratory                O
# 36                    Critical Care (Intensivists)                F
# 37                                     Dermatology                O
# 38                                 Family Practice                F
# 39                                 Family Practice                O
# 40                                 General Surgery                O
# 41                             Hematology-Oncology                F
# 42  Independent Diagnostic Testing Facility (IDTF)                O
# 43                               Internal Medicine                F
# 44                    Mass Immunizer Roster Biller                O
# 45                                       Neurology                F
# 46                              Nurse Practitioner                F
# 47                              Nurse Practitioner                O
# 48                                       Optometry                O
# 49            Physical Medicine and Rehabilitation                F
#
#     Avg Submit 2016  Avg Payment 2016
# 0         99.000000         50.821318
# 1        118.331705         30.980826
# 2         60.349183          7.126193
# 3        216.142857         45.142286
# 4        195.000000         48.481250
# 5         94.456071         44.815154
# 6        170.232143         25.845988
# 7        162.487179         28.857517
# 8        605.308058        296.130643
# 9       2215.704286        661.193805
# 10      1408.351973        243.520306
# 11      1454.956140        278.410852
# 12        70.000000         34.025909
# 13       147.117333         90.740000
# 14       101.833333         10.967641
# 15       123.256442         39.058990
# 16       115.000000         87.154667
# 17       169.425919         40.870329
# 18       166.661130         34.879086
# 19      4466.253374        666.951586
# 20       366.666787         80.163485
# 21       239.380204         66.304226
# 22       562.333333         63.066667
# 23        99.259259         34.585859
# 24      4742.279547       1179.122820
# 25      1219.636099         90.501129
# 26        60.000000         35.085000
# 27       299.289916         88.627689
# 28       102.493420         29.983605
# 29       109.423077         32.867382
# 30       151.208333         36.192355
# 31       690.765972         68.220049
# 32        97.500000         24.010528
# 33        48.510842         44.952438
# 34        60.412240         30.950996
# 35        95.166743         14.299696
# 36       795.097564        119.346659
# 37       452.527539         92.576385
# 38       471.847829        101.270676
# 39       118.663993         16.917080
# 40       123.220417         88.281607
# 41       203.800000         49.593500
# 42      3678.556992        574.885565
# 43       526.550619        112.166220
# 44        52.898105         51.507556
# 45       500.501636         72.816399
# 46       252.467386         59.217888
# 47       222.210112         72.005920
# 48       197.633959         66.269506
# 49       600.281818        133.106793

# %%
# Check data

len(df_2016)
# Out:
# 348582

# %%
# Save dataframe as CSV

df_2016.to_csv('2016.csv')
