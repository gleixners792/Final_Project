# %%
# Dependencies

import pandas as pd
import numpy as np

# %%
# Read data file and store into pandas data frame.

df = pd.read_csv("2013/Medicare_Provider_Util_Payment_PUF_CY2013/Medicare_Provider_Util_Payment_PUF_CY2013.txt", sep="\t", header=0)
# Out:
# /Users/diegogonzalez/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Check data

df.dtypes
# Out:
# NPI                                   int64
# NPPES_PROVIDER_LAST_ORG_NAME         object
# NPPES_PROVIDER_FIRST_NAME            object
# NPPES_PROVIDER_MI                    object
# NPPES_CREDENTIALS                    object
# NPPES_PROVIDER_GENDER                object
# NPPES_ENTITY_CODE                    object
# NPPES_PROVIDER_STREET1               object
# NPPES_PROVIDER_STREET2               object
# NPPES_PROVIDER_CITY                  object
# NPPES_PROVIDER_ZIP                   object
# NPPES_PROVIDER_STATE                 object
# NPPES_PROVIDER_COUNTRY               object
# PROVIDER_TYPE                        object
# MEDICARE_PARTICIPATION_INDICATOR     object
# PLACE_OF_SERVICE                     object
# HCPCS_CODE                           object
# HCPCS_DESCRIPTION                    object
# HCPCS_DRUG_INDICATOR                 object
# LINE_SRVC_CNT                       float64
# BENE_UNIQUE_CNT                     float64
# BENE_DAY_SRVC_CNT                   float64
# AVERAGE_MEDICARE_ALLOWED_AMT        float64
# STDEV_MEDICARE_ALLOWED_AMT          float64
# AVERAGE_SUBMITTED_CHRG_AMT          float64
# STDEV_SUBMITTED_CHRG_AMT            float64
# AVERAGE_MEDICARE_PAYMENT_AMT        float64
# STDEV_MEDICARE_PAYMENT_AMT          float64
# dtype: object

# %%
# Check Data

len(df)
# Out:
# 9287877

# %%
# Select only US

df1= df[df.NPPES_PROVIDER_COUNTRY == 'US']
df1
# Out:
#                 NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 1        1003000126                    ENKESHAFI                   ARDALAN
# 2        1003000126                    ENKESHAFI                   ARDALAN
# 3        1003000126                    ENKESHAFI                   ARDALAN
# 4        1003000126                    ENKESHAFI                   ARDALAN
# 5        1003000126                    ENKESHAFI                   ARDALAN
# ...             ...                          ...                       ...
# 9287872  1992999874                        JOFFE                 GABRIELLA
# 9287873  1992999874                        JOFFE                 GABRIELLA
# 9287874  1992999874                        JOFFE                 GABRIELLA
# 9287875  1992999874                        JOFFE                 GABRIELLA
# 9287876  1992999874                        JOFFE                 GABRIELLA
#
#         NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER  \
# 1                     NaN              M.D.                     M
# 2                     NaN              M.D.                     M
# 3                     NaN              M.D.                     M
# 4                     NaN              M.D.                     M
# 5                     NaN              M.D.                     M
# ...                   ...               ...                   ...
# 9287872               NaN               NaN                     F
# 9287873               NaN               NaN                     F
# 9287874               NaN               NaN                     F
# 9287875               NaN               NaN                     F
# 9287876               NaN               NaN                     F
#
#         NPPES_ENTITY_CODE NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2  \
# 1                       I           900 SETON DR                    NaN
# 2                       I           900 SETON DR                    NaN
# 3                       I           900 SETON DR                    NaN
# 4                       I           900 SETON DR                    NaN
# 5                       I           900 SETON DR                    NaN
# ...                   ...                    ...                    ...
# 9287872                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9287873                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9287874                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9287875                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9287876                 I          8260 ATLEE RD       MOB 2, SUITE 319
#
#         NPPES_PROVIDER_CITY  ... HCPCS_DRUG_INDICATOR LINE_SRVC_CNT  \
# 1                CUMBERLAND  ...                    N         142.0
# 2                CUMBERLAND  ...                    N          96.0
# 3                CUMBERLAND  ...                    N          61.0
# 4                CUMBERLAND  ...                    N         777.0
# 5                CUMBERLAND  ...                    N         170.0
# ...                     ...  ...                  ...           ...
# 9287872      MECHANICSVILLE  ...                    N         169.0
# 9287873      MECHANICSVILLE  ...                    N         317.0
# 9287874      MECHANICSVILLE  ...                    N         275.0
# 9287875      MECHANICSVILLE  ...                    N         145.0
# 9287876      MECHANICSVILLE  ...                    N          23.0
#
#         BENE_UNIQUE_CNT BENE_DAY_SRVC_CNT AVERAGE_MEDICARE_ALLOWED_AMT  \
# 1                 138.0             142.0                   136.452324
# 2                  95.0              96.0                   201.320000
# 3                  47.0              61.0                    38.740000
# 4                 381.0             777.0                    71.270000
# 5                 106.0             170.0                   102.760000
# ...                 ...               ...                          ...
# 9287872           166.0             169.0                   194.050000
# 9287873           174.0             317.0                    68.890000
# 9287874           155.0             275.0                    99.280000
# 9287875           144.0             145.0                   102.950000
# 9287876            19.0              23.0                   213.410000
#
#         STDEV_MEDICARE_ALLOWED_AMT AVERAGE_SUBMITTED_CHRG_AMT  \
# 1                         6.028319                 368.626761
# 2                         0.000000                 524.604167
# 3                         0.000000                  97.000000
# 4                         0.000000                 187.594595
# 5                         0.000000                 271.976471
# ...                            ...                        ...
# 9287872                   0.000000                 496.000000
# 9287873                   0.000000                 176.640379
# 9287874                   0.000000                 254.000000
# 9287875                   0.000000                 262.000000
# 9287876                   0.000000                 548.608696
#
#         STDEV_SUBMITTED_CHRG_AMT AVERAGE_MEDICARE_PAYMENT_AMT  \
# 1                      89.642452                   104.299718
# 2                     141.760470                   155.901146
# 3                      29.291637                    30.065246
# 4                      49.282122                    55.091351
# 5                      69.870801                    80.641235
# ...                          ...                          ...
# 9287872                 0.000000                   153.187574
# 9287873                 6.174386                    54.082208
# 9287874                 0.000000                    77.772473
# 9287875                 0.000000                    81.017241
# 9287876                 2.497636                   169.099130
#
#          STDEV_MEDICARE_PAYMENT_AMT
# 1                         17.890405
# 2                         19.510660
# 3                          3.891932
# 4                          7.631141
# 5                          4.303711
# ...                             ...
# 9287872                    1.674093
# 9287873                    2.160302
# 9287874                    4.528083
# 9287875                    0.642301
# 9287876                    1.703388
#
# [9287471 rows x 28 columns]

# %%
# Create ZIP Column

df1['ZIP'] = df1['NPPES_PROVIDER_ZIP']
df1.head(5)
# Out:
# <ipython-input-6-189a4acb3a75>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ZIP'] = df1['NPPES_PROVIDER_ZIP']
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  ...  \
# 1           900 SETON DR                    NaN          CUMBERLAND  ...
# 2           900 SETON DR                    NaN          CUMBERLAND  ...
# 3           900 SETON DR                    NaN          CUMBERLAND  ...
# 4           900 SETON DR                    NaN          CUMBERLAND  ...
# 5           900 SETON DR                    NaN          CUMBERLAND  ...
#
#   LINE_SRVC_CNT BENE_UNIQUE_CNT BENE_DAY_SRVC_CNT  \
# 1         142.0           138.0             142.0
# 2          96.0            95.0              96.0
# 3          61.0            47.0              61.0
# 4         777.0           381.0             777.0
# 5         170.0           106.0             170.0
#
#   AVERAGE_MEDICARE_ALLOWED_AMT STDEV_MEDICARE_ALLOWED_AMT  \
# 1                   136.452324                   6.028319
# 2                   201.320000                   0.000000
# 3                    38.740000                   0.000000
# 4                    71.270000                   0.000000
# 5                   102.760000                   0.000000
#
#   AVERAGE_SUBMITTED_CHRG_AMT STDEV_SUBMITTED_CHRG_AMT  \
# 1                 368.626761                89.642452
# 2                 524.604167               141.760470
# 3                  97.000000                29.291637
# 4                 187.594595                49.282122
# 5                 271.976471                69.870801
#
#   AVERAGE_MEDICARE_PAYMENT_AMT STDEV_MEDICARE_PAYMENT_AMT          ZIP
# 1                   104.299718                  17.890405  2.15022e+08
# 2                   155.901146                  19.510660  2.15022e+08
# 3                    30.065246                   3.891932  2.15022e+08
# 4                    55.091351                   7.631141  2.15022e+08
# 5                    80.641235                   4.303711  2.15022e+08
#
# [5 rows x 29 columns]

# %%
# Check Data

df1.dtypes
# Out:
# NPI                                   int64
# NPPES_PROVIDER_LAST_ORG_NAME         object
# NPPES_PROVIDER_FIRST_NAME            object
# NPPES_PROVIDER_MI                    object
# NPPES_CREDENTIALS                    object
# NPPES_PROVIDER_GENDER                object
# NPPES_ENTITY_CODE                    object
# NPPES_PROVIDER_STREET1               object
# NPPES_PROVIDER_STREET2               object
# NPPES_PROVIDER_CITY                  object
# NPPES_PROVIDER_ZIP                   object
# NPPES_PROVIDER_STATE                 object
# NPPES_PROVIDER_COUNTRY               object
# PROVIDER_TYPE                        object
# MEDICARE_PARTICIPATION_INDICATOR     object
# PLACE_OF_SERVICE                     object
# HCPCS_CODE                           object
# HCPCS_DESCRIPTION                    object
# HCPCS_DRUG_INDICATOR                 object
# LINE_SRVC_CNT                       float64
# BENE_UNIQUE_CNT                     float64
# BENE_DAY_SRVC_CNT                   float64
# AVERAGE_MEDICARE_ALLOWED_AMT        float64
# STDEV_MEDICARE_ALLOWED_AMT          float64
# AVERAGE_SUBMITTED_CHRG_AMT          float64
# STDEV_SUBMITTED_CHRG_AMT            float64
# AVERAGE_MEDICARE_PAYMENT_AMT        float64
# STDEV_MEDICARE_PAYMENT_AMT          float64
# ZIP                                  object
# dtype: object

# %%
# Check unique ZIPs

df1['ZIP'].unique
# Out:
# <bound method Series.unique of 1          2.15022e+08
# 2          2.15022e+08
# 3          2.15022e+08
# 4          2.15022e+08
# 5          2.15022e+08
#               ...
# 9287872      231161844
# 9287873      231161844
# 9287874      231161844
# 9287875      231161844
# 9287876      231161844
# Name: ZIP, Length: 9287471, dtype: object>

# %%
# Create new dataframe with selected columns

df2 = df1[['ZIP','NPPES_PROVIDER_STATE', 'NPI', 'PLACE_OF_SERVICE','PROVIDER_TYPE', 'HCPCS_CODE', 'HCPCS_DRUG_INDICATOR', 'AVERAGE_SUBMITTED_CHRG_AMT', 'STDEV_MEDICARE_PAYMENT_AMT']]
df2.tail(50)
# Out:
#                ZIP NPPES_PROVIDER_STATE         NPI PLACE_OF_SERVICE  \
# 9287827  448706062                   OH  1992999452                O
# 9287828  208741214                   MD  1992999551                O
# 9287829  208741214                   MD  1992999551                O
# 9287830  208741214                   MD  1992999551                O
# 9287831  208741214                   MD  1992999551                O
# 9287832  208741214                   MD  1992999551                O
# 9287833  208741214                   MD  1992999551                O
# 9287834  208741214                   MD  1992999551                O
# 9287835  208741214                   MD  1992999551                O
# 9287836  208741214                   MD  1992999551                O
# 9287837  208741214                   MD  1992999551                O
# 9287838  208741214                   MD  1992999551                O
# 9287839  208741214                   MD  1992999551                O
# 9287840  208741214                   MD  1992999551                O
# 9287841  208741214                   MD  1992999551                O
# 9287842  208741214                   MD  1992999551                O
# 9287843  208741214                   MD  1992999551                O
# 9287844  208741214                   MD  1992999551                O
# 9287845  208741214                   MD  1992999551                O
# 9287846  208741214                   MD  1992999551                O
# 9287847  941342809                   CA  1992999569                O
# 9287848  941342809                   CA  1992999569                O
# 9287849  941342809                   CA  1992999569                O
# 9287850  941342809                   CA  1992999569                O
# 9287851  177011932                   PA  1992999585                O
# 9287852  177011932                   PA  1992999585                O
# 9287853  974014604                   OR  1992999775                F
# 9287854  974014604                   OR  1992999775                F
# 9287855  974014604                   OR  1992999775                F
# 9287856  981012756                   WA  1992999825                F
# 9287857  981012756                   WA  1992999825                O
# 9287858  981012756                   WA  1992999825                F
# 9287859  981012756                   WA  1992999825                F
# 9287860  981012756                   WA  1992999825                O
# 9287861  981012756                   WA  1992999825                O
# 9287862  981012756                   WA  1992999825                O
# 9287863  981012756                   WA  1992999825                O
# 9287864  981012756                   WA  1992999825                O
# 9287865  981012756                   WA  1992999825                F
# 9287866  981012756                   WA  1992999825                O
# 9287867  981012756                   WA  1992999825                O
# 9287868  981012756                   WA  1992999825                F
# 9287869  981012756                   WA  1992999825                O
# 9287870  231161844                   VA  1992999874                F
# 9287871  231161844                   VA  1992999874                F
# 9287872  231161844                   VA  1992999874                F
# 9287873  231161844                   VA  1992999874                F
# 9287874  231161844                   VA  1992999874                F
# 9287875  231161844                   VA  1992999874                F
# 9287876  231161844                   VA  1992999874                F
#
#                       PROVIDER_TYPE HCPCS_CODE HCPCS_DRUG_INDICATOR  \
# 9287827                Chiropractic      98941                    N
# 9287828           Internal Medicine      36415                    N
# 9287829           Internal Medicine      80048                    N
# 9287830           Internal Medicine      80061                    N
# 9287831           Internal Medicine      80076                    N
# 9287832           Internal Medicine      81003                    N
# 9287833           Internal Medicine      82043                    N
# 9287834           Internal Medicine      82570                    N
# 9287835           Internal Medicine      83036                    N
# 9287836           Internal Medicine      84443                    N
# 9287837           Internal Medicine      84450                    N
# 9287838           Internal Medicine      84460                    N
# 9287839           Internal Medicine      85025                    N
# 9287840           Internal Medicine      90662                    Y
# 9287841           Internal Medicine      93000                    N
# 9287842           Internal Medicine      99202                    N
# 9287843           Internal Medicine      99213                    N
# 9287844           Internal Medicine      99214                    N
# 9287845           Internal Medicine      G0008                    N
# 9287846           Internal Medicine      G0439                    N
# 9287847                   Optometry      92004                    N
# 9287848                   Optometry      92012                    N
# 9287849                   Optometry      92014                    N
# 9287850                   Optometry      99213                    N
# 9287851                Chiropractic      98940                    N
# 9287852                Chiropractic      98941                    N
# 9287853  Ambulatory Surgical Center      62310                    N
# 9287854  Ambulatory Surgical Center      62311                    N
# 9287855  Ambulatory Surgical Center      64483                    N
# 9287856              Otolaryngology      31231                    N
# 9287857              Otolaryngology      31231                    N
# 9287858              Otolaryngology      31237                    N
# 9287859              Otolaryngology      31575                    N
# 9287860              Otolaryngology      31575                    N
# 9287861              Otolaryngology      36415                    N
# 9287862              Otolaryngology      69210                    N
# 9287863              Otolaryngology      82565                    N
# 9287864              Otolaryngology      99203                    N
# 9287865              Otolaryngology      99204                    N
# 9287866              Otolaryngology      99204                    N
# 9287867              Otolaryngology      99213                    N
# 9287868              Otolaryngology      99214                    N
# 9287869              Otolaryngology      99214                    N
# 9287870           Internal Medicine      99220                    N
# 9287871           Internal Medicine      99221                    N
# 9287872           Internal Medicine      99223                    N
# 9287873           Internal Medicine      99232                    N
# 9287874           Internal Medicine      99233                    N
# 9287875           Internal Medicine      99239                    N
# 9287876           Internal Medicine      99291                    N
#
#          AVERAGE_SUBMITTED_CHRG_AMT  STDEV_MEDICARE_PAYMENT_AMT
# 9287827                   55.000000                    7.252225
# 9287828                   20.000000                    0.189942
# 9287829                   55.000000                    2.167419
# 9287830                   50.000000                    2.560180
# 9287831                   52.000000                    1.538757
# 9287832                   16.000000                    0.544498
# 9287833                   35.000000                    0.063213
# 9287834                   41.000000                    0.055311
# 9287835                   50.000000                    1.880387
# 9287836                   50.000000                    0.201990
# 9287837                   24.000000                    0.313537
# 9287838                   25.000000                    0.324890
# 9287839                   32.000000                    1.442172
# 9287840                   37.068966                    0.418275
# 9287841                   80.000000                    2.988121
# 9287842                  121.000000                   27.964312
# 9287843                  116.000000                   20.604654
# 9287844                  173.000000                   33.686621
# 9287845                   30.970588                    0.086168
# 9287846                  142.575758                    0.975807
# 9287847                  205.000000                   33.132045
# 9287848                  120.000000                    0.000000
# 9287849                  170.000000                   30.710593
# 9287850                   95.000000                    0.000000
# 9287851                   30.000000                    7.501760
# 9287852                   40.000000                    4.097938
# 9287853                 1500.000000                    8.382208
# 9287854                 1500.000000                   31.924145
# 9287855                 1500.000000                   49.149330
# 9287856                  563.000000                   16.719054
# 9287857                  563.000000                    0.000000
# 9287858                 1134.142857                   39.148930
# 9287859                  329.000000                    7.371845
# 9287860                  329.000000                   13.529634
# 9287861                   16.000000                    0.022361
# 9287862                  143.000000                   10.628558
# 9287863                   28.000000                    0.000000
# 9287864                  271.000000                   32.841160
# 9287865                  240.000000                   18.715677
# 9287866                  399.000000                   17.510341
# 9287867                  217.000000                   19.450793
# 9287868                  161.000000                   19.407902
# 9287869                  320.000000                   20.580265
# 9287870                  452.000000                    0.784935
# 9287871                  248.153846                    0.413028
# 9287872                  496.000000                    1.674093
# 9287873                  176.640379                    2.160302
# 9287874                  254.000000                    4.528083
# 9287875                  262.000000                    0.642301
# 9287876                  548.608696                    1.703388

# %%
# Check New dataframe

df2.dtypes
# Out:
# ZIP                            object
# NPPES_PROVIDER_STATE           object
# NPI                             int64
# PLACE_OF_SERVICE               object
# PROVIDER_TYPE                  object
# HCPCS_CODE                     object
# HCPCS_DRUG_INDICATOR           object
# AVERAGE_SUBMITTED_CHRG_AMT    float64
# STDEV_MEDICARE_PAYMENT_AMT    float64
# dtype: object

# %%
# Create states list to then exclude US territories

states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
df2 = df2[df2['NPPES_PROVIDER_STATE'].isin(states)]
df2
# Out:
#                  ZIP NPPES_PROVIDER_STATE         NPI PLACE_OF_SERVICE  \
# 1        2.15022e+08                   MD  1003000126                F
# 2        2.15022e+08                   MD  1003000126                F
# 3        2.15022e+08                   MD  1003000126                F
# 4        2.15022e+08                   MD  1003000126                F
# 5        2.15022e+08                   MD  1003000126                F
# ...              ...                  ...         ...              ...
# 9287872    231161844                   VA  1992999874                F
# 9287873    231161844                   VA  1992999874                F
# 9287874    231161844                   VA  1992999874                F
# 9287875    231161844                   VA  1992999874                F
# 9287876    231161844                   VA  1992999874                F
#
#              PROVIDER_TYPE HCPCS_CODE HCPCS_DRUG_INDICATOR  \
# 1        Internal Medicine      99222                    N
# 2        Internal Medicine      99223                    N
# 3        Internal Medicine      99231                    N
# 4        Internal Medicine      99232                    N
# 5        Internal Medicine      99233                    N
# ...                    ...        ...                  ...
# 9287872  Internal Medicine      99223                    N
# 9287873  Internal Medicine      99232                    N
# 9287874  Internal Medicine      99233                    N
# 9287875  Internal Medicine      99239                    N
# 9287876  Internal Medicine      99291                    N
#
#          AVERAGE_SUBMITTED_CHRG_AMT  STDEV_MEDICARE_PAYMENT_AMT
# 1                        368.626761                   17.890405
# 2                        524.604167                   19.510660
# 3                         97.000000                    3.891932
# 4                        187.594595                    7.631141
# 5                        271.976471                    4.303711
# ...                             ...                         ...
# 9287872                  496.000000                    1.674093
# 9287873                  176.640379                    2.160302
# 9287874                  254.000000                    4.528083
# 9287875                  262.000000                    0.642301
# 9287876                  548.608696                    1.703388
#
# [9250845 rows x 9 columns]

# %%
# Clean and sort ZIP codes for merging

df2['ZIP'] = df2['ZIP'].astype(str).str[0:5].map(lambda x: str(x.replace('.','')))
df2['ZIP'] = df2['ZIP'].astype(int)
df2 = df2.dropna()
df2.sort_values(by=['ZIP'], inplace=True)
df2
# Out:
#            ZIP NPPES_PROVIDER_STATE         NPI PLACE_OF_SERVICE  \
# 1033411      0                   MA  1114060506                F
# 1033409      0                   MA  1114060506                F
# 1033408      0                   MA  1114060506                F
# 1033412      0                   MA  1114060506                F
# 1033407      0                   MA  1114060506                F
# ...        ...                  ...         ...              ...
# 6753340  99929                   AK  1720144520                O
# 7634998  99929                   AK  1821041666                F
# 1018505  99929                   AK  1104982909                F
# 1018504  99929                   AK  1104982909                O
# 6753341  99929                   AK  1720144520                F
#
#                              PROVIDER_TYPE HCPCS_CODE HCPCS_DRUG_INDICATOR  \
# 1033411  Osteopathic Manipulative Medicine      99285                    N
# 1033409  Osteopathic Manipulative Medicine      99283                    N
# 1033408  Osteopathic Manipulative Medicine      99282                    N
# 1033412  Osteopathic Manipulative Medicine      99291                    N
# 1033407  Osteopathic Manipulative Medicine      93010                    N
# ...                                    ...        ...                  ...
# 6753340                    Family Practice      82962                    N
# 7634998                    Family Practice      99232                    N
# 1018505                    Family Practice      99214                    N
# 1018504                    Family Practice      99213                    N
# 6753341                    Family Practice      99222                    N
#
#          AVERAGE_SUBMITTED_CHRG_AMT  STDEV_MEDICARE_PAYMENT_AMT
# 1033411                  493.559701                   11.402637
# 1033409                  260.562500                    0.320797
# 1033408                  134.740741                    8.343193
# 1033412                  715.065217                   16.818090
# 1033407                   17.435146                    1.810957
# ...                             ...                         ...
# 6753340                   20.625000                    0.016536
# 7634998                  218.125000                   14.654401
# 1018505                  215.000000                   20.823442
# 1018504                  148.000000                   22.721738
# 6753341                  383.000000                   12.348309
#
# [9250845 rows x 9 columns]

# %%
# Check data

len(df2)
# Out:
# 9250845

# %%
# Check data

df2.dtypes
# Out:
# ZIP                             int64
# NPPES_PROVIDER_STATE           object
# NPI                             int64
# PLACE_OF_SERVICE               object
# PROVIDER_TYPE                  object
# HCPCS_CODE                     object
# HCPCS_DRUG_INDICATOR           object
# AVERAGE_SUBMITTED_CHRG_AMT    float64
# STDEV_MEDICARE_PAYMENT_AMT    float64
# dtype: object

# %%
# Read ZIP data file and store into pandas data frame

df3 = pd.read_csv('../Final_project_BigData/ZIP-COUNTY-FIPS.csv') 
df3.dtypes
# Out:
# ZIP            int64
# COUNTYNAME    object
# STATE         object
# STCOUNTYFP     int64
# CLASSFP       object
# dtype: object

# %%
# Check data

len(df3)
# Out:
# 52889

# %%
# Create states list to then exclude US territories

df3 = df3[df3['STATE'].isin(states)]
df3
# Out:
#          ZIP      COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0      36003  Autauga County    AL        1001      H1
# 1      36006  Autauga County    AL        1001      H1
# 2      36067  Autauga County    AL        1001      H1
# 3      36066  Autauga County    AL        1001      H1
# 4      36703  Autauga County    AL        1001      H1
# ...      ...             ...   ...         ...     ...
# 52566  82729   Weston County    WY       56045      H1
# 52567  82730   Weston County    WY       56045      H1
# 52568  82701   Weston County    WY       56045      H1
# 52569  82723   Weston County    WY       56045      H1
# 52570  82715   Weston County    WY       56045      H1
#
# [52571 rows x 5 columns]

# %%
# Select column for the merge

df3 = df3[['ZIP','COUNTYNAME']]
df3.sort_values(by=['ZIP'], inplace=True)
df3
# Out:
# <ipython-input-18-9fb1020b0784>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.sort_values(by=['ZIP'], inplace=True)
#          ZIP                         COUNTYNAME
# 32368    501                     Suffolk County
# 20964   1001                     Hampden County
# 20940   1002                    Franklin County
# 21018   1002                   Hampshire County
# 21028   1003                   Hampshire County
# ...      ...                                ...
# 1300   99925  Prince of Wales-Hyder Census Area
# 1296   99926  Prince of Wales-Hyder Census Area
# 1295   99927  Prince of Wales-Hyder Census Area
# 1227   99928          Ketchikan Gateway Borough
# 1333   99929          Wrangell City and Borough
#
# [52571 rows x 2 columns]

# %%
# Check data

df3.dtypes
# Out:
# ZIP            int64
# COUNTYNAME    object
# dtype: object

# %%
# Merge dataframes by Zipcode

dfinal= pd.merge_asof(df2, df3, on='ZIP')

# %%
# Sort Data by NPI number

dfinal.sort_values(by=['NPI'], inplace=True)
dfinal.head(100)
# Out:
#            ZIP NPPES_PROVIDER_STATE         NPI PLACE_OF_SERVICE  \
# 1540096  21502                   MD  1003000126                F
# 1540124  21502                   MD  1003000126                F
# 1540125  21502                   MD  1003000126                F
# 1540131  21502                   MD  1003000126                F
# 1540132  21502                   MD  1003000126                F
# ...        ...                  ...         ...              ...
# 7210815  77030                   TX  1003000738                F
# 7211215  77030                   TX  1003000738                F
# 7200034  77030                   TX  1003000738                O
# 8992300  97227                   OR  1003000753                O
# 8992299  97227                   OR  1003000753                O
#
#                PROVIDER_TYPE HCPCS_CODE HCPCS_DRUG_INDICATOR  \
# 1540096    Internal Medicine      99239                    N
# 1540124    Internal Medicine      99233                    N
# 1540125    Internal Medicine      99232                    N
# 1540131    Internal Medicine      99231                    N
# 1540132    Internal Medicine      99223                    N
# ...                      ...        ...                  ...
# 7210815  Physician Assistant      29823                    N
# 7211215  Physician Assistant      29827                    N
# 7200034  Physician Assistant      J1040                    Y
# 8992300  Physician Assistant      99213                    N
# 8992299  Physician Assistant      99212                    N
#
#          AVERAGE_SUBMITTED_CHRG_AMT  STDEV_MEDICARE_PAYMENT_AMT  \
# 1540096                  245.830986                   10.759638
# 1540124                  271.976471                    4.303711
# 1540125                  187.594595                    7.631141
# 1540131                   97.000000                    3.891932
# 1540132                  524.604167                   19.510660
# ...                             ...                         ...
# 7210815                  717.000000                   18.971410
# 7211215                  773.500000                    2.832286
# 7200034                   40.000000                    1.477520
# 8992300                  140.000000                   20.276607
# 8992299                  110.000000                   15.668588
#
#                COUNTYNAME
# 1540096   Allegany County
# 1540124   Allegany County
# 1540125   Allegany County
# 1540131   Allegany County
# 1540132   Allegany County
# ...                   ...
# 7210815     Harris County
# 7211215     Harris County
# 7200034     Harris County
# 8992300  Multnomah County
# 8992299  Multnomah County
#
# [100 rows x 10 columns]

# %%
# Check data

len(dfinal)
# Out:
# 9250845

# %%
# Create Dataframe 

df_2013 = dfinal.groupby(['NPPES_PROVIDER_STATE', 'COUNTYNAME', 'ZIP', 'PROVIDER_TYPE', 'PLACE_OF_SERVICE']).agg({'AVERAGE_SUBMITTED_CHRG_AMT': ['mean'], 'STDEV_MEDICARE_PAYMENT_AMT': ['mean']})
df_2013.columns = ['avg_submit_2013', 'avg_payment_2013']
df_2013 = df_2013.reset_index()

df_2013.head(50)
# Out:
#    NPPES_PROVIDER_STATE                  COUNTYNAME    ZIP  \
# 0                    AK      Aleutians East Borough  99612
# 1                    AK      Aleutians East Borough  99661
# 2                    AK  Aleutians West Census Area  99660
# 3                    AK  Aleutians West Census Area  99685
# 4                    AK  Aleutians West Census Area  99685
# 5                    AK  Aleutians West Census Area  99685
# 6                    AK  Aleutians West Census Area  99685
# 7                    AK  Aleutians West Census Area  99685
# 8                    AK      Anchorage Municipality  99501
# 9                    AK      Anchorage Municipality  99501
# 10                   AK      Anchorage Municipality  99501
# 11                   AK      Anchorage Municipality  99501
# 12                   AK      Anchorage Municipality  99501
# 13                   AK      Anchorage Municipality  99501
# 14                   AK      Anchorage Municipality  99501
# 15                   AK      Anchorage Municipality  99501
# 16                   AK      Anchorage Municipality  99501
# 17                   AK      Anchorage Municipality  99501
# 18                   AK      Anchorage Municipality  99501
# 19                   AK      Anchorage Municipality  99501
# 20                   AK      Anchorage Municipality  99501
# 21                   AK      Anchorage Municipality  99501
# 22                   AK      Anchorage Municipality  99502
# 23                   AK      Anchorage Municipality  99502
# 24                   AK      Anchorage Municipality  99502
# 25                   AK      Anchorage Municipality  99502
# 26                   AK      Anchorage Municipality  99502
# 27                   AK      Anchorage Municipality  99502
# 28                   AK      Anchorage Municipality  99502
# 29                   AK      Anchorage Municipality  99502
# 30                   AK      Anchorage Municipality  99502
# 31                   AK      Anchorage Municipality  99503
# 32                   AK      Anchorage Municipality  99503
# 33                   AK      Anchorage Municipality  99503
# 34                   AK      Anchorage Municipality  99503
# 35                   AK      Anchorage Municipality  99503
# 36                   AK      Anchorage Municipality  99503
# 37                   AK      Anchorage Municipality  99503
# 38                   AK      Anchorage Municipality  99503
# 39                   AK      Anchorage Municipality  99503
# 40                   AK      Anchorage Municipality  99503
# 41                   AK      Anchorage Municipality  99503
# 42                   AK      Anchorage Municipality  99503
# 43                   AK      Anchorage Municipality  99503
# 44                   AK      Anchorage Municipality  99503
# 45                   AK      Anchorage Municipality  99503
# 46                   AK      Anchorage Municipality  99503
# 47                   AK      Anchorage Municipality  99503
# 48                   AK      Anchorage Municipality  99503
# 49                   AK      Anchorage Municipality  99503
#
#                               PROVIDER_TYPE PLACE_OF_SERVICE  avg_submit_2013  \
# 0                        Nurse Practitioner                O       106.000000
# 1                        Nurse Practitioner                O       119.219829
# 2                        Nurse Practitioner                F       117.404097
# 3                           Family Practice                O        92.216151
# 4                         Internal Medicine                F       212.750000
# 5                        Nurse Practitioner                F       100.055556
# 6                        Nurse Practitioner                O        90.000000
# 7                       Physician Assistant                O       165.816667
# 8                Ambulance Service Supplier                F       382.764817
# 9                Ambulatory Surgical Center                F      1996.312000
# 10                                     CRNA                F       893.199870
# 11                          Family Practice                O        83.634001
# 12                        Internal Medicine                O       116.149547
# 13          Licensed Clinical Social Worker                O       143.528974
# 14          Mass Immunization Roster Biller                O        27.161441
# 15                       Nurse Practitioner                O       167.710000
# 16                            Ophthalmology                F      4419.364604
# 17                            Ophthalmology                O       352.782986
# 18                                Optometry                O       234.229284
# 19                       Physical Therapist                O       117.472842
# 20                      Physician Assistant                O        39.750000
# 21                               Psychiatry                F       122.500000
# 22               Ambulance Service Supplier                F      4091.053783
# 23                             Chiropractic                O        39.535000
# 24                          Family Practice                F       173.629630
# 25                          Family Practice                O       118.143112
# 26                         General Practice                O        86.722581
# 27                        Internal Medicine                O       225.554933
# 28          Mass Immunization Roster Biller                O        29.284490
# 29                                Neurology                F       569.920988
# 30                       Nurse Practitioner                O       249.000000
# 31                          Centralized Flu                O        27.294643
# 32                             Chiropractic                O        46.784370
# 33                      Clinical Laboratory                O        53.407302
# 34                    Clinical Psychologist                O       341.000000
# 35             Critical Care (Intensivists)                F       754.544626
# 36                              Dermatology                O       497.318681
# 37                          Family Practice                F       492.065679
# 38                          Family Practice                O       123.248532
# 39                          General Surgery                O       123.906250
# 40  Independent Diagnostic Testing Facility                O      4635.000000
# 41                        Internal Medicine                F       489.256918
# 42          Mass Immunization Roster Biller                O        28.172126
# 43                       Nurse Practitioner                F       218.750000
# 44                       Nurse Practitioner                O       147.394934
# 45                    Obstetrics/Gynecology                O       175.506172
# 46                                Optometry                O       182.403805
# 47     Physical Medicine and Rehabilitation                F       463.176812
# 48                       Physical Therapist                O        88.502062
# 49                      Physician Assistant                O       173.657218
#
#     avg_payment_2013
# 0          10.726037
# 1          11.152344
# 2          14.496392
# 3           2.866764
# 4          14.179404
# 5           4.326681
# 6          11.034453
# 7          21.078659
# 8          17.308632
# 9          61.475308
# 10         19.393788
# 11          1.811709
# 12          5.911177
# 13          8.798480
# 14          2.377597
# 15          7.590141
# 16        111.446924
# 17         24.100850
# 18         22.698828
# 19         14.803683
# 20          0.024875
# 21          7.432457
# 22        140.350562
# 23         10.110393
# 24          5.731978
# 25         19.148333
# 26         12.363329
# 27         21.836612
# 28          1.479192
# 29         12.019000
# 30         14.762605
# 31          0.298970
# 32          9.557756
# 33          0.053182
# 34         15.925105
# 35          4.908140
# 36         33.042992
# 37          9.311505
# 38          1.708411
# 39         11.902609
# 40         96.349032
# 41          8.404468
# 42          1.301634
# 43         21.254613
# 44          9.585173
# 45         19.717687
# 46         19.985449
# 47          4.171892
# 48          9.431581
# 49          6.206146

# %%
# Check data

len(df_2013)
# Out:
# 336514

# %%
# Save dataframe as CSV

df_2013.to_csv('2013.csv')
