# %%
import pandas as pd
import numpy as np
import os

# %%
data_file2012 = "PartD_Prescriber_PUF_NPI_Drug_12.txt"
data_file2013 = "PartD_Prescriber_PUF_NPI_Drug_13.txt"
data_file2014 = "PartD_Prescriber_PUF_NPI_Drug_14.txt"
data_file2015 = "PartD_Prescriber_PUF_NPI_Drug_15.txt"
data_file2016 = "PartD_Prescriber_PUF_NPI_Drug_16.txt"
data_file2017 = "PartD_Prescriber_PUF_NPI_Drug_17.txt"

provider_1 = 0
provider_2 = 1568476968

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2013),sep='\t', nrows=100000)
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2017),sep='\t')
# Drop the null rows
#data_df = data_df.dropna()
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   npi                            100000 non-null  int64
#  1   nppes_provider_last_org_name   100000 non-null  object
#  2   nppes_provider_first_name      99993 non-null   object
#  3   nppes_provider_city            100000 non-null  object
#  4   nppes_provider_state           100000 non-null  object
#  5   specialty_description          100000 non-null  object
#  6   description_flag               100000 non-null  object
#  7   drug_name                      100000 non-null  object
#  8   generic_name                   100000 non-null  object
#  9   bene_count                     36482 non-null   float64
#  10  total_claim_count              100000 non-null  int64
#  11  total_30_day_fill_count        100000 non-null  float64
#  12  total_day_supply               100000 non-null  int64
#  13  total_drug_cost                100000 non-null  float64
#  14  bene_count_ge65                13078 non-null   float64
#  15  bene_count_ge65_suppress_flag  86922 non-null   object
#  16  total_claim_count_ge65         56739 non-null   float64
#  17  ge65_suppress_flag             43261 non-null   object
#  18  total_30_day_fill_count_ge65   56739 non-null   float64
#  19  total_day_supply_ge65          56739 non-null   float64
#  20  total_drug_cost_ge65           56739 non-null   float64
# dtypes: float64(8), int64(3), object(10)
# memory usage: 16.0+ MB

# %%
# Drop the null columns where all values are null
data_df = data_df.dropna(axis='columns', how='all')
# Drop the null rows
#data_df = data_df.dropna()

# %%
data_df
# Out:
#               npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0      1003000126                    ENKESHAFI                   ARDALAN
# 1      1003000126                    ENKESHAFI                   ARDALAN
# 2      1003000126                    ENKESHAFI                   ARDALAN
# 3      1003000126                    ENKESHAFI                   ARDALAN
# 4      1003000126                    ENKESHAFI                   ARDALAN
# ...           ...                          ...                       ...
# 99995  1003842998                        COMES                      IRIS
# 99996  1003843004                    SCHNEIDER                      PAUL
# 99997  1003843004                    SCHNEIDER                      PAUL
# 99998  1003843004                    SCHNEIDER                      PAUL
# 99999  1003843004                    SCHNEIDER                      PAUL
#
#       nppes_provider_city nppes_provider_state specialty_description  \
# 0              CUMBERLAND                   MD     Internal Medicine
# 1              CUMBERLAND                   MD     Internal Medicine
# 2              CUMBERLAND                   MD     Internal Medicine
# 3              CUMBERLAND                   MD     Internal Medicine
# 4              CUMBERLAND                   MD     Internal Medicine
# ...                   ...                  ...                   ...
# 99995       N KANSAS CITY                   MO     Internal Medicine
# 99996          BIRMINGHAM                   AL    Pediatric Medicine
# 99997          BIRMINGHAM                   AL    Pediatric Medicine
# 99998          BIRMINGHAM                   AL    Pediatric Medicine
# 99999          BIRMINGHAM                   AL    Pediatric Medicine
#
#       description_flag                  drug_name               generic_name  \
# 0                    S  ISOSORBIDE MONONITRATE ER     ISOSORBIDE MONONITRATE
# 1                    S               LEVOFLOXACIN               LEVOFLOXACIN
# 2                    S                 LISINOPRIL                 LISINOPRIL
# 3                    S        METOPROLOL TARTRATE        METOPROLOL TARTRATE
# 4                    S                 PREDNISONE                 PREDNISONE
# ...                ...                        ...                        ...
# 99995                S                 PREDNISONE                 PREDNISONE
# 99996                S         ALENDRONATE SODIUM         ALENDRONATE SODIUM
# 99997                S                   CELEBREX                  CELECOXIB
# 99998                S                     EVISTA             RALOXIFENE HCL
# 99999                S  HYDROCODONE-ACETAMINOPHEN  HYDROCODONE/ACETAMINOPHEN
#
#        bene_count  ...  total_30_day_fill_count  total_day_supply  \
# 0             NaN  ...                     11.0               307
# 1            26.0  ...                     26.0               165
# 2            17.0  ...                     19.0               570
# 3            28.0  ...                     31.0               916
# 4            14.0  ...                     14.0               133
# ...           ...  ...                      ...               ...
# 99995        21.0  ...                     24.0               410
# 99996         NaN  ...                     20.0               560
# 99997         NaN  ...                     31.0               930
# 99998         NaN  ...                     15.0               450
# 99999         NaN  ...                     16.0               360
#
#        total_drug_cost  bene_count_ge65  bene_count_ge65_suppress_flag  \
# 0               171.59              NaN                              *
# 1               227.10             15.0                            NaN
# 2               100.37              NaN                              #
# 3               154.65              NaN                              #
# 4                44.72              NaN                              *
# ...                ...              ...                            ...
# 99995           104.33              NaN                              #
# 99996           145.94              NaN                              *
# 99997          7369.29              NaN                              #
# 99998          2646.87              NaN                              *
# 99999           211.48              NaN                              *
#
#       total_claim_count_ge65  ge65_suppress_flag total_30_day_fill_count_ge65  \
# 0                        NaN                   *                          NaN
# 1                       15.0                 NaN                         15.0
# 2                        NaN                   #                          NaN
# 3                        NaN                   #                          NaN
# 4                        NaN                   *                          NaN
# ...                      ...                 ...                          ...
# 99995                    NaN                   #                          NaN
# 99996                   20.0                 NaN                         20.0
# 99997                    NaN                   #                          NaN
# 99998                   11.0                 NaN                         15.0
# 99999                   16.0                 NaN                         16.0
#
#        total_day_supply_ge65  total_drug_cost_ge65
# 0                        NaN                   NaN
# 1                      106.0                159.72
# 2                        NaN                   NaN
# 3                        NaN                   NaN
# 4                        NaN                   NaN
# ...                      ...                   ...
# 99995                    NaN                   NaN
# 99996                  560.0                145.94
# 99997                    NaN                   NaN
# 99998                  450.0               2646.87
# 99999                  360.0                211.48
#
# [100000 rows x 21 columns]

# %%
#data_df

# %%
data_df2012 = data_df.loc[(data_df["NPI"] == provider_1) | (data_df["NPI"] == provider_2), :]
data_df2012['year'] = 2012

# %%
data_df2012

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2013),sep='\t')
# Drop the null rows
data_df = data_df.dropna()

# %%
data_df2013 = data_df.loc[(data_df["NPI"] == provider_1) | (data_df["NPI"] == provider_2), :]
data_df2013['year'] = 2013
data_df2013

# %%
data_df2013.info()

# %%
data_df_total = pd.concat([data_df2012, data_df2013])
data_df_total.info()

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2014),sep='\t')
# Drop the null rows
data_df = data_df.dropna()

# %%
data_df.info()

# %%
data_df.columns

# %%
data_df_total.columns

data_df_total.drop(['STDEV_MEDICARE_ALLOWED_AMT', 'STDEV_SUBMITTED_CHRG_AMT','STDEV_MEDICARE_PAYMENT_AMT'], axis=1, inplace=True)

# %%
data_df_total.columns

# %%
data_df_total.columns = ['npi', 'nppes_provider_last_org_name', 'nppes_provider_first_name',
       'nppes_provider_mi', 'nppes_credentials', 'nppes_provider_gender',
       'nppes_entity_code', 'nppes_provider_street1', 'nppes_provider_street2',
       'nppes_provider_city', 'nppes_provider_zip', 'nppes_provider_state',
       'nppes_provider_country', 'provider_type',
       'medicare_participation_indicator', 'place_of_service', 'hcpcs_code',
       'hcpcs_description', 'hcpcs_drug_indicator', 'line_srvc_cnt',
       'bene_unique_cnt', 'bene_day_srvc_cnt', 'average_Medicare_allowed_amt',
       'average_submitted_chrg_amt', 'average_Medicare_payment_amt',
       'year']

data_df_total.columns

# %%
data_df2014 = data_df.loc[(data_df["npi"] == provider_1) | (data_df["npi"] == provider_2), :]
data_df2014['year'] = 2014

data_df2014.drop('average_Medicare_standard_amt', axis=1, inplace=True)


data_df2014.info()

# %%
data_df_total = pd.concat([data_df_total, data_df2014])
data_df_total.info()

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2015),sep='\t')
# Drop the null rows
data_df = data_df.dropna()

# %%
data_df2015 = data_df.loc[(data_df["npi"] == provider_1) | (data_df["npi"] == provider_2), :]
data_df2015['year'] = 2015

data_df2015.drop('average_Medicare_standard_amt', axis=1, inplace=True)


data_df2015.info()

# %%
data_df_total = pd.concat([data_df_total, data_df2015])
data_df_total.info()

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2016),sep='\t')
# Drop the null rows
data_df = data_df.dropna()

# %%
data_df.info()

# %%
data_df2016 = data_df.loc[(data_df["NPI"] == provider_1) | (data_df["NPI"] == provider_2), :]
data_df2016['year'] = 2016

data_df2016.drop('AVERAGE_MEDICARE_STANDARD_AMT', axis=1, inplace=True)

data_df2016.columns = ['npi', 'nppes_provider_last_org_name', 'nppes_provider_first_name',
       'nppes_provider_mi', 'nppes_credentials', 'nppes_provider_gender',
       'nppes_entity_code', 'nppes_provider_street1', 'nppes_provider_street2',
       'nppes_provider_city', 'nppes_provider_zip', 'nppes_provider_state',
       'nppes_provider_country', 'provider_type',
       'medicare_participation_indicator', 'place_of_service', 'hcpcs_code',
       'hcpcs_description', 'hcpcs_drug_indicator', 'line_srvc_cnt',
       'bene_unique_cnt', 'bene_day_srvc_cnt', 'average_Medicare_allowed_amt',
       'average_submitted_chrg_amt', 'average_Medicare_payment_amt',
       'year']

data_df2016.info()

# %%
data_df_total = pd.concat([data_df_total, data_df2016])
data_df_total.info()

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2017),sep='\t')
# Drop the null rows
data_df = data_df.dropna()

# %%
data_df.info()

# %%
data_df2017 = data_df.loc[(data_df["npi"] == provider_1) | (data_df["npi"] == provider_2), :]
data_df2017['year'] = 2017

data_df2017.drop('average_Medicare_standard_amt', axis=1, inplace=True)

# %%
data_df_total = pd.concat([data_df_total, data_df2017])
data_df_total.info()

# %%
output_data_file = "output_data_part_d.txt"
data_df.to_csv(os.path.join("..", "Data", output_data_file), index= False, sep='\t')
