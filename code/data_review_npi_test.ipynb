# %%
import pandas as pd
import numpy as np
import os

# %%
data_file2012 = "Medicare_Provider_Util_Payment_PUF_CY2012.txt"
data_file2013 = "Medicare_Provider_Util_Payment_PUF_CY2013.txt"
data_file2014 = "Medicare_Provider_Util_Payment_PUF_CY2014.txt"
data_file2015 = "Medicare_Provider_Util_Payment_PUF_CY2015.txt"
data_file2016 = "Medicare_Provider_Util_Payment_PUF_CY2016.txt"
data_file2017 = "Medicare_Provider_Util_Payment_PUF_CY2017.txt"
data_updated = "UPDATED.csv"


provider_1 = 1104909043
provider_2 = 1568476968

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2012),sep='\t', nrows=500000)
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2012),sep='\t')
# Drop the null rows
#data_df = data_df.dropna()
#data_df.head()
# Out:
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   NPI                               500000 non-null  int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      500000 non-null  object
#  2   NPPES_PROVIDER_FIRST_NAME         479993 non-null  object
#  3   NPPES_PROVIDER_MI                 371371 non-null  object
#  4   NPPES_CREDENTIALS                 471119 non-null  object
#  5   NPPES_PROVIDER_GENDER             479999 non-null  object
#  6   NPPES_ENTITY_CODE                 499999 non-null  object
#  7   NPPES_PROVIDER_STREET1            499999 non-null  object
#  8   NPPES_PROVIDER_STREET2            227173 non-null  object
#  9   NPPES_PROVIDER_CITY               499999 non-null  object
#  10  NPPES_PROVIDER_ZIP                499999 non-null  object
# ...

# %%
#data_df

# %%
data_df2012 = data_df
#data_df2012 = data_df.loc[(data_df["NPI"] == provider_1) | (data_df["NPI"] == provider_2), :]
data_df2012['year'] = 2012

# %%
data_df2012
# Out:
#                NPI                       NPPES_PROVIDER_LAST_ORG_NAME  \
# 0                1  CPT copyright 2011 American Medical Associatio...
# 1       1003000126                                          ENKESHAFI
# 2       1003000126                                          ENKESHAFI
# 3       1003000126                                          ENKESHAFI
# 4       1003000126                                          ENKESHAFI
# ...            ...                                                ...
# 499995  1053381673                                           NDUAGUBA
# 499996  1053381673                                           NDUAGUBA
# 499997  1053381673                                           NDUAGUBA
# 499998  1053381673                                           NDUAGUBA
# 499999  1053381673                                           NDUAGUBA
#
#        NPPES_PROVIDER_FIRST_NAME NPPES_PROVIDER_MI NPPES_CREDENTIALS  \
# ...

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2013),sep='\t', nrows=500000)
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2013),sep='\t')
# Drop the null rows
#data_df = data_df.dropna()

# %%
data_df2013 = data_df
#data_df2013 = data_df.loc[(data_df["NPI"] == provider_1) | (data_df["NPI"] == provider_2), :]
data_df2013['year'] = 2013
data_df2013
# Out:
#                NPI                       NPPES_PROVIDER_LAST_ORG_NAME  \
# 0                1  CPT copyright 2012 American Medical Associatio...
# 1       1003000126                                          ENKESHAFI
# 2       1003000126                                          ENKESHAFI
# 3       1003000126                                          ENKESHAFI
# 4       1003000126                                          ENKESHAFI
# ...            ...                                                ...
# 499995  1053371955                                              ABBAS
# 499996  1053371955                                              ABBAS
# 499997  1053371955                                              ABBAS
# 499998  1053371955                                              ABBAS
# 499999  1053371955                                              ABBAS
#
#        NPPES_PROVIDER_FIRST_NAME NPPES_PROVIDER_MI NPPES_CREDENTIALS  \
# ...

# %%
data_df2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   NPI                               500000 non-null  int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      499996 non-null  object
#  2   NPPES_PROVIDER_FIRST_NAME         478284 non-null  object
#  3   NPPES_PROVIDER_MI                 368593 non-null  object
#  4   NPPES_CREDENTIALS                 469049 non-null  object
#  5   NPPES_PROVIDER_GENDER             478291 non-null  object
#  6   NPPES_ENTITY_CODE                 499999 non-null  object
#  7   NPPES_PROVIDER_STREET1            499999 non-null  object
#  8   NPPES_PROVIDER_STREET2            226332 non-null  object
#  9   NPPES_PROVIDER_CITY               499999 non-null  object
#  10  NPPES_PROVIDER_ZIP                499999 non-null  float64
# ...

# %%
data_df_total = pd.concat([data_df2012, data_df2013])
data_df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 0 to 499999
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   NPI                               1000000 non-null  int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      999996 non-null   object
#  2   NPPES_PROVIDER_FIRST_NAME         958277 non-null   object
#  3   NPPES_PROVIDER_MI                 739964 non-null   object
#  4   NPPES_CREDENTIALS                 940168 non-null   object
#  5   NPPES_PROVIDER_GENDER             958290 non-null   object
#  6   NPPES_ENTITY_CODE                 999998 non-null   object
#  7   NPPES_PROVIDER_STREET1            999998 non-null   object
#  8   NPPES_PROVIDER_STREET2            453505 non-null   object
#  9   NPPES_PROVIDER_CITY               999998 non-null   object
#  10  NPPES_PROVIDER_ZIP                999998 non-null   object
# ...

# %%
updated_data_df = pd.read_csv(os.path.join("..", "Data", data_updated))
updated_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73850 entries, 0 to 73849
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LASTNAME    70693 non-null  object
#  1   FIRSTNAME   70694 non-null  object
#  2   MIDNAME     73850 non-null  object
#  3   BUSNAME     3154 non-null   object
#  4   GENERAL     73850 non-null  object
#  5   SPECIALTY   69677 non-null  object
#  6   UPIN        6259 non-null   object
#  7   NPI         73850 non-null  int64
#  8   DOB         69832 non-null  float64
#  9   ADDRESS     73841 non-null  object
#  10  CITY        73849 non-null  object
#  11  STATE       73845 non-null  object
#  12  ZIP         73850 non-null  int64
#  13  EXCLTYPE    73850 non-null  object
#  14  EXCLDATE    73850 non-null  int64
#  15  REINDATE    73850 non-null  int64
#  16  WAIVERDATE  73850 non-null  int64
#  17  WVRSTATE    14 non-null     object
# dtypes: float64(1), int64(5), object(12)
# ...

# %%
updated_data_df
# Out:
#          LASTNAME   FIRSTNAME MIDNAME                        BUSNAME  \
# 0             NaN         NaN              #1 MARKETING SERVICE, INC
# 1             NaN         NaN               14 LAWRENCE AVE PHARMACY
# 2             NaN         NaN               143 MEDICAL EQUIPMENT CO
# 3             NaN         NaN             184TH STREET PHARMACY CORP
# 4             NaN         NaN          1951 FLATBUSH AVENUE PHARMACY
# ...           ...         ...     ...                            ...
# 73845   ZWOLINSKI     RUSSELL      K                             NaN
# 73846   ZYDERVELD        MARY    ANN                             NaN
# 73847     ZYLSTRA  CHRISTEENA   LYNN                             NaN
# 73848     ZYLSTRA       JAMES  PETER                             NaN
# 73849  ZYWOCINSKI     CYNTHIA      A                             NaN
#
#                     GENERAL          SPECIALTY    UPIN         NPI  \
# 0            OTHER BUSINESS         SOBER HOME     NaN           0
# ...

# %%
updated_data_df.drop(updated_data_df[updated_data_df['NPI'] == 0].index, inplace = True)
updated_data_df.reset_index(inplace=True)
updated_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5635 entries, 0 to 5634
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       5635 non-null   int64
#  1   LASTNAME    5263 non-null   object
#  2   FIRSTNAME   5263 non-null   object
#  3   MIDNAME     5635 non-null   object
#  4   BUSNAME     371 non-null    object
#  5   GENERAL     5635 non-null   object
#  6   SPECIALTY   5514 non-null   object
#  7   UPIN        1468 non-null   object
#  8   NPI         5635 non-null   int64
#  9   DOB         5264 non-null   float64
#  10  ADDRESS     5635 non-null   object
#  11  CITY        5635 non-null   object
#  12  STATE       5634 non-null   object
#  13  ZIP         5635 non-null   int64
#  14  EXCLTYPE    5635 non-null   object
#  15  EXCLDATE    5635 non-null   int64
#  16  REINDATE    5635 non-null   int64
#  17  WAIVERDATE  5635 non-null   int64
#  18  WVRSTATE    8 non-null      object
# ...

# %%
updated_data_df
# Out:
#       index    LASTNAME FIRSTNAME MIDNAME                         BUSNAME  \
# 0         3         NaN       NaN              184TH STREET PHARMACY CORP
# 1        23         NaN       NaN               A & Y MEDICAL SUPPLY, INC
# 2        27         NaN       NaN               A CARING ALTERNATIVE, INC
# 3        30         NaN       NaN               A FAIR DEAL PHARMACY, INC
# 4        58         NaN       NaN          ACACIA MENTAL HEALTH CLINIC, L
# ...     ...         ...       ...     ...                             ...
# 5630  73807   ZUCKERMAN     DAVID      H                              NaN
# 5631  73814       ZUKOR      ALAN      J                              NaN
# 5632  73824     ZUPKOFF    GERALD                                     NaN
# 5633  73829     ZURAWEK    TOMASZ   ADAM                              NaN
# 5634  73830  ZURAWIECKI    ROBERT      A                              NaN
#
#                    GENERAL             SPECIALTY    UPIN         NPI  \
# ...

# %%
#data_df_total['leie'] = "no"
#data_df_total['leie_code'] = "none"

# %%
reduced_updated_df = updated_data_df[['NPI','EXCLTYPE']]
reduced_updated_df2 = reduced_updated_df.rename(columns={'NPI' : 'NPI','EXCLTYPE': 'leie_code'})
reduced_updated_df2['leie'] = "On_List"
reduced_updated_df2
# Out:
#              NPI leie_code     leie
# 0     1922348218    1128a1  On_List
# 1     1942476080    1128b8  On_List
# 2     1275600959    1128a1  On_List
# 3     1891731758    1128b8  On_List
# 4     1851631543    1128b7  On_List
# ...          ...       ...      ...
# 5630  1124024435    1128b4  On_List
# 5631  1194930149    1128b5  On_List
# 5632  1578637385    1128a1  On_List
# 5633  1558366815    1128a1  On_List
# 5634  1174561708    1128b4  On_List
#
# [5635 rows x 3 columns]

# %%
#npi_codes = updated_data_df.iloc[:,1:].values

# %%
#npi_codes = updated_data_df.NPI.values.reshape(-1, 1)
#exclusion_codes = updated_data_df.EXCLTYPE.values.reshape(-1, 1)
#print(len(npi_codes))
#print(len(exclusion_codes))

# %%
#cnt = 0
#for npi in npi_codes:

# %%
new_df = pd.merge(data_df_total, reduced_updated_df2, on="NPI", how='left')
new_df['leie_code'] = new_df['leie_code'].fillna('None')
new_df['leie'] = new_df['leie'].fillna('Not')

# %%
new_df
# Out:
#                 NPI                       NPPES_PROVIDER_LAST_ORG_NAME  \
# 0                 1  CPT copyright 2011 American Medical Associatio...
# 1        1003000126                                          ENKESHAFI
# 2        1003000126                                          ENKESHAFI
# 3        1003000126                                          ENKESHAFI
# 4        1003000126                                          ENKESHAFI
# ...             ...                                                ...
# 1000003  1053371955                                              ABBAS
# 1000004  1053371955                                              ABBAS
# 1000005  1053371955                                              ABBAS
# 1000006  1053371955                                              ABBAS
# 1000007  1053371955                                              ABBAS
#
#         NPPES_PROVIDER_FIRST_NAME NPPES_PROVIDER_MI NPPES_CREDENTIALS  \
# ...

# %%
test_df = new_df.loc[(new_df["leie"] == "On_List"), :]

# %%
test_df
# Out:
#                NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 23      1003000407                      GIRARDI                     DAVID
# 24      1003000407                      GIRARDI                     DAVID
# 25      1003000407                      GIRARDI                     DAVID
# 26      1003000407                      GIRARDI                     DAVID
# 27      1003000407                      GIRARDI                     DAVID
# ...            ...                          ...                       ...
# 993560  1053360966                      FUENTES                     EDWIN
# 993561  1053360966                      FUENTES                     EDWIN
# 993562  1053360966                      FUENTES                     EDWIN
# 993563  1053360966                      FUENTES                     EDWIN
# 993564  1053360966                      FUENTES                     EDWIN
#
#        NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER  \
# ...

# %%
output_data_file = "output_data_test.txt"
new_df.to_csv(os.path.join("..", "Data", output_data_file), index= False, sep='\t')
