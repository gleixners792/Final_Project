# %%
import pandas as pd
import numpy as np
import os

# %%
data_file2012 = "Medicare_Provider_Util_Payment_PUF_CY2012.txt"
data_file2013 = "Medicare_Provider_Util_Payment_PUF_CY2013.txt"
data_file2014 = "Medicare_Provider_Util_Payment_PUF_CY2014.txt"
data_file2015 = "Medicare_Provider_Util_Payment_PUF_CY2015.txt"
data_file2016 = "Medicare_Provider_Util_Payment_PUF_CY2016.txt"
data_file2017 = "Medicare_Provider_Util_Payment_PUF_CY2017.txt"
data_updated = "UPDATED.csv"


provider_1 = 1104909043
provider_2 = 1568476968

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2012),sep='\t', nrows=200000)
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2012),sep='\t')
# Drop the null rows
data_df = data_df.dropna()
#data_df.head()

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70231 entries, 8 to 199932
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   NPI                               70231 non-null  int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      70231 non-null  object
#  2   NPPES_PROVIDER_FIRST_NAME         70231 non-null  object
#  3   NPPES_PROVIDER_MI                 70231 non-null  object
#  4   NPPES_CREDENTIALS                 70231 non-null  object
#  5   NPPES_PROVIDER_GENDER             70231 non-null  object
#  6   NPPES_ENTITY_CODE                 70231 non-null  object
#  7   NPPES_PROVIDER_STREET1            70231 non-null  object
#  8   NPPES_PROVIDER_STREET2            70231 non-null  object
#  9   NPPES_PROVIDER_CITY               70231 non-null  object
#  10  NPPES_PROVIDER_ZIP                70231 non-null  float64
#  11  NPPES_PROVIDER_STATE              70231 non-null  object
#  12  NPPES_PROVIDER_COUNTRY            70231 non-null  object
#  13  PROVIDER_TYPE                     70231 non-null  object
#  14  MEDICARE_PARTICIPATION_INDICATOR  70231 non-null  object
#  15  PLACE_OF_SERVICE                  70231 non-null  object
#  16  HCPCS_CODE                        70231 non-null  object
#  17  HCPCS_DESCRIPTION                 70231 non-null  object
#  18  HCPCS_DRUG_INDICATOR              70231 non-null  object
#  19  LINE_SRVC_CNT                     70231 non-null  float64
#  20  BENE_UNIQUE_CNT                   70231 non-null  float64
#  21  BENE_DAY_SRVC_CNT                 70231 non-null  float64
#  22  AVERAGE_MEDICARE_ALLOWED_AMT      70231 non-null  float64
#  23  STDEV_MEDICARE_ALLOWED_AMT        70231 non-null  float64
#  24  AVERAGE_SUBMITTED_CHRG_AMT        70231 non-null  float64
#  25  STDEV_SUBMITTED_CHRG_AMT          70231 non-null  float64
#  26  AVERAGE_MEDICARE_PAYMENT_AMT      70231 non-null  float64
#  27  STDEV_MEDICARE_PAYMENT_AMT        70231 non-null  float64
# dtypes: float64(10), int64(1), object(17)
# memory usage: 15.5+ MB

# %%
#data_df

# %%
data_df2012 = data_df
#data_df2012 = data_df.loc[(data_df["NPI"] == provider_1) | (data_df["NPI"] == provider_2), :]
data_df2012['year'] = 2012

# %%
data_df2012
# Out:
#                NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 8       1003000134                       CIBULL                    THOMAS
# 9       1003000134                       CIBULL                    THOMAS
# 10      1003000134                       CIBULL                    THOMAS
# 11      1003000134                       CIBULL                    THOMAS
# 12      1003000134                       CIBULL                    THOMAS
# ...            ...                          ...                       ...
# 199925  1023027596                     BJORLING                   VINCENT
# 199926  1023027661                       KELLEY                    JUDITH
# 199930  1023027703                     BROCKMAN                   MICHAEL
# 199931  1023027703                     BROCKMAN                   MICHAEL
# 199932  1023027703                     BROCKMAN                   MICHAEL
#
#        NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER  \
# 8                      L              M.D.                     M
# 9                      L              M.D.                     M
# 10                     L              M.D.                     M
# 11                     L              M.D.                     M
# 12                     L              M.D.                     M
# ...                  ...               ...                   ...
# 199925                 G              M.D.                     M
# 199926                 A                MD                     F
# 199930                 J                MD                     M
# 199931                 J                MD                     M
# 199932                 J                MD                     M
#
#        NPPES_ENTITY_CODE NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2  \
# 8                      I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 9                      I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 10                     I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 11                     I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 12                     I         2650 RIDGE AVE      EVANSTON HOSPITAL
# ...                  ...                    ...                    ...
# 199925                 I          3911 AVENUE B             SUITE 1110
# 199926                 I        77 W FOREST AVE              SUITE 207
# 199930                 I     2845 GREENBRIER RD                   #420
# 199931                 I     2845 GREENBRIER RD                   #420
# 199932                 I     2845 GREENBRIER RD                   #420
#
#        NPPES_PROVIDER_CITY  ...  LINE_SRVC_CNT BENE_UNIQUE_CNT  \
# 8                 EVANSTON  ...          226.0           207.0
# 9                 EVANSTON  ...         6070.0          3624.0
# 10                EVANSTON  ...           13.0            13.0
# 11                EVANSTON  ...          330.0           231.0
# 12                EVANSTON  ...           51.0            46.0
# ...                    ...  ...            ...             ...
# 199925         SCOTTSBLUFF  ...           40.0            40.0
# 199926           FLAGSTAFF  ...           12.0            12.0
# 199930           GREEN BAY  ...           18.0            13.0
# 199931           GREEN BAY  ...           22.0            20.0
# 199932           GREEN BAY  ...           14.0            14.0
#
#        BENE_DAY_SRVC_CNT AVERAGE_MEDICARE_ALLOWED_AMT  \
# 8                  209.0                    11.640000
# 9                 4416.0                    37.729960
# 10                  13.0                    12.700000
# 11                 238.0                    27.149576
# 12                  48.0                    12.340000
# ...                  ...                          ...
# 199925              40.0                    11.000000
# 199926              12.0                   302.301667
# 199930              18.0                    40.940000
# 199931              22.0                    67.980000
# 199932              14.0                    36.082857
#
#        STDEV_MEDICARE_ALLOWED_AMT AVERAGE_SUBMITTED_CHRG_AMT  \
# 8                        0.000000                    115.000
# 9                        0.001257                    170.000
# 10                       0.000000                     39.000
# 11                       0.005433                     88.000
# 12                       0.000000                     68.000
# ...                           ...                        ...
# 199925                   0.000000                     11.000
# 199926                  80.359823                   1538.250
# 199930                   0.000000                    116.000
# 199931                   0.000000                    193.000
# 199932                   0.169976                     36.145
#
#        STDEV_SUBMITTED_CHRG_AMT AVERAGE_MEDICARE_PAYMENT_AMT  \
# 8                      0.000000                     8.980442
# 9                      0.000000                    28.984504
# 10                     0.000000                     7.815385
# 11                     0.000000                    21.391364
# 12                     0.000000                     9.676471
# ...                         ...                          ...
# 199925                 0.000000                    10.763500
# 199926               380.902902                   241.841667
# 199930                 0.000000                    30.930556
# 199931                 0.000000                    47.106364
# 199932                 0.291468                    36.082857
#
#        STDEV_MEDICARE_PAYMENT_AMT  year
# 8                        1.720341  2012
# 9                        5.626832  2012
# 10                       4.280662  2012
# 11                       2.646612  2012
# 12                       1.368460  2012
# ...                           ...   ...
# 199925                   1.476942  2012
# 199926                  64.287920  2012
# 199930                   7.501762  2012
# 199931                  15.963476  2012
# 199932                   0.169976  2012
#
# [70231 rows x 29 columns]

# %%
data_df = pd.read_csv(os.path.join("..", "Data", data_file2013),sep='\t', nrows=200000)
#data_df = pd.read_csv(os.path.join("..", "Data", data_file2013),sep='\t')
# Drop the null rows
data_df = data_df.dropna()

# %%
data_df2013 = data_df
#data_df2013 = data_df.loc[(data_df["NPI"] == provider_1) | (data_df["NPI"] == provider_2), :]
data_df2013['year'] = 2013
data_df2013
# Out:
#                NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 8       1003000134                       CIBULL                    THOMAS
# 9       1003000134                       CIBULL                    THOMAS
# 10      1003000134                       CIBULL                    THOMAS
# 11      1003000134                       CIBULL                    THOMAS
# 12      1003000134                       CIBULL                    THOMAS
# ...            ...                          ...                       ...
# 199973  1023019882                         SHAH                      RAJU
# 199974  1023019882                         SHAH                      RAJU
# 199975  1023019882                         SHAH                      RAJU
# 199976  1023019882                         SHAH                      RAJU
# 199977  1023019882                         SHAH                      RAJU
#
#        NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER  \
# 8                      L              M.D.                     M
# 9                      L              M.D.                     M
# 10                     L              M.D.                     M
# 11                     L              M.D.                     M
# 12                     L              M.D.                     M
# ...                  ...               ...                   ...
# 199973                 S              M.D.                     M
# 199974                 S              M.D.                     M
# 199975                 S              M.D.                     M
# 199976                 S              M.D.                     M
# 199977                 S              M.D.                     M
#
#        NPPES_ENTITY_CODE NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2  \
# 8                      I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 9                      I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 10                     I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 11                     I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 12                     I         2650 RIDGE AVE      EVANSTON HOSPITAL
# ...                  ...                    ...                    ...
# 199973                 I       5705 MONCLOVA RD              SUITE 203
# 199974                 I       5705 MONCLOVA RD              SUITE 203
# 199975                 I       5705 MONCLOVA RD              SUITE 203
# 199976                 I       5705 MONCLOVA RD              SUITE 203
# 199977                 I       5705 MONCLOVA RD              SUITE 203
#
#        NPPES_PROVIDER_CITY  ...  LINE_SRVC_CNT BENE_UNIQUE_CNT  \
# 8                 EVANSTON  ...          209.0           201.0
# 9                 EVANSTON  ...         5786.0          3771.0
# 10                EVANSTON  ...          428.0           324.0
# 11                EVANSTON  ...           76.0            68.0
# 12                EVANSTON  ...           48.0            46.0
# ...                    ...  ...            ...             ...
# 199973              MAUMEE  ...          108.0           108.0
# 199974              MAUMEE  ...           44.0            40.0
# 199975              MAUMEE  ...           77.0            69.0
# 199976              MAUMEE  ...           18.0            18.0
# 199977              MAUMEE  ...           27.0            27.0
#
#        BENE_DAY_SRVC_CNT AVERAGE_MEDICARE_ALLOWED_AMT  \
# 8                  204.0                    11.990000
# 9                 4632.0                    38.429983
# 10                 332.0                    27.850000
# 11                  70.0                    12.690000
# 12                  47.0                    88.975833
# ...                  ...                          ...
# 199973             108.0                   105.310000
# 199974              44.0                    42.300000
# 199975              77.0                    70.650000
# 199976              18.0                   202.554444
# 199977              27.0                   219.820000
#
#        STDEV_MEDICARE_ALLOWED_AMT AVERAGE_SUBMITTED_CHRG_AMT  \
# 8                        0.000000                 115.000000
# 9                        0.000588                 170.000000
# 10                       0.000000                  88.000000
# 11                       0.000000                  68.000000
# 12                       6.394314                 265.187500
# ...                           ...                        ...
# 199973                   0.000000                 176.250000
# 199974                   0.000000                  66.818182
# 199975                   0.000000                  93.662338
# 199976                  48.834366                 844.888889
# 199977                   0.000000                 865.777778
#
#        STDEV_SUBMITTED_CHRG_AMT AVERAGE_MEDICARE_PAYMENT_AMT  \
# 8                      0.000000                     9.327464
# 9                      0.000000                    29.279589
# 10                     0.000000                    21.388808
# 11                     0.000000                    10.018421
# 12                     3.244587                    61.946875
# ...                         ...                          ...
# 199973                54.126588                    73.354815
# 199974                 3.856946                    29.723182
# 199975                 3.245818                    46.937143
# 199976                86.127095                   198.571667
# 199977               118.165400                   215.908889
#
#        STDEV_MEDICARE_PAYMENT_AMT  year
# 8                        0.976977  2013
# 9                        5.268831  2013
# 10                       3.479517  2013
# 11                       0.094883  2013
# 12                      22.221258  2013
# ...                           ...   ...
# 199973                  23.634027  2013
# 199974                   9.959074  2013
# 199975                  19.932748  2013
# 199976                  47.654768  2013
# 199977                   1.382787  2013
#
# [69794 rows x 29 columns]

# %%
data_df2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69794 entries, 8 to 199977
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   NPI                               69794 non-null  int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      69794 non-null  object
#  2   NPPES_PROVIDER_FIRST_NAME         69794 non-null  object
#  3   NPPES_PROVIDER_MI                 69794 non-null  object
#  4   NPPES_CREDENTIALS                 69794 non-null  object
#  5   NPPES_PROVIDER_GENDER             69794 non-null  object
#  6   NPPES_ENTITY_CODE                 69794 non-null  object
#  7   NPPES_PROVIDER_STREET1            69794 non-null  object
#  8   NPPES_PROVIDER_STREET2            69794 non-null  object
#  9   NPPES_PROVIDER_CITY               69794 non-null  object
#  10  NPPES_PROVIDER_ZIP                69794 non-null  float64
#  11  NPPES_PROVIDER_STATE              69794 non-null  object
#  12  NPPES_PROVIDER_COUNTRY            69794 non-null  object
#  13  PROVIDER_TYPE                     69794 non-null  object
#  14  MEDICARE_PARTICIPATION_INDICATOR  69794 non-null  object
#  15  PLACE_OF_SERVICE                  69794 non-null  object
#  16  HCPCS_CODE                        69794 non-null  object
#  17  HCPCS_DESCRIPTION                 69794 non-null  object
#  18  HCPCS_DRUG_INDICATOR              69794 non-null  object
#  19  LINE_SRVC_CNT                     69794 non-null  float64
#  20  BENE_UNIQUE_CNT                   69794 non-null  float64
#  21  BENE_DAY_SRVC_CNT                 69794 non-null  float64
#  22  AVERAGE_MEDICARE_ALLOWED_AMT      69794 non-null  float64
#  23  STDEV_MEDICARE_ALLOWED_AMT        69794 non-null  float64
#  24  AVERAGE_SUBMITTED_CHRG_AMT        69794 non-null  float64
#  25  STDEV_SUBMITTED_CHRG_AMT          69794 non-null  float64
#  26  AVERAGE_MEDICARE_PAYMENT_AMT      69794 non-null  float64
#  27  STDEV_MEDICARE_PAYMENT_AMT        69794 non-null  float64
#  28  year                              69794 non-null  int64
# dtypes: float64(10), int64(2), object(17)
# memory usage: 16.0+ MB

# %%
data_df_total = pd.concat([data_df2012, data_df2013])
data_df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140025 entries, 8 to 199977
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   NPI                               140025 non-null  int64
#  1   NPPES_PROVIDER_LAST_ORG_NAME      140025 non-null  object
#  2   NPPES_PROVIDER_FIRST_NAME         140025 non-null  object
#  3   NPPES_PROVIDER_MI                 140025 non-null  object
#  4   NPPES_CREDENTIALS                 140025 non-null  object
#  5   NPPES_PROVIDER_GENDER             140025 non-null  object
#  6   NPPES_ENTITY_CODE                 140025 non-null  object
#  7   NPPES_PROVIDER_STREET1            140025 non-null  object
#  8   NPPES_PROVIDER_STREET2            140025 non-null  object
#  9   NPPES_PROVIDER_CITY               140025 non-null  object
#  10  NPPES_PROVIDER_ZIP                140025 non-null  float64
#  11  NPPES_PROVIDER_STATE              140025 non-null  object
#  12  NPPES_PROVIDER_COUNTRY            140025 non-null  object
#  13  PROVIDER_TYPE                     140025 non-null  object
#  14  MEDICARE_PARTICIPATION_INDICATOR  140025 non-null  object
#  15  PLACE_OF_SERVICE                  140025 non-null  object
#  16  HCPCS_CODE                        140025 non-null  object
#  17  HCPCS_DESCRIPTION                 140025 non-null  object
#  18  HCPCS_DRUG_INDICATOR              140025 non-null  object
#  19  LINE_SRVC_CNT                     140025 non-null  float64
#  20  BENE_UNIQUE_CNT                   140025 non-null  float64
#  21  BENE_DAY_SRVC_CNT                 140025 non-null  float64
#  22  AVERAGE_MEDICARE_ALLOWED_AMT      140025 non-null  float64
#  23  STDEV_MEDICARE_ALLOWED_AMT        140025 non-null  float64
#  24  AVERAGE_SUBMITTED_CHRG_AMT        140025 non-null  float64
#  25  STDEV_SUBMITTED_CHRG_AMT          140025 non-null  float64
#  26  AVERAGE_MEDICARE_PAYMENT_AMT      140025 non-null  float64
#  27  STDEV_MEDICARE_PAYMENT_AMT        140025 non-null  float64
#  28  year                              140025 non-null  int64
# dtypes: float64(10), int64(2), object(17)
# memory usage: 32.0+ MB

# %%
updated_data_df = pd.read_csv(os.path.join("..", "Data", data_updated))
updated_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73850 entries, 0 to 73849
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LASTNAME    70693 non-null  object
#  1   FIRSTNAME   70694 non-null  object
#  2   MIDNAME     73850 non-null  object
#  3   BUSNAME     3154 non-null   object
#  4   GENERAL     73850 non-null  object
#  5   SPECIALTY   69677 non-null  object
#  6   UPIN        6259 non-null   object
#  7   NPI         73850 non-null  int64
#  8   DOB         69832 non-null  float64
#  9   ADDRESS     73841 non-null  object
#  10  CITY        73849 non-null  object
#  11  STATE       73845 non-null  object
#  12  ZIP         73850 non-null  int64
#  13  EXCLTYPE    73850 non-null  object
#  14  EXCLDATE    73850 non-null  int64
#  15  REINDATE    73850 non-null  int64
#  16  WAIVERDATE  73850 non-null  int64
#  17  WVRSTATE    14 non-null     object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 10.1+ MB
# C:\Users\gleix\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
updated_data_df
# Out:
#          LASTNAME   FIRSTNAME MIDNAME                        BUSNAME  \
# 0             NaN         NaN              #1 MARKETING SERVICE, INC
# 1             NaN         NaN               14 LAWRENCE AVE PHARMACY
# 2             NaN         NaN               143 MEDICAL EQUIPMENT CO
# 3             NaN         NaN             184TH STREET PHARMACY CORP
# 4             NaN         NaN          1951 FLATBUSH AVENUE PHARMACY
# ...           ...         ...     ...                            ...
# 73845   ZWOLINSKI     RUSSELL      K                             NaN
# 73846   ZYDERVELD        MARY    ANN                             NaN
# 73847     ZYLSTRA  CHRISTEENA   LYNN                             NaN
# 73848     ZYLSTRA       JAMES  PETER                             NaN
# 73849  ZYWOCINSKI     CYNTHIA      A                             NaN
#
#                     GENERAL          SPECIALTY    UPIN         NPI  \
# 0            OTHER BUSINESS         SOBER HOME     NaN           0
# 1                  PHARMACY                NaN     NaN           0
# 2               DME COMPANY       DME - OXYGEN     NaN           0
# 3            OTHER BUSINESS           PHARMACY     NaN  1922348218
# 4                  PHARMACY                NaN     NaN           0
# ...                     ...                ...     ...         ...
# 73845  MEDICAL PRACTICE, MD            SURGERY  G25488           0
# 73846              PHARMACY         TECHNICIAN     NaN           0
# 73847    NURSING PROFESSION  NURSE/NURSES AIDE     NaN           0
# 73848  REHAB FACILITY - GEN           EMPLOYEE     NaN           0
# 73849      OSTEOPATHIC PRAC         OSTEOPATHY  F00244           0
#
#               DOB                    ADDRESS          CITY STATE    ZIP  \
# 0             NaN  239 BRIGHTON BEACH AVENUE      BROOKLYN    NY  11235
# 1             NaN         14 LAWRENCE AVENUE     SMITHTOWN    NY  11787
# 2             NaN           701 NW 36 AVENUE         MIAMI    FL  33125
# 3             NaN              69 E 184TH ST         BRONX    NY  10468
# 4             NaN          1951 FLATBUSH AVE      BROOKLYN    NY  11234
# ...           ...                        ...           ...   ...    ...
# 73845  19670330.0        1728 W WINNEMAC AVE       CHICAGO    IL  60618
# 73846  19520825.0    1358 MORNING GLORY TURN  RUCKERSVILLE    VA  22962
# 73847  19670724.0        1816 NE 49TH STREET   KANSAS CITY    MO  64118
# 73848  19550420.0   2305 MINNESOTA BLVD, S E      ST CLOUD    MN  56304
# 73849  19630316.0        117 WHITE TAIL LANE     LANCASTER    MA   1523
#
#       EXCLTYPE  EXCLDATE  REINDATE  WAIVERDATE WVRSTATE
# 0       1128a1  20200319         0           0      NaN
# 1       1128a1  19880830         0           0      NaN
# 2       1128b7  19970620         0           0      NaN
# 3       1128a1  20180419         0           0      NaN
# 4       1128b5  20090319         0           0      NaN
# ...        ...       ...       ...         ...      ...
# 73845   1128b4  20031020         0           0      NaN
# 73846   1128b4  20090219         0           0      NaN
# 73847   1128b4  20100318         0           0      NaN
# 73848   1128a2  20040920         0           0      NaN
# 73849  1128b14  19990720         0           0      NaN
#
# [73850 rows x 18 columns]

# %%
updated_data_df.drop(updated_data_df[updated_data_df['NPI'] == 0].index, inplace = True)
updated_data_df.reset_index(inplace=True)
updated_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5635 entries, 0 to 5634
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       5635 non-null   int64
#  1   LASTNAME    5263 non-null   object
#  2   FIRSTNAME   5263 non-null   object
#  3   MIDNAME     5635 non-null   object
#  4   BUSNAME     371 non-null    object
#  5   GENERAL     5635 non-null   object
#  6   SPECIALTY   5514 non-null   object
#  7   UPIN        1468 non-null   object
#  8   NPI         5635 non-null   int64
#  9   DOB         5264 non-null   float64
#  10  ADDRESS     5635 non-null   object
#  11  CITY        5635 non-null   object
#  12  STATE       5634 non-null   object
#  13  ZIP         5635 non-null   int64
#  14  EXCLTYPE    5635 non-null   object
#  15  EXCLDATE    5635 non-null   int64
#  16  REINDATE    5635 non-null   int64
#  17  WAIVERDATE  5635 non-null   int64
#  18  WVRSTATE    8 non-null      object
# dtypes: float64(1), int64(6), object(12)
# memory usage: 836.6+ KB

# %%
updated_data_df
# Out:
#       index    LASTNAME FIRSTNAME MIDNAME                         BUSNAME  \
# 0         3         NaN       NaN              184TH STREET PHARMACY CORP
# 1        23         NaN       NaN               A & Y MEDICAL SUPPLY, INC
# 2        27         NaN       NaN               A CARING ALTERNATIVE, INC
# 3        30         NaN       NaN               A FAIR DEAL PHARMACY, INC
# 4        58         NaN       NaN          ACACIA MENTAL HEALTH CLINIC, L
# ...     ...         ...       ...     ...                             ...
# 5630  73807   ZUCKERMAN     DAVID      H                              NaN
# 5631  73814       ZUKOR      ALAN      J                              NaN
# 5632  73824     ZUPKOFF    GERALD                                     NaN
# 5633  73829     ZURAWEK    TOMASZ   ADAM                              NaN
# 5634  73830  ZURAWIECKI    ROBERT      A                              NaN
#
#                    GENERAL             SPECIALTY    UPIN         NPI  \
# 0           OTHER BUSINESS              PHARMACY     NaN  1922348218
# 1              DME COMPANY         DME - GENERAL     NaN  1942476080
# 2           OTHER BUSINESS    HOME HEALTH AGENCY     NaN  1275600959
# 3           OTHER BUSINESS              PHARMACY     NaN  1891731758
# 4           OTHER BUSINESS  MENTAL/BEHAVIORAL HE     NaN  1851631543
# ...                    ...                   ...     ...         ...
# 5630  IND- LIC HC SERV PRO              PODIATRY  U10438  1124024435
# 5631       DENTAL PRACTICE               DENTIST  T96408  1194930149
# 5632  IND- LIC HC SERV PRO               DENTIST     NaN  1578637385
# 5633    PHYSICIAN (MD, DO)           PULMONOLOGY     NaN  1558366815
# 5634    PHYSICIAN (MD, DO)      GENERAL PRACTICE     NaN  1174561708
#
#              DOB                         ADDRESS          CITY STATE    ZIP  \
# 0            NaN                   69 E 184TH ST         BRONX    NY  10468
# 1            NaN       6310 108TH STREET, APT 6J  FOREST HILLS    NY  11375
# 2            NaN        1229 HURON RD E, FLR 6TH     CLEVELAND    OH  44115
# 3            NaN  C/O  P O BOX 329014, #69709-05      BROOKLYN    NY  11232
# 4            NaN       5228 W FOND DU LAC AVENUE     MILWAUKEE    WI  53216
# ...          ...                             ...           ...   ...    ...
# 5630  19540411.0            1803 COUNTRY CLUB DR   CHERRY HILL    NJ   8003
# 5631  19500126.0    9322 THIRD AVENUE, SUITE 204      BROOKLYN    NY  11209
# 5632  19301230.0             245 PEPPERIDGE ROAD       HEWLETT    NY  11557
# 5633  19621215.0         118 HIGHWAY 70 E, STE 2       DICKSON    TN  37055
# 5634  19450609.0             7454 SW 115TH COURT         MIAMI    FL  33173
#
#      EXCLTYPE  EXCLDATE  REINDATE  WAIVERDATE WVRSTATE
# 0      1128a1  20180419         0           0      NaN
# 1      1128b8  20170518         0           0      NaN
# 2      1128a1  20130320         0           0      NaN
# 3      1128b8  20170518         0           0      NaN
# 4      1128b7  20190326         0           0      NaN
# ...       ...       ...       ...         ...      ...
# 5630   1128b4  20120920         0           0      NaN
# 5631   1128b5  20090920         0           0      NaN
# 5632   1128a1  20120920         0           0      NaN
# 5633   1128a1  20160320         0           0      NaN
# 5634   1128b4  20161220         0           0      NaN
#
# [5635 rows x 19 columns]

# %%
#data_df_total['leie'] = "no"
#data_df_total['leie_code'] = "none"

# %%
reduced_updated_df = updated_data_df[['NPI','EXCLTYPE']]
reduced_updated_df2 = reduced_updated_df.rename(columns={'NPI' : 'NPI','EXCLTYPE': 'leie_code'})
reduced_updated_df2['leie'] = "Yes"
reduced_updated_df2
# Out:
#              NPI leie_code leie
# 0     1922348218    1128a1  Yes
# 1     1942476080    1128b8  Yes
# 2     1275600959    1128a1  Yes
# 3     1891731758    1128b8  Yes
# 4     1851631543    1128b7  Yes
# ...          ...       ...  ...
# 5630  1124024435    1128b4  Yes
# 5631  1194930149    1128b5  Yes
# 5632  1578637385    1128a1  Yes
# 5633  1558366815    1128a1  Yes
# 5634  1174561708    1128b4  Yes
#
# [5635 rows x 3 columns]

# %%
#npi_codes = updated_data_df.iloc[:,1:].values

# %%
#npi_codes = updated_data_df.NPI.values.reshape(-1, 1)
#exclusion_codes = updated_data_df.EXCLTYPE.values.reshape(-1, 1)
#print(len(npi_codes))
#print(len(exclusion_codes))

# %%
#cnt = 0
#for npi in npi_codes:

# %%
new_df = pd.merge(data_df_total, reduced_updated_df2, on="NPI", how='left')
new_df['leie_code'] = new_df['leie_code'].fillna('None')
new_df['leie'] = new_df['leie'].fillna('No')

# %%
new_df
# Out:
#                NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0       1003000134                       CIBULL                    THOMAS
# 1       1003000134                       CIBULL                    THOMAS
# 2       1003000134                       CIBULL                    THOMAS
# 3       1003000134                       CIBULL                    THOMAS
# 4       1003000134                       CIBULL                    THOMAS
# ...            ...                          ...                       ...
# 140020  1023019882                         SHAH                      RAJU
# 140021  1023019882                         SHAH                      RAJU
# 140022  1023019882                         SHAH                      RAJU
# 140023  1023019882                         SHAH                      RAJU
# 140024  1023019882                         SHAH                      RAJU
#
#        NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER  \
# 0                      L              M.D.                     M
# 1                      L              M.D.                     M
# 2                      L              M.D.                     M
# 3                      L              M.D.                     M
# 4                      L              M.D.                     M
# ...                  ...               ...                   ...
# 140020                 S              M.D.                     M
# 140021                 S              M.D.                     M
# 140022                 S              M.D.                     M
# 140023                 S              M.D.                     M
# 140024                 S              M.D.                     M
#
#        NPPES_ENTITY_CODE NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2  \
# 0                      I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 1                      I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 2                      I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 3                      I         2650 RIDGE AVE      EVANSTON HOSPITAL
# 4                      I         2650 RIDGE AVE      EVANSTON HOSPITAL
# ...                  ...                    ...                    ...
# 140020                 I       5705 MONCLOVA RD              SUITE 203
# 140021                 I       5705 MONCLOVA RD              SUITE 203
# 140022                 I       5705 MONCLOVA RD              SUITE 203
# 140023                 I       5705 MONCLOVA RD              SUITE 203
# 140024                 I       5705 MONCLOVA RD              SUITE 203
#
#        NPPES_PROVIDER_CITY  ...  BENE_DAY_SRVC_CNT  \
# 0                 EVANSTON  ...              209.0
# 1                 EVANSTON  ...             4416.0
# 2                 EVANSTON  ...               13.0
# 3                 EVANSTON  ...              238.0
# 4                 EVANSTON  ...               48.0
# ...                    ...  ...                ...
# 140020              MAUMEE  ...              108.0
# 140021              MAUMEE  ...               44.0
# 140022              MAUMEE  ...               77.0
# 140023              MAUMEE  ...               18.0
# 140024              MAUMEE  ...               27.0
#
#        AVERAGE_MEDICARE_ALLOWED_AMT STDEV_MEDICARE_ALLOWED_AMT  \
# 0                         11.640000                   0.000000
# 1                         37.729960                   0.001257
# 2                         12.700000                   0.000000
# 3                         27.149576                   0.005433
# 4                         12.340000                   0.000000
# ...                             ...                        ...
# 140020                   105.310000                   0.000000
# 140021                    42.300000                   0.000000
# 140022                    70.650000                   0.000000
# 140023                   202.554444                  48.834366
# 140024                   219.820000                   0.000000
#
#        AVERAGE_SUBMITTED_CHRG_AMT STDEV_SUBMITTED_CHRG_AMT  \
# 0                      115.000000                 0.000000
# 1                      170.000000                 0.000000
# 2                       39.000000                 0.000000
# 3                       88.000000                 0.000000
# 4                       68.000000                 0.000000
# ...                           ...                      ...
# 140020                 176.250000                54.126588
# 140021                  66.818182                 3.856946
# 140022                  93.662338                 3.245818
# 140023                 844.888889                86.127095
# 140024                 865.777778               118.165400
#
#        AVERAGE_MEDICARE_PAYMENT_AMT STDEV_MEDICARE_PAYMENT_AMT  year  \
# 0                          8.980442                   1.720341  2012
# 1                         28.984504                   5.626832  2012
# 2                          7.815385                   4.280662  2012
# 3                         21.391364                   2.646612  2012
# 4                          9.676471                   1.368460  2012
# ...                             ...                        ...   ...
# 140020                    73.354815                  23.634027  2013
# 140021                    29.723182                   9.959074  2013
# 140022                    46.937143                  19.932748  2013
# 140023                   198.571667                  47.654768  2013
# 140024                   215.908889                   1.382787  2013
#
#        leie_code  leie
# 0           None    No
# 1           None    No
# 2           None    No
# 3           None    No
# 4           None    No
# ...          ...   ...
# 140020      None    No
# 140021      None    No
# 140022      None    No
# 140023      None    No
# 140024      None    No
#
# [140025 rows x 31 columns]

# %%
test_df = new_df.loc[(new_df["leie"] == "Yes"), :]

# %%
test_df
# Out:
#                NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 7108    1003809195                       MACKEY                    JOSEPH
# 7109    1003809195                       MACKEY                    JOSEPH
# 7110    1003809195                       MACKEY                    JOSEPH
# 7111    1003809195                       MACKEY                    JOSEPH
# 7112    1003809195                       MACKEY                    JOSEPH
# ...            ...                          ...                       ...
# 107685  1013093178                        WHITE                     CULLY
# 107686  1013093178                        WHITE                     CULLY
# 134693  1023000122                         VIDA                     KEVIN
# 134694  1023000122                         VIDA                     KEVIN
# 134695  1023000122                         VIDA                     KEVIN
#
#        NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER  \
# 7108                   T              M.D.                     M
# 7109                   T              M.D.                     M
# 7110                   T              M.D.                     M
# 7111                   T              M.D.                     M
# 7112                   T              M.D.                     M
# ...                  ...               ...                   ...
# 107685                 R                DO                     M
# 107686                 R                DO                     M
# 134693                 A              PA C                     M
# 134694                 A              PA C                     M
# 134695                 A              PA C                     M
#
#        NPPES_ENTITY_CODE             NPPES_PROVIDER_STREET1  \
# 7108                   I                  104 NO. 7 HIGHWAY
# 7109                   I                  104 NO. 7 HIGHWAY
# 7110                   I                  104 NO. 7 HIGHWAY
# 7111                   I                  104 NO. 7 HIGHWAY
# 7112                   I                  104 NO. 7 HIGHWAY
# ...                  ...                                ...
# 107685                 I  2901 W KINNICKINNIC RIVER PARKWAY
# 107686                 I  2901 W KINNICKINNIC RIVER PARKWAY
# 134693                 I               39000 BOB HOPE DRIVE
# 134694                 I               39000 BOB HOPE DRIVE
# 134695                 I               39000 BOB HOPE DRIVE
#
#                NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  ...  \
# 7108                          SUITE B        BLUE SPRINGS  ...
# 7109                          SUITE B        BLUE SPRINGS  ...
# 7110                          SUITE B        BLUE SPRINGS  ...
# 7111                          SUITE B        BLUE SPRINGS  ...
# 7112                          SUITE B        BLUE SPRINGS  ...
# ...                               ...                 ...  ...
# 107685                      SUITE 201           MILWAUKEE  ...
# 107686                      SUITE 201           MILWAUKEE  ...
# 134693  HARRY & DIANE RINKER BUILDING       RANCHO MIRAGE  ...
# 134694  HARRY & DIANE RINKER BUILDING       RANCHO MIRAGE  ...
# 134695  HARRY & DIANE RINKER BUILDING       RANCHO MIRAGE  ...
#
#         BENE_DAY_SRVC_CNT AVERAGE_MEDICARE_ALLOWED_AMT  \
# 7108                 21.0                        30.92
# 7109                 31.0                        23.40
# 7110                 88.0                        69.37
# 7111                142.0                       102.61
# 7112                 21.0                        23.40
# ...                   ...                          ...
# 107685               22.0                        36.36
# 107686              138.0                        67.03
# 134693               13.0                        13.42
# 134694               13.0                         7.71
# 134695               30.0                        21.12
#
#        STDEV_MEDICARE_ALLOWED_AMT AVERAGE_SUBMITTED_CHRG_AMT  \
# 7108                          0.0                  46.380000
# 7109                          0.0                  35.000000
# 7110                          0.0                  96.590909
# 7111                          0.0                 144.788732
# 7112                          0.0                  28.000000
# ...                           ...                        ...
# 107685                        0.0                 200.000000
# 107686                        0.0                 220.000000
# 134693                        0.0                  55.510000
# 134694                        0.0                  31.010000
# 134695                        0.0                  80.640000
#
#        STDEV_SUBMITTED_CHRG_AMT AVERAGE_MEDICARE_PAYMENT_AMT  \
# 7108                   0.000000                    30.920000
# 7109                   0.000000                    13.992500
# 7110                   4.740149                    46.046818
# 7111                   4.995535                    62.662676
# 7112                   0.000000                    23.400000
# ...                         ...                          ...
# 107685                 0.000000                    29.037273
# 107686                 0.000000                    52.590580
# 134693                 0.000000                     3.151538
# 134694                 0.000000                     1.898462
# 134695                 0.000000                     5.801333
#
#        STDEV_MEDICARE_PAYMENT_AMT  year leie_code  leie
# 7108                     0.000000  2012    1128b4   Yes
# 7109                     7.042950  2012    1128b4   Yes
# 7110                    19.565442  2012    1128b4   Yes
# 7111                    31.400280  2012    1128b4   Yes
# 7112                     0.000000  2012    1128b4   Yes
# ...                           ...   ...       ...   ...
# 107685                   0.166738  2013    1128a3   Yes
# 107686                   3.127485  2013    1128a3   Yes
# 134693                   4.751411  2013    1128b4   Yes
# 134694                   2.847692  2013    1128b4   Yes
# 134695                   7.899024  2013    1128b4   Yes
#
# [151 rows x 31 columns]
